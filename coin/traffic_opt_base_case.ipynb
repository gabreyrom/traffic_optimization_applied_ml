# %%
# SPA vs COIN_FF vs COIN_FF_RL (imitation of COIN_FF)

import math
import random
import pandas as pd
import numpy as np
from dataclasses import dataclass
from typing import Dict, List, Tuple, Set, Counter, Optional
from collections import defaultdict

import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import LineString, MultiLineString
import networkx as nx
import heapq
from matplotlib.animation import FuncAnimation, FFMpegWriter

# Reproducibility: set seeds before any network/OD sampling
GLOBAL_SEED = 26
random.seed(GLOBAL_SEED)
np.random.seed(GLOBAL_SEED)

# %% [markdown]
# # Load shapefile and build TrafficNetwork

# %%
# Path to your shapefile
path = "../trimmed_manhattan_shape/trimmed_manhattan.shp"
gdf = gpd.read_file(path)
print("CRS:", gdf.crs)
print("Geometry types:", gdf.geom_type.unique())
print("Columns:", gdf.columns.tolist())

# If CRS is geographic (lat/lon), reproject to EPSG:2263 (NY State Plane)
if gdf.crs is not None and gdf.crs.is_geographic:
    gdf = gdf.to_crs(epsg=2263)
print("Reprojected CRS: ", gdf.crs)
# Out:
# CRS: EPSG:4326
# Geometry types: ['LineString']
# Columns: ['osm_id', 'name', 'highway', 'oneway', 'geometry']
# Reprojected CRS:  EPSG:2263

# %% [markdown]
# ## Constants of the network

# %%
# =========================
# Types
# =========================
Node = Tuple[float, float]          # (x, y)
EdgeId = Tuple[Node, Node]          # directed edge
EdgeFlows = Dict[EdgeId, float]     # typically veh/hour if used in BPR
Graph = Dict[Node, List[EdgeId]]


def make_node(x: float, y: float, ndigits: int = 3) -> Node:
    """Rounding keeps nodes consistent instead of tiny float differences."""
    return round(x, ndigits), round(y, ndigits)


# =========================
# Constants (consistent units)
# =========================
FT_TO_M = 0.3048006096          # EPSG:2263 is US survey feet
SPACE_PER_VEH_M = 7.5           # avg standstill spacing: car length + gap (meters/veh)
MIN_STORAGE_CAP = 1             # minimum storage vehicles per directed edge

# BPR parameters
BPR_ALPHA = 0.15
BPR_BETA = 4.0

# Flow (throughput) capacity per lane for Manhattan-like signalized streets (tunable)
Q_SAT_VPHPL = 900.0             # veh/hour/lane


# Optional: rough defaults by highway type if lanes missing (keep if useful)
HIGHWAY_DEFAULT_LANES = {
    "motorway": 6,
    "trunk": 5,
    "primary": 5,
    "secondary": 4,
    "tertiary": 2,
    "residential": 2,
    "service": 1,
}


def parse_lanes(row: dict, default: int = 1) -> int:
    """
    Robust lane parsing:
    - uses row['lanes'] if present
    - else falls back to row['highway'] defaults
    """
    val = row.get("lanes", None)
    if val is None or (isinstance(val, float) and math.isnan(val)):
        hw = row.get("highway", None)
        return max(1, int(HIGHWAY_DEFAULT_LANES.get(hw, default)))

    try:
        if isinstance(val, str):
            # handle "2;3", "2|3", "2,3" etc. -> take first token
            for sep in (";", "|", ","):
                if sep in val:
                    val = val.split(sep)[0]
                    break
            val = val.strip()
        lanes = int(float(val))
        return max(1, lanes)
    except Exception:
        hw = row.get("highway", None)
        return max(1, int(HIGHWAY_DEFAULT_LANES.get(hw, default)))


def sample_free_speed_time_based() -> float:
    """
    Sample free-flow speed via a lognormal model on time-per-meter.
    Returns m/s, clamped to ~18–90 km/h (5–25 m/s).
    """
    median_s_per_m = 0.09  # ~11.11 m/s (~40 km/h)
    mu = math.log(median_s_per_m)
    sigma = 0.3
    s_per_m = random.lognormvariate(mu, sigma)  # seconds per meter
    v_free = 1.0 / s_per_m

    return max(min(v_free, 25.0), 5.0)

# %% [markdown]
# ## Data Classes of the network

# %%
@dataclass
class Edge:
    start: Node
    end: Node
    length_m: float            # meters
    v_free: float              # m/s

    storage_cap: int           # vehicles (max vehicles that fit on segment)
    flow_cap_vph: float        # vehicles/hour (throughput capacity for BPR)

    alpha: float = BPR_ALPHA
    beta: float = BPR_BETA

    @property
    def free_time(self) -> float:
        """Free-flow travel time (seconds)."""
        return self.length_m / self.v_free if self.v_free > 0 else float("inf")

    def travel_time(self, flow_vph: float) -> float:
        """
        BPR travel time.
        IMPORTANT: flow_vph must be in vehicles/hour, and is compared to flow_cap_vph (vehicles/hour).
        """
        if self.flow_cap_vph <= 0:
            return float("inf")
        x = max(0.0, flow_vph / self.flow_cap_vph)
        return self.free_time * (1.0 + self.alpha * (x ** self.beta))


@dataclass
class TrafficNetwork:
    graph: Graph
    edges: Dict[EdgeId, Edge]

# %% [markdown]
# ## Network builder

# %%
# =========================
# Network builder
# =========================
def network_from_streets_gdf(streets_gdf: gpd.GeoDataFrame) -> Tuple[TrafficNetwork, List[int]]:
    """
    Build a directed TrafficNetwork from a GeoDataFrame of street segments.

    Assumptions:
    - Input geometries are in EPSG:2263 (US survey feet).
    - We convert lengths to meters internally.
    - storage_cap = physical storage capacity (veh).
    - flow_cap_vph = throughput capacity (veh/h) for BPR.
    """
    graph: Dict[Node, List[EdgeId]] = defaultdict(list)
    edges: Dict[EdgeId, Edge] = {}

    storage_caps: List[int] = []

    for _, row in streets_gdf.iterrows():
        geom = row.geometry
        if geom is None:
            continue

        if isinstance(geom, MultiLineString):
            line_geoms = list(geom.geoms)
        elif isinstance(geom, LineString):
            line_geoms = [geom]
        else:
            continue

        lanes = parse_lanes(row, default=1)

        for line in line_geoms:
            coords = list(line.coords)
            if len(coords) < 2:
                continue

            # endpoints become graph nodes
            u = make_node(*coords[0])
            v = make_node(*coords[-1])

            # length: feet -> meters
            length_m = float(line.length) * FT_TO_M

            # fixed storage capacity (veh)
            storage_cap = max(
                MIN_STORAGE_CAP,
                int((length_m * lanes) // SPACE_PER_VEH_M)
            )
            storage_caps.append(storage_cap)

            # speed affects travel time and (optionally) an upper bound on flow cap
            v_free = sample_free_speed_time_based()  # m/s

            # flow cap for BPR (veh/h): cap by signalized saturation and speed-based upper bound
            q_speed_vphpl = (v_free / SPACE_PER_VEH_M) * 3600.0
            q_lane_vph = min(q_speed_vphpl, Q_SAT_VPHPL)
            flow_cap_vph = lanes * q_lane_vph

            def _add_edge(a: Node, b: Node):
                eid = (a, b)
                if eid in edges:
                    # keep the "stronger" version if duplicates occur
                    if length_m > edges[eid].length_m:
                        edges[eid].length_m = length_m
                        edges[eid].storage_cap = storage_cap
                        edges[eid].flow_cap_vph = flow_cap_vph
                        edges[eid].v_free = v_free
                    return

                edges[eid] = Edge(
                    start=a,
                    end=b,
                    length_m=length_m,
                    v_free=v_free,
                    storage_cap=storage_cap,
                    flow_cap_vph=flow_cap_vph,
                )
                graph[a].append(eid)

            # add both directions
            _add_edge(u, v)
            _add_edge(v, u)

    return TrafficNetwork(graph=dict(graph), edges=edges), storage_caps

# %% [markdown]
# ## Create the manhattan network

# %%
# Build network
manhattan_network, capacities = network_from_streets_gdf(gdf)
print(f"# nodes: {len(manhattan_network.graph)}")
print(f"# edges: {len(manhattan_network.edges)}")
# Out:
# # nodes: 6701
# # edges: 16444

# %%
def count_dead_ends(network: TrafficNetwork) -> int:
    outdeg = {n: len(network.graph.get(n, [])) for n in network.graph.keys()}
    indeg = defaultdict(int)
    for (u, v) in network.edges.keys():
        indeg[v] += 1
    dead = [n for n in set(outdeg) | set(indeg) if (outdeg.get(n,0) + indeg.get(n,0)) <= 1]
    return len(dead)

print("Dead-end-ish nodes:", count_dead_ends(manhattan_network))
# Out:
# Dead-end-ish nodes: 0

# %%
capacities = pd.Series(capacities)
capacities.hist(bins=100)
print(min(capacities), max(capacities))
# Out:
# 1 2225

# %% [markdown]
# ## NetworkX conversion (for sanity plot)

# %%
def to_networkx(network: TrafficNetwork) -> nx.DiGraph:
    G = nx.DiGraph()

    for node in network.graph.keys():
        G.add_node(node, x=node[0], y=node[1])

    for edge in network.edges.values():
        G.add_edge(
            edge.start,
            edge.end,
            free_time=edge.free_time,          # seconds
            storage_cap=edge.storage_cap,      # vehicles (queue size)
            flow_cap_vph=edge.flow_cap_vph,    # vehicles/hour (throughput)
            length_m=edge.length_m,
            v_free=edge.v_free,
        )

    return G


G_nx = to_networkx(manhattan_network)
print("# NX nodes:", G_nx.number_of_nodes(), "# NX edges:", G_nx.number_of_edges())
# Out:
# # NX nodes: 6701 # NX edges: 16444

# %% [markdown]
# ### Print Network X graph

# %%
pos = {n: (n[0], n[1]) for n in G_nx.nodes()}
plt.figure(figsize=(8, 8))
nx.draw(G_nx, pos=pos, node_size=1, linewidths=0.1, width=0.1)
plt.axis("equal")
plt.title("Road network graph from trimmed_manhattan.shp")
plt.show()

# %% [markdown]
# ## Agents + OD selection

# %%
@dataclass
class Agent:
    origin: Node
    destination: Node
    path: List[Node] = None
    experienced_time_s: Optional[float] = None


def sample_agents_random(network: TrafficNetwork, num_agents: int) -> List[Agent]:
    nodes = list(network.graph.keys())
    agents: List[Agent] = []
    for _ in range(num_agents):
        o = random.choice(nodes)
        d = random.choice(nodes)
        while d == o:
            d = random.choice(nodes)
        agents.append(Agent(origin=o, destination=d))
    return agents


def sample_agents_north_south(
    network: TrafficNetwork,
    num_agents: int,
    band_split: float = 0.5,
) -> List[Agent]:
    nodes = list(network.graph.keys())
    ys = [y for (_, y) in nodes]
    y_min, y_max = min(ys), max(ys)
    y_mid = y_min + band_split * (y_max - y_min)

    north_nodes = [n for n in nodes if n[1] >= y_mid]
    south_nodes = [n for n in nodes if n[1] <= y_mid]
    assert north_nodes and south_nodes, "North/south bands empty – check CRS/band_split."

    agents: List[Agent] = []
    for _ in range(num_agents):
        o = random.choice(north_nodes)
        d = random.choice(south_nodes)
        agents.append(Agent(origin=o, destination=d))
    return agents


def pick_north_south_pair(network: TrafficNetwork) -> Tuple[Node, Node]:
    """Pick a single north–south OD pair to keep SPA / COIN_FF comparable."""
    nodes = list(network.graph.keys())
    ys = [y for (_, y) in nodes]
    y_min, y_max = min(ys), max(ys)

    # north = top 20%, south = bottom 20%
    north_nodes = [n for n in nodes if n[1] >= y_min + 0.8 * (y_max - y_min)]
    south_nodes = [n for n in nodes if n[1] <= y_min + 0.2 * (y_max - y_min)]

    o = random.choice(north_nodes)
    d = random.choice(south_nodes)
    return o, d


def sample_agents_fixed(
    network: TrafficNetwork,
    num_agents: int,
    origin: Node,
    destination: Node
) -> List[Agent]:
    return [Agent(origin=origin, destination=destination) for _ in range(num_agents)]

# %% [markdown]
# # Routing Algorithms

# %% [markdown]
# ## Dijkstra (SPA)

# %%
def dijkstra(network: TrafficNetwork, source: Node, target: Node, edge_flow_vph: EdgeFlows) -> List[Node]:
    """Dijkstra where cost = travel time t(flow_vph)."""
    graph, edges = network.graph, network.edges

    dist: Dict[Node, float] = {source: 0.0}
    prev: Dict[Node, Node] = {}
    pq = [(0.0, source)]
    visited = set()

    while pq:
        d_u, u = heapq.heappop(pq)
        if u in visited:
            continue
        visited.add(u)
        if u == target:
            break

        for edge_id in graph.get(u, []):
            edge = edges[edge_id]
            v = edge.end
            w = edge.travel_time(edge_flow_vph.get(edge_id, 0.0))
            nd = d_u + w
            if v not in dist or nd < dist[v]:
                dist[v] = nd
                prev[v] = u
                heapq.heappush(pq, (nd, v))

    if target not in dist:
        return []

    path: List[Node] = []
    cur = target
    while cur != source:
        path.append(cur)
        cur = prev[cur]
    path.append(source)
    path.reverse()
    return path

# %%
def edges_from_path(path: List[Node]) -> List[EdgeId]:
    return list(zip(path[:-1], path[1:]))


def spa_route_all(
    network: TrafficNetwork,
    agents: List[Agent],
    horizon_s: float = 3600.0,   # interpret all agents as demand over this time horizon
) -> Tuple[List[Agent], EdgeFlows]:
    """
    Selfish Path Assignment (SPA):
    edge_counts[e] is a vehicle count; we convert to flow_vph for BPR.

    Also records each agent's experienced travel time using the live flow
    seen at traversal time (before that agent increments edge counts).
    """
    edge_counts: EdgeFlows = defaultdict(float)
    scale_to_vph = 3600.0 / horizon_s

    for agent in agents:
        edge_flow_vph = {e: c * scale_to_vph for e, c in edge_counts.items()}

        path = dijkstra(network, agent.origin, agent.destination, edge_flow_vph)
        agent.path = path

        travel_s = 0.0
        for e in edges_from_path(path):
            edge = network.edges[e]
            flow_vph = edge_counts[e] * scale_to_vph
            travel_s += edge.travel_time(flow_vph)
            edge_counts[e] += 1.0

        agent.experienced_time_s = travel_s

    return agents, edge_counts

# %% [markdown]
# ## FF

# %%
DELTA_VPH = 50.0


def edge_marginal_cost(edge: Edge, flow_before_vph: float, delta_vph: float = DELTA_VPH) -> float:
    """Marginal increase in total system travel time proxy when flow increases by delta_vph."""
    f1 = flow_before_vph
    f2 = flow_before_vph + delta_vph
    t1 = edge.travel_time(f1)
    t2 = edge.travel_time(f2)
    return (f2 * t2) - (f1 * t1)


# Optional tiny noise so the expert does not collapse into identical ties everywhere
FF_NOISE_EPS = 0.02     # 0.00–0.05


def edge_assignment_cost(
    edge: Edge,
    flow_before_vph: float,
    delta_vph: float = DELTA_VPH,
) -> float:
    """
    Edge cost for static FF assignment.

    We intentionally avoid storage-cap penalties/blocks here because edge_counts is
    a cumulative trip count in static assignment, not a time-indexed occupancy.
    """
    base = edge_marginal_cost(edge, flow_before_vph, delta_vph=delta_vph)

    if FF_NOISE_EPS > 0:
        base *= (1.0 + FF_NOISE_EPS * (random.random() - 0.5))

    return base


def dijkstra_coin_ff_marginal(
    network: TrafficNetwork,
    source: Node,
    target: Node,
    edge_flow_vph: EdgeFlows,
) -> List[Node]:
    """Shortest path where edge weight is the marginal system travel-time cost."""
    graph, edges = network.graph, network.edges

    dist: Dict[Node, float] = {source: 0.0}
    prev: Dict[Node, Node] = {}
    pq = [(0.0, source)]
    visited = set()

    while pq:
        cost_u, u = heapq.heappop(pq)
        if u in visited:
            continue
        visited.add(u)
        if u == target:
            break

        for edge_id in graph.get(u, []):
            edge = edges[edge_id]
            v = edge.end

            f_before_vph = float(edge_flow_vph.get(edge_id, 0.0))
            marginal = edge_assignment_cost(edge, flow_before_vph=f_before_vph)

            new_cost = cost_u + marginal

            if v not in dist or new_cost < dist[v]:
                dist[v] = new_cost
                prev[v] = u
                heapq.heappush(pq, (new_cost, v))

    if target not in dist:
        return []

    path: List[Node] = []
    cur = target
    while cur != source:
        path.append(cur)
        cur = prev[cur]
    path.append(source)
    path.reverse()
    return path

# %%
def ford_fulkerson_route_all(
    network: TrafficNetwork,
    agents: List[Agent],
    horizon_s: float = 3600.0,
) -> Tuple[List[Agent], EdgeFlows]:
    """
    FF-style marginal-cost routing over static demand assignment.

    - edge_counts = cumulative vehicle counts (demand assignment), not queue occupancy
    - edge_flow_vph = derived (veh/h) for travel_time/marginal costs
    """
    edge_counts: EdgeFlows = defaultdict(float)
    scale_to_vph = 3600.0 / horizon_s

    for agent in agents:
        edge_flow_vph = {e: c * scale_to_vph for e, c in edge_counts.items()}

        path = dijkstra_coin_ff_marginal(
            network,
            agent.origin,
            agent.destination,
            edge_flow_vph=edge_flow_vph,
        )
        agent.path = path

        travel_s = 0.0
        for e in edges_from_path(path):
            edge = network.edges[e]
            flow_vph = edge_counts[e] * scale_to_vph
            travel_s += edge.travel_time(flow_vph)
            edge_counts[e] += 1.0

        agent.experienced_time_s = travel_s

    return agents, edge_counts

# %% [markdown]
# # World utility & OD used for fixed experiments

# %%
def total_system_travel_time(
    network: TrafficNetwork,
    edge_counts: EdgeFlows,
    horizon_s: float = 3600.0,
) -> float:
    """Total system travel time in seconds."""
    total_s = 0.0
    scale = 3600.0 / horizon_s  # counts -> veh/hour

    for e_id, count in edge_counts.items():
        edge = network.edges[e_id]
        flow_vph = count * scale
        total_s += count * edge.travel_time(flow_vph)

    return total_s


# Fixed OD pair (global, to keep things simple and consistent)
origin, destination = pick_north_south_pair(manhattan_network)
zero_flows = defaultdict(float)
shortest_path = dijkstra(manhattan_network, origin, destination, zero_flows)
shortest_edges = set(edges_from_path(shortest_path))

print("Origin:", origin)
print("Destination:", destination)
print("Shortest path length (edges):", max(len(shortest_path) - 1, 0))
# Out:
# Origin: (1003004.765, 252431.584)
# Destination: (986224.45, 201611.479)
# Shortest path length (edges): 123

# %% [markdown]
# # Coin

# %% [markdown]
# ## Difference reward helpers

# %%
# --- COIN / difference–reward helpers ---------------------------------

def edge_global_cost(
    edge: Edge,
    count: float,
    horizon_s: float,
) -> float:
    """
    Global contribution of a single edge to total system travel time:

        G_e = count * T_e(flow_vph)

    where:
        flow_vph = count * (3600 / horizon_s)

    Units: seconds
    """
    flow_vph = count * (3600.0 / horizon_s)
    return count * edge.travel_time(flow_vph)


def edge_marginal_global_cost(
    edge: Edge,
    count_before: float,
    horizon_s: float,
) -> float:
    """
    Marginal increase in total system travel time caused by
    adding ONE additional vehicle to this edge.

    Units: seconds
    """
    return (
        edge_global_cost(edge, count_before + 1.0, horizon_s)
        - edge_global_cost(edge, count_before, horizon_s)
    )

# %% [markdown]
# ## Online Q

# %% [markdown]
# ### Expert dataset

# %%
def build_ff_expert_dataset(
    network: TrafficNetwork,
    num_agents: int = 200,
    od_mode: str = "fixed",
    horizon_s: float = 3600.0,
    fixed_od: Optional[Tuple[Node, Node]] = None,
):
    """
    Run Ford-Fulkerson-based assignment once and record expert transitions.

    Returns
    -------
    expert_steps        : list of (s, d, a, edge_id)
    agents_ff           : list[Agent]
    flows_ff            : EdgeFlows  (vehicle counts per edge)
    expert_edge_quality : Dict[EdgeId, float]
        Quality score in [0, 1] for each expert edge.
        1.0 = lowest marginal system cost at expert time (best choice),
        0.0 = highest marginal cost.  Used as a continuous expert bonus
        in Q-learning so that high-quality expert edges are rewarded more.
    """
    if od_mode == "random":
        agents = sample_agents_random(network, num_agents)
    elif od_mode in ("north_south", "north-south"):
        agents = sample_agents_north_south(network, num_agents)
    else:  # "fixed"
        if fixed_od is None:
            raise ValueError("fixed_od=(origin, destination) is required when od_mode='fixed'")
        agents = sample_agents_fixed(network, num_agents, fixed_od[0], fixed_od[1])

    agents_ff, edge_counts_ff = ford_fulkerson_route_all(network, agents, horizon_s=horizon_s)

    expert_steps = []
    for agent in agents_ff:
        if not agent.path or agent.path[-1] != agent.destination:
            continue
        d = agent.destination
        for (s, a) in edges_from_path(agent.path):
            expert_steps.append((s, d, a, (s, a)))

    print(
        f"Collected {len(expert_steps)} FF-expert (s,d,a,edge_id) steps "
        f"from {len(agents_ff)} agents."
    )

    # ------------------------------------------------------------------
    # Quality scoring: marginal system cost at expert execution time.
    # Lower delta_G  =>  edge was a better system-level choice  =>  higher quality.
    # ------------------------------------------------------------------
    raw_dG: Dict[EdgeId, float] = {}
    for (_, _, _, edge_id) in expert_steps:
        if edge_id in raw_dG:
            continue
        edge = network.edges[edge_id]
        c_before = max(edge_counts_ff.get(edge_id, 0.0) - 1.0, 0.0)
        raw_dG[edge_id] = edge_marginal_global_cost(edge, c_before, horizon_s)

    expert_edge_quality: Dict[EdgeId, float] = {}
    if raw_dG:
        min_dG = min(raw_dG.values())
        max_dG = max(raw_dG.values())
        span   = max(max_dG - min_dG, 1.0)
        for eid, dg in raw_dG.items():
            expert_edge_quality[eid] = 1.0 - (dg - min_dG) / span   # invert: low cost => high quality

    if expert_edge_quality:
        q_vals = list(expert_edge_quality.values())
        print(
            f"Expert quality scores: {len(expert_edge_quality)} edges, "
            f"range [{min(q_vals):.3f}, {max(q_vals):.3f}]."
        )

    return expert_steps, agents_ff, edge_counts_ff, expert_edge_quality

# %% [markdown]
# ### Helpers

# %%
def get_neighbors(network: TrafficNetwork, node: Node) -> List[Node]:
    return [network.edges[e_id].end for e_id in network.graph.get(node, [])]


def edge_congestion_bin(edge: Edge, flow_vph: float) -> int:
    """
    Discretize congestion into 3 bins for COIN-style state.
    Uses FLOW capacity (veh/h), consistent with BPR.

      0 = low    (v/c < 0.3)
      1 = medium (0.3 <= v/c < 0.7)
      2 = high   (v/c >= 0.7)
    """
    cap_vph = max(edge.flow_cap_vph, 1e-6)
    ratio = flow_vph / cap_vph

    if ratio < 0.3:
        return 0
    elif ratio < 0.7:
        return 1
    else:
        return 2

def dist_to_dest(node: Node, dest: Node) -> float:
    """Euclidean distance (in coordinate units) from node to dest."""
    x1, y1 = node
    x2, y2 = dest
    return math.hypot(x2 - x1, y2 - y1)

# %%
from dataclasses import dataclass, field
from collections import defaultdict
from typing import Any, Dict

@dataclass
class RewardDebug:
    enabled: bool = True
    n: int = 0
    sums: Dict[str, float] = field(default_factory=lambda: defaultdict(float))
    mins: Dict[str, float] = field(default_factory=lambda: defaultdict(lambda: float("inf")))
    maxs: Dict[str, float] = field(default_factory=lambda: defaultdict(lambda: float("-inf")))

    def add(self, **vals: Any) -> None:
        if not self.enabled:
            return
        self.n += 1
        for k, v in vals.items():
            if v is None:
                continue
            fv = float(v)
            self.sums[k] += fv
            self.mins[k] = min(self.mins[k], fv)
            self.maxs[k] = max(self.maxs[k], fv)

    def summary(self, name: str = "Reward breakdown") -> None:
        if not self.enabled or self.n == 0:
            print(f"[{name}] (no samples)")
            return

        print(f"\n[{name}] n={self.n}")
        for k in sorted(self.sums.keys()):
            mean = self.sums[k] / self.n
            print(
                f"  {k:8s}  mean={mean: .4f}   min={self.mins[k]: .4f}   max={self.maxs[k]: .4f}"
            )

# %%
def build_reverse_adj_weighted(network: TrafficNetwork) -> Dict[Node, List[Tuple[Node, float]]]:
    """Reverse adjacency with weights: for each v, list (u, w(u->v)). w = free-flow time."""
    rev = defaultdict(list)
    for (u, v), edge in network.edges.items():
        rev[v].append((u, float(edge.free_time)))
    return dict(rev)

def shortest_path_to_dest_freeflow(
    dest: Node,
    rev_adj_w: Dict[Node, List[Tuple[Node, float]]],
) -> Dict[Node, float]:
    """Dijkstra on reverse graph: gives min free-flow time from node -> dest."""
    dist = {dest: 0.0}
    pq = [(0.0, dest)]
    while pq:
        dv, v = heapq.heappop(pq)
        if dv != dist.get(v, float("inf")):
            continue
        for u, w in rev_adj_w.get(v, []):
            nd = dv + w
            if nd < dist.get(u, float("inf")):
                dist[u] = nd
                heapq.heappush(pq, (nd, u))
    return dist

# %%
# ============================================================
# Global RL / COIN constants
# ============================================================

# ===== RL / reward-shaping constants =====
TIME_SCALE   = 1000.0

# Difference–reward weight (already used)
LAMBDA_DR    = 0.3

# Optional shaping
LAMBDA_PROG  = 0.1      # progress towards destination
LAMBDA_TERM  = 10.0     # bonus if you reach destination
LAMBDA_EXP   = 0.1      # expert edge bonus

# NEW: extra shaping for path length
LAMBDA_STEP  = 0.01     # per-step cost (discourages very long routes)
LAMBDA_MISS  = 50.0     # penalty if you hit max_steps without reaching dest

# %%
# ============================================================
# Helper classes for improved Q-learning
# ============================================================

class RunningStats:
    """
    Online mean / std tracker (Welford's algorithm).

    Used to normalise reward components (delta_G, time penalty) so that
    each component has consistent magnitude regardless of network scale,
    preventing any single term from dominating the Q-updates.
    """
    def __init__(self, eps: float = 1e-8):
        self.n    = 0
        self.mean = 0.0
        self.M2   = 0.0
        self.eps  = eps

    def update(self, x: float) -> None:
        self.n += 1
        delta   = x - self.mean
        self.mean += delta / self.n
        self.M2   += delta * (x - self.mean)

    @property
    def std(self) -> float:
        return math.sqrt(self.M2 / max(self.n - 1, 1)) + self.eps

    def normalize(self, x: float) -> float:
        """Return z-score of x given observed distribution so far."""
        return (x - self.mean) / self.std


class ReplayBuffer:
    """
    Fixed-capacity circular replay buffer for off-policy Q-learning.

    Stores (s, d, a, reward, s_next, done) transitions.
    Sampling a random mini-batch breaks temporal correlations and lets
    the agent reuse past experience more efficiently.
    """
    def __init__(self, capacity: int = 10_000):
        from collections import deque
        self._buf: deque = deque(maxlen=capacity)

    def push(self, s, d, a, reward: float, s_next, done: bool) -> None:
        self._buf.append((s, d, a, float(reward), s_next, bool(done)))

    def sample(self, batch_size: int):
        return random.sample(self._buf, min(batch_size, len(self._buf)))

    def __len__(self) -> int:
        return len(self._buf)

# %% [markdown]
# ### Q learning from expert (COIN)

# %%
def q_learning_train_true_coin_from_ff_expert(
    network: TrafficNetwork,
    expert_steps,
    flows_expert: EdgeFlows,
    expert_edge_ids: Set[EdgeId],
    # NEW: continuous quality scores per expert edge [0=low, 1=high quality]
    expert_edge_quality: Dict[EdgeId, float] = None,
    num_episodes: int = 20,
    num_agents_per_episode: int = 100,
    od_mode: str = "fixed",
    fixed_od: Optional[Tuple[Node, Node]] = None,
    alpha: float = 0.3,
    gamma: float = 0.95,
    # --- Boltzmann (softmax) exploration – replaces epsilon-greedy ---
    temp_start: float = 1.0,   # high temperature => exploratory at start
    temp_end:   float = 0.1,   # low temperature  => near-greedy at end
    max_steps_per_agent: int = 1500,
    # TRUE COIN + shaping weights
    lambda_dr:   float = LAMBDA_DR,
    lambda_prog: float = LAMBDA_PROG,
    lambda_term: float = LAMBDA_TERM,
    lambda_exp:  float = LAMBDA_EXP,
    lambda_step: float = LAMBDA_STEP,
    lambda_miss: float = LAMBDA_MISS,
    time_scale:  float = TIME_SCALE,
    horizon_s:   float = 3600.0,
    debug_rewards: bool = True,
    visited_penalty_train: float = 0.0,
    # Training-time time penalty (BPR) – kept in raw units (not z-scored)
    lambda_time_train: float = 1.0,
    time_scale_s:      float = 1000.0,
    t_cap_s:           float = 3000.0,
    # Soft detour allowance
    tau: float = 0.05,
    # --- Experience replay ---
    replay_capacity: int = 10_000,
    replay_batch:    int = 64,
    replay_min:      int = 256,   # buffer must be this large before replaying
    # --- Congestion-aware SP: refresh every K episodes (0 = never) ---
    refresh_sp_every: int = 1,
    # --- Expert dataset refresh: re-run FF every K episodes (0 = disabled) ---
    refresh_expert_every:        int = 0,
    num_agents_expert_refresh:   int = 100,
) -> Dict[Tuple[Node, Node, Node], float]:
    """
    TRUE COIN Q-learning with difference rewards + expert shaping.

    Improvements over the base version:
      1. Quality-weighted expert bonus  – continuous [0,1] score replaces binary flag.
      2. Adaptive delta_G clipping      – RunningStats tracks the distribution; clips at
                                          mean + 3*std instead of a hard constant cap.
                                          DR is still always <= 0 (correct sign).
      3. Congestion-aware progress SP   – shortest-path distances recomputed with live BPR
                                          times every `refresh_sp_every` episodes.
      4. Boltzmann exploration          – temperature-annealed softmax replaces epsilon-greedy,
                                          consistent with the evaluation policy.
      5. Experience replay              – random mini-batch updates after each episode break
                                          temporal correlation and reuse past transitions.
      6. Expert dataset refresh         – every `refresh_expert_every` episodes the FF expert
                                          is re-run so its distribution stays close to the
                                          current congestion regime.

    NOTE on reward signs:
      delta_G >= 0 always  =>  dr = -lambda_dr * (delta_G / time_scale)  <= 0  always.
      t_edge  >= 0 always  =>  time_pen = -lambda_time_train * (t_edge / time_scale_s) <= 0.
      Keeping both penalties strictly non-positive prevents the agent from being rewarded
      for staying in uncongested/fast areas near the origin.
    """
    import heapq
    from collections import defaultdict, deque

    Q: Dict[Tuple[Node, Node, Node], float] = {}

    # Fall back to uniform quality (=1.0) if not provided
    _quality = expert_edge_quality if expert_edge_quality is not None else {}

    # ----------------------------------------------------------------
    # Build reverse adjacency for reachability + SP caches
    # ----------------------------------------------------------------
    rev_adj: Dict[Node, List[Node]] = defaultdict(list)
    rev_adj_w: Dict[Node, List[Tuple[Node, float]]] = defaultdict(list)

    for (u, v), edge in network.edges.items():
        rev_adj[v].append(u)
        rev_adj_w[v].append((u, float(edge.free_time)))

    reachable_cache: Dict[Node, Set[Node]] = {}
    sp_cache:        Dict[Node, Dict[Node, float]] = {}

    scale_to_vph = 3600.0 / float(horizon_s)

    def reachable_set(dest: Node) -> Set[Node]:
        rs = reachable_cache.get(dest)
        if rs is not None:
            return rs
        seen: Set[Node] = {dest}
        q = deque([dest])
        while q:
            v = q.popleft()
            for u in rev_adj.get(v, []):
                if u not in seen:
                    seen.add(u)
                    q.append(u)
        reachable_cache[dest] = seen
        return seen

    def sp_dist_map(dest: Node, edge_counts: EdgeFlows = None) -> Dict[Node, float]:
        """
        Backward Dijkstra from dest.
        If edge_counts provided: uses live BPR times (congestion-aware).
        Without edge_counts:     uses free-flow times (cached per dest).
        """
        if edge_counts is None:
            m = sp_cache.get(dest)
            if m is not None:
                return m

        dist: Dict[Node, float] = {dest: 0.0}
        pq = [(0.0, dest)]
        while pq:
            dv, v = heapq.heappop(pq)
            if dv > dist.get(v, float("inf")):
                continue
            for u, w_ff in rev_adj_w.get(v, []):
                if edge_counts is not None:
                    edge = network.edges.get((u, v))
                    w = float(edge.travel_time(edge_counts.get((u, v), 0.0) * scale_to_vph)) if edge else w_ff
                else:
                    w = w_ff
                nd = dv + w
                if nd < dist.get(u, float("inf")):
                    dist[u] = nd
                    heapq.heappush(pq, (nd, u))

        if edge_counts is None:
            sp_cache[dest] = dist
        return dist

    def progress_sp(sp: Dict[Node, float], s: Node, a: Node) -> float:
        old_d = sp.get(s, float("inf"))
        new_d = sp.get(a, float("inf"))
        if not np.isfinite(old_d) or old_d <= 0.0:
            return 0.0
        return max(0.0, (old_d - new_d) / max(old_d, 1.0))

    def filter_neighbors_reach_tau(
        sp: Dict[Node, float], s: Node, neighbors: List[Node]
    ) -> List[Node]:
        old_d = sp.get(s, float("inf"))
        if not np.isfinite(old_d) or old_d <= 0.0:
            return neighbors
        filtered = [
            nxt for nxt in neighbors
            if (old_d - sp.get(nxt, float("inf"))) / max(old_d, 1.0) >= -tau
        ]
        return filtered if filtered else neighbors

    def sample_agents_for_mode(n: int) -> List[Agent]:
        if od_mode == "random":
            return sample_agents_random(network, n)
        elif od_mode in ("north_south", "north-south"):
            return sample_agents_north_south(network, n)
        else:
            if fixed_od is None:
                raise ValueError("fixed_od=(origin, destination) is required when od_mode='fixed'")
            return sample_agents_fixed(network, n, fixed_od[0], fixed_od[1])

    # ----------------------------------------------------------------
    # RunningStats: track delta_G distribution for adaptive clipping.
    # We do NOT z-score (which would flip sign and reward uncongested edges).
    # Instead we clip at mean + 3*std to suppress outliers.
    # ----------------------------------------------------------------
    dG_stats = RunningStats()

    # Warm-up from expert flows so clipping threshold is ready from episode 1
    for (_, _, _, edge_id) in expert_steps:
        edge = network.edges[edge_id]
        c_before = max(flows_expert.get(edge_id, 0.0) - 1.0, 0.0)
        dG_stats.update(edge_marginal_global_cost(edge, c_before, horizon_s))

    def clip_delta_G(delta_G: float) -> float:
        """Clip delta_G at mean + 3*std (adaptive); fallback to 1e6."""
        ceiling = dG_stats.mean + 3.0 * dG_stats.std if dG_stats.n >= 2 else 1e6
        return min(max(delta_G, 0.0), ceiling)

    # ----------------------------------------------------------------
    # Experience replay buffer
    # ----------------------------------------------------------------
    replay = ReplayBuffer(capacity=replay_capacity)

    # ----------------------------------------------------------------
    # Mutable expert state (refreshed if refresh_expert_every > 0)
    # ----------------------------------------------------------------
    _expert_steps = list(expert_steps)
    _expert_ids   = set(expert_edge_ids)
    _expert_qual  = dict(_quality)

    # ----------------------------------------------------------------
    # Phase 0: offline initialisation from FF expert transitions
    # ----------------------------------------------------------------
    print("Initialising TRUE-COIN Q from Ford-Fulkerson expert trajectories...")

    for (s, d, a, edge_id) in _expert_steps:
        edge     = network.edges[edge_id]
        c_before = max(flows_expert.get(edge_id, 0.0) - 1.0, 0.0)
        delta_G  = edge_marginal_global_cost(edge, c_before, horizon_s)
        dG_stats.update(delta_G)

        # DR: always <= 0 (divide by time_scale, no z-score)
        dr = -lambda_dr * (clip_delta_G(delta_G) / time_scale)

        sp   = sp_dist_map(d)
        prog = progress_sp(sp, s, a)

        # Quality-weighted expert bonus (continuous [0,1])
        exp_bon = lambda_exp * _expert_qual.get(edge_id, 1.0) if edge_id in _expert_ids else 0.0

        reward = dr + lambda_prog * prog + exp_bon - lambda_step
        if a == d:
            reward += lambda_term

        key   = (s, d, a)
        old_q = Q.get(key, 0.0)
        Q[key] = old_q + alpha * (reward - old_q)

    print(
        f"TRUE-COIN Q initialised on {len(_expert_steps)} expert steps "
        f"({len(Q)} unique state-action pairs). "
        f"delta_G stats: mean={dG_stats.mean:.1f} std={dG_stats.std:.1f}"
    )

    # ----------------------------------------------------------------
    # Phase 1: online TRUE COIN Q-learning
    # ----------------------------------------------------------------
    for ep in range(num_episodes):
        # Boltzmann temperature schedule (linear anneal)
        temp = temp_start + (temp_end - temp_start) * ep / max(num_episodes - 1, 1)

        # Expert dataset refresh
        if refresh_expert_every > 0 and ep > 0 and ep % refresh_expert_every == 0:
            print(f"  [Expert refresh] Episode {ep+1}: re-running FF expert...")
            new_steps, _, new_flows, new_quality = build_ff_expert_dataset(
                network,
                num_agents=num_agents_expert_refresh,
                od_mode=od_mode,
                horizon_s=horizon_s,
            )
            _expert_steps = new_steps
            _expert_ids   = {eid for (_, _, _, eid) in new_steps}
            _expert_qual  = new_quality

        edge_counts: EdgeFlows = defaultdict(float)

        # Congestion-aware SP: compute once per episode using PREVIOUS episode's
        # accumulated counts would require storing them – instead we build it fresh
        # per-destination, lazily, using the current (empty-at-start) edge_counts.
        # Agents early in the episode get free-flow SP; late agents get congested SP.
        ep_sp_cache: Dict[Node, Dict[Node, float]] = {}

        def get_ep_sp(dest: Node) -> Dict[Node, float]:
            if dest not in ep_sp_cache:
                if refresh_sp_every > 0 and ep % refresh_sp_every == 0:
                    ep_sp_cache[dest] = sp_dist_map(dest, edge_counts)
                else:
                    ep_sp_cache[dest] = sp_dist_map(dest)
            return ep_sp_cache[dest]

        agents = sample_agents_for_mode(num_agents_per_episode)

        total_reward = 0.0
        total_steps  = 0
        dbg = RewardDebug(enabled=debug_rewards)
        deltaG_samples = []

        for agent in agents:
            s = agent.origin
            d = agent.destination
            visited: Set[Node] = set()
            steps = 0

            rs = reachable_set(d)
            # Invalidate ep_sp cache per agent so congestion is up-to-date
            ep_sp_cache.pop(d, None)
            sp = get_ep_sp(d)

            while s != d and steps < max_steps_per_agent:
                neighbors = [nxt for nxt in get_neighbors(network, s) if nxt in rs]
                if not neighbors:
                    break
                neighbors = filter_neighbors_reach_tau(sp, s, neighbors)
                if not neighbors:
                    break

                visited.add(s)

                # Boltzmann action selection
                q_vals = [Q.get((s, d, nxt), 0.0) for nxt in neighbors]
                a = neighbors[softmax_sample(q_vals, temperature=temp)]

                edge_id = (s, a)
                edge    = network.edges.get(edge_id)
                if edge is None:
                    break

                count_before = edge_counts[edge_id]

                # Difference reward: always <= 0 (adaptive clip, raw scale)
                delta_G = edge_marginal_global_cost(edge, count_before, horizon_s)
                deltaG_samples.append(delta_G)
                dG_stats.update(delta_G)
                dr = -lambda_dr * (clip_delta_G(delta_G) / time_scale)

                # Progress toward destination (uses SP computed at start of agent route)
                prog = progress_sp(sp, s, a)

                # Quality-weighted expert bonus
                exp_bon = lambda_exp * _expert_qual.get(edge_id, 1.0) if edge_id in _expert_ids else 0.0

                # Time penalty: always <= 0 (raw BPR time, capped, divided by scale)
                time_pen = 0.0
                if lambda_time_train != 0.0:
                    flow_vph = count_before * scale_to_vph
                    t_edge   = min(float(edge.travel_time(flow_vph)), float(t_cap_s))
                    time_pen = -lambda_time_train * (t_edge / float(time_scale_s))

                reward = (
                    dr
                    + lambda_prog * prog
                    + exp_bon
                    - lambda_step
                    + time_pen
                )

                if visited_penalty_train != 0.0 and a in visited:
                    reward -= visited_penalty_train

                edge_counts[edge_id] += 1.0
                s_next = a
                steps += 1
                total_steps += 1

                done = (s_next == d) or (steps >= max_steps_per_agent)
                term_bonus   = 0.0
                miss_penalty = 0.0
                if done and s_next != d:
                    reward     -= lambda_miss
                    miss_penalty = -lambda_miss
                elif s_next == d:
                    reward    += lambda_term
                    term_bonus = lambda_term

                # Online Q-update (reuse SP computed at start of agent route)
                sp_next = sp
                if done:
                    target = reward
                else:
                    nn = [n for n in get_neighbors(network, s_next) if n in rs]
                    nn = filter_neighbors_reach_tau(sp_next, s_next, nn)
                    target = reward + gamma * (max(Q.get((s_next, d, n), 0.0) for n in nn) if nn else 0.0)

                key   = (s, d, a)
                old_q = Q.get(key, 0.0)
                Q[key] = old_q + alpha * (target - old_q)

                replay.push(s, d, a, reward, s_next, done)

                dbg.add(
                    total=reward, dr=dr, prog=lambda_prog * prog,
                    exp=exp_bon, step=-lambda_step, time=time_pen,
                    term=term_bonus, miss=miss_penalty, delta_G=delta_G,
                )
                total_reward += reward
                s = s_next

        # Experience replay mini-batch updates
        if len(replay) >= replay_min:
            batch = replay.sample(replay_batch)
            for (rb_s, rb_d, rb_a, rb_r, rb_sn, rb_done) in batch:
                rb_rs = reachable_set(rb_d)
                rb_sp = sp_dist_map(rb_d)   # free-flow for stable replay targets
                if rb_done:
                    rb_target = rb_r
                else:
                    rb_nn = [n for n in get_neighbors(network, rb_sn) if n in rb_rs]
                    rb_nn = filter_neighbors_reach_tau(rb_sp, rb_sn, rb_nn)
                    rb_target = rb_r + gamma * (max(Q.get((rb_sn, rb_d, n), 0.0) for n in rb_nn) if rb_nn else 0.0)
                rb_key = (rb_s, rb_d, rb_a)
                Q[rb_key] = Q.get(rb_key, 0.0) + alpha * (rb_target - Q.get(rb_key, 0.0))

        avg_r     = total_reward / max(total_steps, 1)
        avg_steps = total_steps  / max(len(agents),  1)
        clip_ceil = dG_stats.mean + 3.0 * dG_stats.std if dG_stats.n >= 2 else 1e6
        print(
            f"[TRUE-COIN+Expert] Ep {ep+1}/{num_episodes}: "
            f"temp={temp:.3f}, avg_r/step={avg_r:.4f}, avg_steps={avg_steps:.1f}, "
            f"replay={len(replay)}, dG_clip={clip_ceil:.1f}"
        )

        if debug_rewards:
            dbg.summary(name=f"Episode {ep+1} reward breakdown")
            if deltaG_samples:
                arr = np.array(deltaG_samples, dtype=float)
                print(
                    f"[delta_G] p50={np.percentile(arr,50):.1f} "
                    f"p90={np.percentile(arr,90):.1f} "
                    f"p99={np.percentile(arr,99):.1f} "
                    f"clip_ceiling={clip_ceil:.1f}"
                )

    print(f"Finished TRUE-COIN+Expert Q-learning: {len(Q)} state-action entries.")
    return Q

# %% [markdown]
# ##  Routing with softmax policy

# %% [markdown]
# ### Softmax Helper

# %%
def softmax_sample(values: List[float], temperature: float = 1.0) -> int:
    """
    Sample an index according to softmax(values / temperature).

    If temperature <= 0, falls back to argmax.
    Returns the chosen index.
    """
    if not values:
        raise ValueError("softmax_sample called with empty list")

    if temperature <= 0:
        # deterministic argmax
        max_val = max(values)
        candidates = [i for i, v in enumerate(values) if v == max_val]
        return random.choice(candidates)

    # numerically stable softmax
    scaled = [v / temperature for v in values]
    m = max(scaled)
    exps = [math.exp(v - m) for v in scaled]
    Z = sum(exps)
    probs = [e / Z for e in exps]

    r = random.random()
    cum = 0.0
    for i, p in enumerate(probs):
        cum += p
        if r <= cum:
            return i

    # numerical residue
    return len(values) - 1

# %% [markdown]
# ### Routing Helpers

# %%
from collections import deque


def build_reverse_adj(network: TrafficNetwork) -> Dict[Node, List[Node]]:
    """Build reverse adjacency once: rev[v] = list of predecessors u with edge u->v."""
    rev_adj: Dict[Node, List[Node]] = defaultdict(list)
    for (u, v) in network.edges.keys():
        rev_adj[v].append(u)
    return dict(rev_adj)


def nodes_that_can_reach_dest_from_rev(rev_adj: Dict[Node, List[Node]], dest: Node) -> Set[Node]:
    """Reverse-graph BFS/DFS: set of nodes from which dest is reachable."""
    reachable = {dest}
    q = deque([dest])

    while q:
        x = q.popleft()
        for prev in rev_adj.get(x, []):
            if prev not in reachable:
                reachable.add(prev)
                q.append(prev)

    return reachable


def nodes_that_can_reach_dest(network: TrafficNetwork, dest: Node) -> Set[Node]:
    """Compatibility wrapper."""
    return nodes_that_can_reach_dest_from_rev(build_reverse_adj(network), dest)

# %% [markdown]
# ### Route with trained Q flow and adaptive softmax

# %%
def route_with_trained_Q_flow_adaptive_softmax(
    network: TrafficNetwork,
    Q: Dict[Tuple[Node, Node, Node], float],
    num_agents: int = 200,
    od_mode: str = "fixed",
    max_steps_per_agent: int = 1500,
    lambda_live_cost: float = 5.0,
    epsilon_eval: float = 0.0,
    temperature: float = 0.7,
    time_scale: float = TIME_SCALE,
    horizon_s: float = 3600.0,
    visited_penalty_val: float = 3.0,
    fixed_od: Optional[Tuple[Node, Node]] = None,
) -> Tuple[List[Agent], EdgeFlows, float]:
    """
    Evaluate a trained Q-table by routing agents with a softmax policy
    aware of live congestion.

    Utility for each candidate action:
        utility(a) = Q(s,d,a) - lambda_live_cost * congestion_penalty(a) - visited_pen

    Before softmax, utilities are range-normalised to [0, 1] so that
    `temperature` has a consistent interpretation regardless of Q-value
    magnitude. This prevents high Q-values from overpowering the live
    congestion signal when many agents are present.

    Congestion penalty = (t_live - t_free) / t_free (fractional delay above free-flow).
    """
    edge_flows: EdgeFlows = defaultdict(float)

    if od_mode == "random":
        agents = sample_agents_random(network, num_agents)
    elif od_mode in ("north_south", "north-south"):
        agents = sample_agents_north_south(network, num_agents)
    else:
        if fixed_od is None:
            raise ValueError("fixed_od=(origin, destination) is required when od_mode='fixed'")
        agents = sample_agents_fixed(network, num_agents, fixed_od[0], fixed_od[1])

    scale_to_vph = 3600.0 / horizon_s
    rev_adj = build_reverse_adj(network)

    reachable_cache: Dict[Node, Set[Node]] = {}

    def reachable_to_dest(d: Node) -> Set[Node]:
        if d not in reachable_cache:
            reachable_cache[d] = nodes_that_can_reach_dest_from_rev(rev_adj, d)
        return reachable_cache[d]

    for agent in agents:
        s = agent.origin
        d = agent.destination
        path = [s]
        steps = 0
        visited: set[Node] = set()
        travel_s = 0.0

        reach_set = reachable_to_dest(d)
        if s not in reach_set:
            agent.path = path
            agent.experienced_time_s = 0.0
            continue

        while s != d and steps < max_steps_per_agent:
            neighbors = [nxt for nxt in get_neighbors(network, s) if nxt in reach_set]
            if not neighbors:
                break

            visited.add(s)

            if epsilon_eval > 0.0 and random.random() < epsilon_eval:
                a = random.choice(neighbors)
            else:
                utilities: List[float] = []
                candidate_actions: List[Node] = []

                for nxt in neighbors:
                    edge_id = (s, nxt)
                    edge = network.edges.get(edge_id)
                    if edge is None:
                        continue

                    count_live = edge_flows.get(edge_id, 0.0)
                    flow_live_vph = count_live * scale_to_vph

                    t_free = float(edge.free_time)
                    t_live = float(edge.travel_time(flow_live_vph))
                    congestion_frac = (t_live - t_free) / max(t_free, 1.0)

                    base_q = Q.get((s, d, nxt), 0.0)
                    vpen = visited_penalty_val if nxt in visited else 0.0

                    utility = base_q - lambda_live_cost * congestion_frac - vpen

                    utilities.append(utility)
                    candidate_actions.append(nxt)

                if not candidate_actions:
                    break

                if len(utilities) > 1:
                    u_min = min(utilities)
                    u_max = max(utilities)
                    u_range = u_max - u_min
                    if u_range > 1e-9:
                        utilities = [(u - u_min) / u_range for u in utilities]

                idx = softmax_sample(utilities, temperature=temperature)
                a = candidate_actions[idx]

            edge_id = (s, a)
            edge = network.edges.get(edge_id)
            if edge is None:
                break

            flow_live_vph = edge_flows.get(edge_id, 0.0) * scale_to_vph
            travel_s += float(edge.travel_time(flow_live_vph))

            edge_flows[edge_id] += 1.0
            s = a
            path.append(s)
            steps += 1

        agent.path = path
        agent.experienced_time_s = travel_s

    G = total_system_travel_time(network, edge_flows, horizon_s=horizon_s)
    return agents, edge_flows, G

# %% [markdown]
# # Experiment Setups

# %% [markdown]
# ## SPA Experiment

# %%
def run_spa_experiment(
    network: TrafficNetwork,
    num_agents: int = 500,
    od_mode: str = "north_south",
    horizon_s: float = 3600.0,
    fixed_od: Optional[Tuple[Node, Node]] = None,
) -> Tuple[List[Agent], EdgeFlows, float]:
    if od_mode == "random":
        agents = sample_agents_random(network, num_agents)
    elif od_mode in ("north_south", "north-south"):
        agents = sample_agents_north_south(network, num_agents)
    elif od_mode == "fixed":
        if fixed_od is None:
            raise ValueError("fixed_od=(origin, destination) is required when od_mode='fixed'")
        agents = sample_agents_fixed(network, num_agents, fixed_od[0], fixed_od[1])
    else:
        raise ValueError(f"Unknown od_mode: {od_mode}")

    agents, edge_counts = spa_route_all(network, agents, horizon_s=horizon_s)
    G = total_system_travel_time(network, edge_counts, horizon_s=horizon_s)

    print(f"SPA experiment with {num_agents} agents ({od_mode} O/D)")
    print(f"Used edges: {len([e for e, c in edge_counts.items() if c > 0])} / {len(network.edges)}")

    return agents, edge_counts, G

# %% [markdown]
# ## FF

# %%
def run_ff_experiment(
    network: TrafficNetwork,
    num_agents: int = 500,
    od_mode: str = "fixed",
    horizon_s: float = 3600.0,
    fixed_od: Optional[Tuple[Node, Node]] = None,
) -> Tuple[List[Agent], EdgeFlows, float]:
    """
    FF-style experiment:
    routes agents with marginal system cost and computes world utility G.
    """
    if od_mode == "random":
        agents = sample_agents_random(network, num_agents)
    elif od_mode in ("north_south", "north-south"):
        agents = sample_agents_north_south(network, num_agents)
    else:  # "fixed"
        if fixed_od is None:
            raise ValueError("fixed_od=(origin, destination) is required when od_mode='fixed'")
        agents = sample_agents_fixed(network, num_agents, fixed_od[0], fixed_od[1])

    agents, edge_counts = ford_fulkerson_route_all(network, agents, horizon_s=horizon_s)
    G = total_system_travel_time(network, edge_counts, horizon_s=horizon_s)

    print(f"FFA experiment with {num_agents} agents ({od_mode} O/D)")
    print(f"Used edges: {len([e for e, c in edge_counts.items() if c > 0])} / {len(network.edges)}")
    return agents, edge_counts, G

# %% [markdown]
# ## Coin Experiment

# %%
def run_ff_expert_coin_rl_experiment(
    network: TrafficNetwork,
    alpha  = 0.3,
    gamma  = 0.95,
    # ---- Boltzmann exploration (training) ----
    temp_start: float = 1.0,
    temp_end:   float = 0.1,
    # ---- evaluation exploration (flow-adaptive) ----
    epsilon_eval: float        = 0.0,
    temperature: float         = 0.7,
    lambda_live_cost: float    = 10.0,
    visited_penalty_val: float = 3.0,
    # ---- reward weights for TRUE COIN + expert ----
    lambda_dr:   float = 1.0,
    lambda_prog: float = 0.05,
    lambda_exp:  float = 0.4,
    lambda_step: float = 0.01,
    visited_penalty_train = 1.0,
    lambda_time_train: float = 1.0,
    time_scale_s: float      = 1000.0,
    t_cap_s: float           = 3000.0,
    tau: float               = 0.05,
    time_scale: float = TIME_SCALE,
    # ---- end-point reward ----
    lambda_term: float = 5.0,
    lambda_miss: float = 50.0,
    # ---- populations ----
    num_agents_baseline: int = 100,
    num_agents_expert:   int = 200,
    num_agents_eval_rl:  int = 100,
    od_mode: str             = "fixed",
    fixed_od: Optional[Tuple[Node, Node]] = None,
    num_episodes_rl: int     = 20,
    steps_per_agent: int     = 1500,
    horizon_s: float         = 3600.0,
    # ---- experience replay ----
    replay_capacity: int = 10_000,
    replay_batch:    int = 64,
    replay_min:      int = 256,
    # ---- congestion-aware SP refresh ----
    refresh_sp_every: int = 1,
    # ---- expert dataset refresh ----
    refresh_expert_every:      int = 0,
    num_agents_expert_refresh: int = 100,
    debug = True,
) -> Tuple[
    List[Agent], EdgeFlows, float,
    List[Agent], EdgeFlows, float,
    List[Agent], EdgeFlows, float,
    Dict[Tuple[Node, Node, Node], float],
]:
    """
    1) SPA baseline
    2) Ford-Fulkerson (FF) baseline
    3) Build FF expert dataset (with quality scores)
    4) Train TRUE COIN Q-learning with FF expert shaping
    5) Evaluate FF-RL with flow-adaptive Q + softmax policy
    """

    # --- 1) SPA baseline ---
    agents_spa, flows_spa, G_spa = run_spa_experiment(
        network, num_agents=num_agents_baseline, od_mode=od_mode, horizon_s=horizon_s, fixed_od=fixed_od,
    )

    # --- 2) FF baseline ---
    agents_ff, flows_ff, G_ff = run_ff_experiment(
        network, num_agents=num_agents_baseline, od_mode=od_mode, horizon_s=horizon_s, fixed_od=fixed_od,
    )

    # --- 3) FF expert dataset (now returns quality scores) ---
    expert_steps, ff_agents_expert, ff_flows_expert, expert_edge_quality = build_ff_expert_dataset(
        network, num_agents=num_agents_expert, od_mode=od_mode, horizon_s=horizon_s, fixed_od=fixed_od,
    )

    expert_edge_ids: Set[EdgeId] = {edge_id for (_, _, _, edge_id) in expert_steps}
    print(f"[FF expert] {len(expert_edge_ids)} distinct expert edges.")

    # --- 4) TRUE COIN Q-learning ---
    Q_ff_rl = q_learning_train_true_coin_from_ff_expert(
        network=network,
        expert_steps=expert_steps,
        flows_expert=ff_flows_expert,
        expert_edge_ids=expert_edge_ids,
        expert_edge_quality=expert_edge_quality,
        num_episodes=num_episodes_rl,
        num_agents_per_episode=num_agents_expert,
        od_mode=od_mode,
        fixed_od=fixed_od,
        alpha=alpha,
        gamma=gamma,
        temp_start=temp_start,
        temp_end=temp_end,
        max_steps_per_agent=steps_per_agent,
        lambda_dr=lambda_dr,
        lambda_prog=lambda_prog,
        lambda_term=lambda_term,
        lambda_exp=lambda_exp,
        lambda_step=lambda_step,
        lambda_miss=lambda_miss,
        time_scale=time_scale,
        horizon_s=horizon_s,
        visited_penalty_train=visited_penalty_train,
        debug_rewards=debug,
        lambda_time_train=lambda_time_train,
        time_scale_s=time_scale_s,
        t_cap_s=t_cap_s,
        tau=tau,
        replay_capacity=replay_capacity,
        replay_batch=replay_batch,
        replay_min=replay_min,
        refresh_sp_every=refresh_sp_every,
        refresh_expert_every=refresh_expert_every,
        num_agents_expert_refresh=num_agents_expert_refresh,
    )

    # --- 5) Evaluate with flow-adaptive Q + softmax ---
    agents_ff_rl, flows_ff_rl, G_ff_rl = route_with_trained_Q_flow_adaptive_softmax(
        network=network,
        Q=Q_ff_rl,
        num_agents=num_agents_eval_rl,
        od_mode=od_mode,
        fixed_od=fixed_od,
        max_steps_per_agent=steps_per_agent,
        lambda_live_cost=lambda_live_cost,
        epsilon_eval=epsilon_eval,
        temperature=temperature,
        time_scale=time_scale,
        horizon_s=horizon_s,
        visited_penalty_val=visited_penalty_val,
    )

    return (
        agents_spa,   flows_spa,   G_spa,
        agents_ff,    flows_ff,    G_ff,
        agents_ff_rl, flows_ff_rl, G_ff_rl,
        Q_ff_rl,
    )

# %% [markdown]
# # Metrics & visualization helpers

# %% [markdown]
# ## Metrics

# %%
def fraction_reached_agentspecific(agents: List[Agent]) -> float:
    reached = sum(1 for a in agents if a.path and a.path[-1] == a.destination)
    return reached / max(len(agents), 1)


def compute_agent_travel_times(
    network: TrafficNetwork,
    edge_flows: EdgeFlows,   # COUNTS
    agents: List[Agent],
    horizon_s: float = 3600.0,
) -> List[float]:
    """
    Returns per-agent travel times in seconds.

    Prefers `agent.experienced_time_s` recorded during routing. Falls back to a
    post-hoc estimate using final aggregate flows when experienced times are not present.
    """
    times = []
    scale_to_vph = 3600.0 / horizon_s

    for agent in agents:
        if agent.experienced_time_s is not None:
            times.append(float(agent.experienced_time_s))
            continue

        if not agent.path or len(agent.path) < 2:
            times.append(0.0)
            continue

        total = 0.0
        for u, v in edges_from_path(agent.path):
            edge = network.edges[(u, v)]
            count = edge_flows.get((u, v), 0.0)
            flow_vph = count * scale_to_vph
            total += edge.travel_time(flow_vph)

        times.append(total)

    return times


def routes_to_gdf(agents: List[Agent], crs) -> gpd.GeoDataFrame:
    geoms = []
    for agent in agents:
        if agent.path is not None and len(agent.path) > 1:
            geoms.append(LineString(agent.path))
    return gpd.GeoDataFrame(geometry=geoms, crs=crs)


def edge_flows_to_gdf(edge_flows, network, crs, horizon_s: float = 3600.0):
    geoms, flows_vph = [], []
    scale_to_vph = 3600.0 / horizon_s
    for (u, v), c in edge_flows.items():
        if c <= 0:
            continue
        geoms.append(LineString([u, v]))
        flows_vph.append(c * scale_to_vph)
    return gpd.GeoDataFrame({"flow_vph": flows_vph}, geometry=geoms, crs=crs)

def total_distance_from_flows(network: TrafficNetwork, flows: EdgeFlows) -> float:
    """
    Total distance traveled in the network (sum over all agents),
    computed from edge flows.

    Returns
    -------
    distance_m : float
        Total distance in meters.
    """
    dist_m = 0.0
    for edge_id, f in flows.items():
        if f <= 0.0:
            continue
        edge = network.edges[edge_id]
        dist_m += edge.length_m * f
    return dist_m


def print_scenario_metrics(
        name: str,
        network: TrafficNetwork,
        flows: EdgeFlows,
        G: float,
        num_agents: int) -> None:
    """
    Print average travel time and distance per agent,
    plus total distance for a given scenario.
    """
    # G is total system travel time (seconds)
    avg_time_s = G / num_agents
    avg_time_min = avg_time_s / 60.0

    total_dist_m = total_distance_from_flows(network, flows)
    total_dist_km = total_dist_m / 1000.0
    avg_dist_m = total_dist_m / num_agents
    avg_dist_km = avg_dist_m / 1000.0

    print(f"\n[{name}] metrics:")
    print(f"  Average travel time per agent: {avg_time_s:8.2f} s  ({avg_time_min:6.2f} min)")
    print(f"  Total distance traveled:       {total_dist_km:8.2f} km")
    print(f"  Average distance per agent:    {avg_dist_km:8.2f} km")

# %% [markdown]
# ## Plot Helper

# %%
def plot_routes_three_way(
    gdf: gpd.GeoDataFrame,
    agents_spa: List[Agent],
    G_spa: float,
    agents_coin_ff: List[Agent],
    G_coin_ff: float,
    agents_coin_ff_rl: List[Agent],
    G_coin_ff_rl: float,
    num_agents: int,
    horizon_s: float,
):
    """
    Single figure with three panels:
    [SPA | COIN_FF | COIN_FF_RL]

    Super-title includes:
      - number of agents
      - demand horizon (hours)
    """

    horizon_hr = horizon_s / 3600.0

    # Convert agents' routes to GeoDataFrames
    routes_spa = routes_to_gdf(agents_spa, crs=gdf.crs)
    routes_ff = routes_to_gdf(agents_coin_ff, crs=gdf.crs)
    routes_ff_rl = routes_to_gdf(agents_coin_ff_rl, crs=gdf.crs)

    fig, axes = plt.subplots(1, 3, figsize=(21, 8))

    fig.suptitle(
        f"Routes Comparison — {num_agents} trips over {horizon_hr:.1f} hours",
        fontsize=18,
        y=0.98,
    )

    # SPA
    gdf.plot(ax=axes[0], linewidth=0.3, color="lightgray")
    routes_spa.plot(ax=axes[0], linewidth=1.2, alpha=0.9)
    axes[0].set_title(f"SPA\nG = {G_spa/3600:.1f} veh·hrs", fontsize=14)
    axes[0].set_axis_off()

    # COIN_FF
    gdf.plot(ax=axes[1], linewidth=0.3, color="lightgray")
    routes_ff.plot(ax=axes[1], linewidth=1.2, alpha=0.9)
    axes[1].set_title(f"FF\nG = {G_coin_ff/3600:.1f} veh·hrs", fontsize=14)
    axes[1].set_axis_off()

    # COIN_FF_RL
    gdf.plot(ax=axes[2], linewidth=0.3, color="lightgray")
    routes_ff_rl.plot(ax=axes[2], linewidth=1.2, alpha=0.9)
    axes[2].set_title(
        f"FF-RL (TRUE COIN)\nG = {G_coin_ff_rl/3600:.1f} veh·hrs",
        fontsize=14,
    )
    axes[2].set_axis_off()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Heatmap helper

# %%
def plot_heatmaps_three_way(
    gdf: gpd.GeoDataFrame,
    network: TrafficNetwork,
    flows_spa: EdgeFlows,
    flows_ff: EdgeFlows,
    flows_ff_rl: EdgeFlows,
    num_agents: int,
    horizon_s: float,
):
    """
    Three-panel heatmap:
    [ SPA | FFA | FFA-RL (TRUE COIN) ]

    Colors represent EDGE USAGE COUNTS (not veh/hour).

    Super-title includes:
      - number of agents
      - demand horizon (hours)
    """

    horizon_hr = horizon_s / 3600.0

    def flows_to_gdf_counts(flows: EdgeFlows) -> gpd.GeoDataFrame:
        geoms = []
        counts = []
        for (u, v), c in flows.items():
            if c <= 0:
                continue
            if (u, v) not in network.edges:
                continue
            geoms.append(LineString([u, v]))
            counts.append(float(c))
        return gpd.GeoDataFrame({"count": counts}, geometry=geoms, crs=gdf.crs)

    spa_gdf = flows_to_gdf_counts(flows_spa)
    ff_gdf  = flows_to_gdf_counts(flows_ff)
    rl_gdf  = flows_to_gdf_counts(flows_ff_rl)

    if spa_gdf.empty or ff_gdf.empty or rl_gdf.empty:
        print("One of the GeoDataFrames is empty – nothing to plot.")
        return

    vmax = max(
        spa_gdf["count"].max(),
        ff_gdf["count"].max(),
        rl_gdf["count"].max(),
    )

    fig, axes = plt.subplots(1, 3, figsize=(22, 8))

    fig.suptitle(
        f"Edge Usage Heatmaps — {num_agents} trips over {horizon_hr:.1f} hours",
        fontsize=16,
        y=1.02
    )

    cmap = "turbo"

    # SPA
    gdf.plot(ax=axes[0], linewidth=0.2, color="lightgray")
    spa_gdf.plot(
        ax=axes[0],
        column="count",
        linewidth=1.5,
        alpha=0.9,
        cmap=cmap,
        vmin=0,
        vmax=vmax,
        legend=True,
    )
    axes[0].set_title("SPA Edge Counts")
    axes[0].set_axis_off()

    # FF
    gdf.plot(ax=axes[1], linewidth=0.2, color="lightgray")
    ff_gdf.plot(
        ax=axes[1],
        column="count",
        linewidth=1.5,
        alpha=0.9,
        cmap=cmap,
        vmin=0,
        vmax=vmax,
        legend=True,
    )
    axes[1].set_title("FF Edge Counts")
    axes[1].set_axis_off()

    # FF-RL
    gdf.plot(ax=axes[2], linewidth=0.2, color="lightgray")
    rl_gdf.plot(
        ax=axes[2],
        column="count",
        linewidth=1.5,
        alpha=0.9,
        cmap=cmap,
        vmin=0,
        vmax=vmax,
        legend=True,
    )
    axes[2].set_title("FF-RL Edge Counts")
    axes[2].set_axis_off()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Run Single Experiment

# %%
random.seed(26)
np.random.seed(26)

num_agents        = 10000     # change to 1000 / 10000 for large-scale runs
num_agents_expert = max(num_agents // 3, 33)
horizon_s         = 3600.0
od_mode           = "fixed"
fixed_od          = (origin, destination) if od_mode == "fixed" else None

(
    agents_spa, flows_spa, G_spa,
    agents_ff,  flows_ff,  G_ff,
    agents_ff_rl, flows_ff_rl, G_ff_rl,
    Q_ff_rl,
) = run_ff_expert_coin_rl_experiment(
    manhattan_network,

    # learning
    alpha = 0.12,
    gamma = 0.97,

    # Boltzmann exploration (replaces epsilon-greedy)
    temp_start = 2.0,
    temp_end   = 0.05,

    # --- evaluation policy ---
    # temperature: controls route diversity during evaluation.
    #   - Near 0  => all agents take the exact same (argmax) route => bad for large N.
    #   - 0.3-0.7 => good spread for 100-1000 agents.
    #   - 1.0+    => more diversity for 10 000+ agents.
    # With utility range-normalisation, temperature is now scale-independent.
    epsilon_eval        = 0.0,
    temperature         = 1,      # raise for large agent counts (e.g. 1.0 for 10k agents)
    # lambda_live_cost: fractional congestion penalty weight.
    # Value of 5 means an edge at 5x free-flow time loses all utility vs an uncongested edge.
    lambda_live_cost    = 30.0,      # raise for large agent counts (e.g. 20-50 for 10k)
    visited_penalty_val = 25.0,

    # training-time behaviour shaping
    tau                   = 0.03,
    visited_penalty_train = 0.02,

    # training-time time penalty
    lambda_time_train = 1.0,
    time_scale_s      = 400.0,
    t_cap_s           = 1200.0,

    # TRUE COIN + expert
    lambda_dr   = 10.0,
    lambda_prog = 20.0,
    lambda_exp  = 0.30,
    lambda_step = 0.0,

    # delta_G scaling
    time_scale = 500.0,

    # terminal shaping
    lambda_term = 2500.0,
    lambda_miss = 500.0,

    # experience replay
    replay_capacity = 10_000,
    replay_batch    = 64,
    replay_min      = 256,

    # congestion-aware SP
    refresh_sp_every = 1,

    # expert refresh (disabled by default)
    refresh_expert_every      = 0,
    num_agents_expert_refresh = num_agents_expert,

    # populations
    num_agents_baseline = num_agents,
    num_agents_expert   = num_agents_expert,
    num_agents_eval_rl  = num_agents,
    od_mode             = od_mode,
    fixed_od            = fixed_od,

    num_episodes_rl = 20,
    steps_per_agent = 1000,
    horizon_s       = horizon_s,

    debug = True,
)

results = {
    "SPA":                       (agents_spa,   flows_spa,   G_spa),
    "FF":                        (agents_ff,    flows_ff,    G_ff),
    "FF-RL (TRUE COIN + expert)": (agents_ff_rl, flows_ff_rl, G_ff_rl),
}
# Out:
# SPA experiment with 10000 agents (fixed O/D)
# Used edges: 1040 / 16444
# FFA experiment with 10000 agents (fixed O/D)
# Used edges: 9946 / 16444
# Collected 665657 FF-expert (s,d,a,edge_id) steps from 3333 agents.
# Expert quality scores: 9766 edges, range [0.000, 1.000].
# [FF expert] 9766 distinct expert edges.
# Initialising TRUE-COIN Q from Ford-Fulkerson expert trajectories...
# TRUE-COIN Q initialised on 665657 expert steps (9766 unique state-action pairs). delta_G stats: mean=15.5 std=22.6
# [TRUE-COIN+Expert] Ep 1/20: temp=2.000, avg_r/step=2.2348, avg_steps=588.9, replay=10000, dG_clip=78.8
#
# [Episode 1 reward breakdown] n=1962843
#   delta_G   mean= 10.5801   min= 0.1606   max= 731.3414
#   dr        mean=-0.1895   min=-1.6658   max=-0.0032
#   exp       mean= 0.2059   min= 0.0000   max= 0.3000
#   miss      mean=-0.3625   min=-500.0000   max= 0.0000
#   prog      mean= 0.1872   min= 0.0000   max= 20.0000
#   step      mean= 0.0000   min=-0.0000   max=-0.0000
#   term      mean= 2.4327   min= 0.0000   max= 2500.0000
#   time      mean=-0.0239   min=-0.6723   max=-0.0004
#   total     mean= 2.2348   min=-500.9522   max= 2520.1573
# [delta_G] p50=6.0 p90=21.9 p99=66.7 clip_ceiling=78.8
# [TRUE-COIN+Expert] Ep 2/20: temp=1.897, avg_r/step=21.8572, avg_steps=119.3, replay=10000, dG_clip=148.3
#
# [Episode 2 reward breakdown] n=397570
#   delta_G   mean= 30.7333   min= 0.2234   max= 2520.3786
#   dr        mean=-0.3381   min=-2.9661   max=-0.0045
#   exp       mean= 0.2765   min= 0.0000   max= 0.2999
#   miss      mean=-0.0013   min=-500.0000   max= 0.0000
#   prog      mean= 1.0152   min= 0.0000   max= 20.0000
#   step      mean= 0.0000   min=-0.0000   max=-0.0000
#   term      mean= 20.9523   min= 0.0000   max= 2500.0000
#   time      mean=-0.0473   min=-1.2949   max=-0.0006
#   total     mean= 21.8572   min=-500.7621   max= 2520.1573
# [delta_G] p50=6.9 p90=49.1 p99=352.3 clip_ceiling=148.3
# [TRUE-COIN+Expert] Ep 3/20: temp=1.795, avg_r/step=22.4215, avg_steps=116.0, replay=10000, dG_clip=185.8
#
# [Episode 3 reward breakdown] n=386628
#   delta_G   mean= 31.3795   min= 0.2234   max= 2520.3786
#   dr        mean=-0.4007   min=-3.7168   max=-0.0045
#   exp       mean= 0.2764   min= 0.0000   max= 0.2999
#   miss      mean= 0.0000   min= 0.0000   max= 0.0000
#   prog      mean= 1.0424   min= 0.0000   max= 20.0000
#   step      mean= 0.0000   min=-0.0000   max=-0.0000
#   term      mean= 21.5517   min= 0.0000   max= 2500.0000
#   time      mean=-0.0483   min=-1.2949   max=-0.0006
#   total     mean= 22.4215   min=-4.5142   max= 2520.1573
# [delta_G] p50=7.0 p90=49.5 p99=359.6 clip_ceiling=185.8
# [TRUE-COIN+Expert] Ep 4/20: temp=1.692, avg_r/step=22.3917, avg_steps=116.0, replay=10000, dG_clip=211.8
#
# [Episode 4 reward breakdown] n=386628
#   delta_G   mean= 31.3795   min= 0.2234   max= 2520.3786
#   dr        mean=-0.4306   min=-4.2367   max=-0.0045
#   exp       mean= 0.2764   min= 0.0000   max= 0.2999
#   miss      mean= 0.0000   min= 0.0000   max= 0.0000
#   prog      mean= 1.0424   min= 0.0000   max= 20.0000
#   step      mean= 0.0000   min=-0.0000   max=-0.0000
#   term      mean= 21.5517   min= 0.0000   max= 2500.0000
#   time      mean=-0.0483   min=-1.2949   max=-0.0006
#   total     mean= 22.3917   min=-5.0344   max= 2520.1573
# [delta_G] p50=7.0 p90=49.5 p99=359.6 clip_ceiling=211.8
# [TRUE-COIN+Expert] Ep 5/20: temp=1.589, avg_r/step=22.3738, avg_steps=116.0, replay=10000, dG_clip=231.4
#
# [Episode 5 reward breakdown] n=386628
#   delta_G   mean= 31.3795   min= 0.2234   max= 2520.3786
#   dr        mean=-0.4484   min=-4.6286   max=-0.0045
#   exp       mean= 0.2764   min= 0.0000   max= 0.2999
#   miss      mean= 0.0000   min= 0.0000   max= 0.0000
#   prog      mean= 1.0424   min= 0.0000   max= 20.0000
#   step      mean= 0.0000   min=-0.0000   max=-0.0000
#   term      mean= 21.5517   min= 0.0000   max= 2500.0000
#   time      mean=-0.0483   min=-1.2949   max=-0.0006
#   total     mean= 22.3738   min=-5.4264   max= 2520.1573
# [delta_G] p50=7.0 p90=49.5 p99=359.6 clip_ceiling=231.4
# [TRUE-COIN+Expert] Ep 6/20: temp=1.487, avg_r/step=22.3622, avg_steps=116.0, replay=10000, dG_clip=246.9
#
# [Episode 6 reward breakdown] n=386628
#   delta_G   mean= 31.3795   min= 0.2234   max= 2520.3786
#   dr        mean=-0.4600   min=-4.9382   max=-0.0045
#   exp       mean= 0.2764   min= 0.0000   max= 0.2999
#   miss      mean= 0.0000   min= 0.0000   max= 0.0000
#   prog      mean= 1.0424   min= 0.0000   max= 20.0000
#   step      mean= 0.0000   min=-0.0000   max=-0.0000
#   term      mean= 21.5517   min= 0.0000   max= 2500.0000
#   time      mean=-0.0483   min=-1.2949   max=-0.0006
#   total     mean= 22.3622   min=-5.7361   max= 2520.1573
# [delta_G] p50=7.0 p90=49.5 p99=359.6 clip_ceiling=246.9
# [TRUE-COIN+Expert] Ep 7/20: temp=1.384, avg_r/step=22.3539, avg_steps=116.0, replay=10000, dG_clip=259.5
#
# [Episode 7 reward breakdown] n=386628
#   delta_G   mean= 31.3795   min= 0.2234   max= 2520.3786
#   dr        mean=-0.4683   min=-5.1905   max=-0.0045
#   exp       mean= 0.2764   min= 0.0000   max= 0.2999
#   miss      mean= 0.0000   min= 0.0000   max= 0.0000
#   prog      mean= 1.0424   min= 0.0000   max= 20.0000
#   step      mean= 0.0000   min=-0.0000   max=-0.0000
#   term      mean= 21.5517   min= 0.0000   max= 2500.0000
#   time      mean=-0.0483   min=-1.2949   max=-0.0006
#   total     mean= 22.3539   min=-5.9886   max= 2520.1573
# [delta_G] p50=7.0 p90=49.5 p99=359.6 clip_ceiling=259.5
# [TRUE-COIN+Expert] Ep 8/20: temp=1.282, avg_r/step=22.3487, avg_steps=116.0, replay=10000, dG_clip=270.0
#
# [Episode 8 reward breakdown] n=386628
#   delta_G   mean= 31.3795   min= 0.2234   max= 2520.3786
#   dr        mean=-0.4735   min=-5.4009   max=-0.0045
#   exp       mean= 0.2764   min= 0.0000   max= 0.2999
#   miss      mean= 0.0000   min= 0.0000   max= 0.0000
#   prog      mean= 1.0424   min= 0.0000   max= 20.0000
#   step      mean= 0.0000   min=-0.0000   max=-0.0000
#   term      mean= 21.5517   min= 0.0000   max= 2500.0000
#   time      mean=-0.0483   min=-1.2949   max=-0.0006
#   total     mean= 22.3487   min=-6.1990   max= 2520.1573
# [delta_G] p50=7.0 p90=49.5 p99=359.6 clip_ceiling=270.0
# [TRUE-COIN+Expert] Ep 9/20: temp=1.179, avg_r/step=22.3454, avg_steps=116.0, replay=10000, dG_clip=279.0
#
# [Episode 9 reward breakdown] n=386628
#   delta_G   mean= 31.3795   min= 0.2234   max= 2520.3786
#   dr        mean=-0.4769   min=-5.5794   max=-0.0045
#   exp       mean= 0.2764   min= 0.0000   max= 0.2999
#   miss      mean= 0.0000   min= 0.0000   max= 0.0000
#   prog      mean= 1.0424   min= 0.0000   max= 20.0000
#   step      mean= 0.0000   min=-0.0000   max=-0.0000
#   term      mean= 21.5517   min= 0.0000   max= 2500.0000
#   time      mean=-0.0483   min=-1.2949   max=-0.0006
#   total     mean= 22.3454   min=-6.3776   max= 2520.1573
# [delta_G] p50=7.0 p90=49.5 p99=359.6 clip_ceiling=279.0
# [TRUE-COIN+Expert] Ep 10/20: temp=1.076, avg_r/step=22.3427, avg_steps=116.0, replay=10000, dG_clip=286.6
#
# [Episode 10 reward breakdown] n=386628
#   delta_G   mean= 31.3795   min= 0.2234   max= 2520.3786
#   dr        mean=-0.4795   min=-5.7330   max=-0.0045
#   exp       mean= 0.2764   min= 0.0000   max= 0.2999
#   miss      mean= 0.0000   min= 0.0000   max= 0.0000
#   prog      mean= 1.0424   min= 0.0000   max= 20.0000
#   step      mean= 0.0000   min=-0.0000   max=-0.0000
#   term      mean= 21.5517   min= 0.0000   max= 2500.0000
#   time      mean=-0.0483   min=-1.2949   max=-0.0006
#   total     mean= 22.3427   min=-6.5312   max= 2520.1573
# [delta_G] p50=7.0 p90=49.5 p99=359.6 clip_ceiling=286.6
# [TRUE-COIN+Expert] Ep 11/20: temp=0.974, avg_r/step=22.3406, avg_steps=116.0, replay=10000, dG_clip=293.3
#
# [Episode 11 reward breakdown] n=386628
#   delta_G   mean= 31.3795   min= 0.2234   max= 2520.3786
#   dr        mean=-0.4817   min=-5.8667   max=-0.0045
#   exp       mean= 0.2764   min= 0.0000   max= 0.2999
#   miss      mean= 0.0000   min= 0.0000   max= 0.0000
#   prog      mean= 1.0424   min= 0.0000   max= 20.0000
#   step      mean= 0.0000   min=-0.0000   max=-0.0000
#   term      mean= 21.5517   min= 0.0000   max= 2500.0000
#   time      mean=-0.0483   min=-1.2949   max=-0.0006
#   total     mean= 22.3406   min=-6.6649   max= 2520.1573
# [delta_G] p50=7.0 p90=49.5 p99=359.6 clip_ceiling=293.3
# [TRUE-COIN+Expert] Ep 12/20: temp=0.871, avg_r/step=22.3388, avg_steps=116.0, replay=10000, dG_clip=299.2
#
# [Episode 12 reward breakdown] n=386628
#   delta_G   mean= 31.3795   min= 0.2234   max= 2520.3786
#   dr        mean=-0.4835   min=-5.9842   max=-0.0045
#   exp       mean= 0.2764   min= 0.0000   max= 0.2999
#   miss      mean= 0.0000   min= 0.0000   max= 0.0000
#   prog      mean= 1.0424   min= 0.0000   max= 20.0000
#   step      mean= 0.0000   min=-0.0000   max=-0.0000
#   term      mean= 21.5517   min= 0.0000   max= 2500.0000
#   time      mean=-0.0483   min=-1.2949   max=-0.0006
#   total     mean= 22.3388   min=-6.7824   max= 2520.1573
# [delta_G] p50=7.0 p90=49.5 p99=359.6 clip_ceiling=299.2
# [TRUE-COIN+Expert] Ep 13/20: temp=0.768, avg_r/step=22.3372, avg_steps=116.0, replay=10000, dG_clip=304.4
#
# [Episode 13 reward breakdown] n=386628
#   delta_G   mean= 31.3795   min= 0.2234   max= 2520.3786
#   dr        mean=-0.4850   min=-6.0883   max=-0.0045
#   exp       mean= 0.2764   min= 0.0000   max= 0.2999
#   miss      mean= 0.0000   min= 0.0000   max= 0.0000
#   prog      mean= 1.0424   min= 0.0000   max= 20.0000
#   step      mean= 0.0000   min=-0.0000   max=-0.0000
#   term      mean= 21.5517   min= 0.0000   max= 2500.0000
#   time      mean=-0.0483   min=-1.2949   max=-0.0006
#   total     mean= 22.3372   min=-6.8866   max= 2520.1573
# [delta_G] p50=7.0 p90=49.5 p99=359.6 clip_ceiling=304.4
# [TRUE-COIN+Expert] Ep 14/20: temp=0.666, avg_r/step=22.3359, avg_steps=116.0, replay=10000, dG_clip=309.1
#
# [Episode 14 reward breakdown] n=386628
#   delta_G   mean= 31.3795   min= 0.2234   max= 2520.3786
#   dr        mean=-0.4864   min=-6.1813   max=-0.0045
#   exp       mean= 0.2764   min= 0.0000   max= 0.2999
#   miss      mean= 0.0000   min= 0.0000   max= 0.0000
#   prog      mean= 1.0424   min= 0.0000   max= 20.0000
#   step      mean= 0.0000   min=-0.0000   max=-0.0000
#   term      mean= 21.5517   min= 0.0000   max= 2500.0000
#   time      mean=-0.0483   min=-1.2949   max=-0.0006
#   total     mean= 22.3359   min=-6.9797   max= 2520.1573
# [delta_G] p50=7.0 p90=49.5 p99=359.6 clip_ceiling=309.1
# [TRUE-COIN+Expert] Ep 15/20: temp=0.563, avg_r/step=22.3347, avg_steps=116.0, replay=10000, dG_clip=313.2
#
# [Episode 15 reward breakdown] n=386628
#   delta_G   mean= 31.3795   min= 0.2234   max= 2520.3786
#   dr        mean=-0.4875   min=-6.2649   max=-0.0045
#   exp       mean= 0.2764   min= 0.0000   max= 0.2999
#   miss      mean= 0.0000   min= 0.0000   max= 0.0000
#   prog      mean= 1.0424   min= 0.0000   max= 20.0000
#   step      mean= 0.0000   min=-0.0000   max=-0.0000
#   term      mean= 21.5517   min= 0.0000   max= 2500.0000
#   time      mean=-0.0483   min=-1.2949   max=-0.0006
#   total     mean= 22.3347   min=-7.0632   max= 2520.1573
# [delta_G] p50=7.0 p90=49.5 p99=359.6 clip_ceiling=313.2
# [TRUE-COIN+Expert] Ep 16/20: temp=0.461, avg_r/step=22.3337, avg_steps=116.0, replay=10000, dG_clip=317.0
#
# [Episode 16 reward breakdown] n=386628
#   delta_G   mean= 31.3795   min= 0.2234   max= 2520.3786
#   dr        mean=-0.4885   min=-6.3404   max=-0.0045
#   exp       mean= 0.2764   min= 0.0000   max= 0.2999
#   miss      mean= 0.0000   min= 0.0000   max= 0.0000
#   prog      mean= 1.0424   min= 0.0000   max= 20.0000
#   step      mean= 0.0000   min=-0.0000   max=-0.0000
#   term      mean= 21.5517   min= 0.0000   max= 2500.0000
#   time      mean=-0.0483   min=-1.2949   max=-0.0006
#   total     mean= 22.3337   min=-7.1388   max= 2520.1573
# [delta_G] p50=7.0 p90=49.5 p99=359.6 clip_ceiling=317.0
# [TRUE-COIN+Expert] Ep 17/20: temp=0.358, avg_r/step=22.3328, avg_steps=116.0, replay=10000, dG_clip=320.5
#
# [Episode 17 reward breakdown] n=386628
#   delta_G   mean= 31.3795   min= 0.2234   max= 2520.3786
#   dr        mean=-0.4894   min=-6.4090   max=-0.0045
#   exp       mean= 0.2764   min= 0.0000   max= 0.2999
#   miss      mean= 0.0000   min= 0.0000   max= 0.0000
#   prog      mean= 1.0424   min= 0.0000   max= 20.0000
#   step      mean= 0.0000   min=-0.0000   max=-0.0000
#   term      mean= 21.5517   min= 0.0000   max= 2500.0000
#   time      mean=-0.0483   min=-1.2949   max=-0.0006
#   total     mean= 22.3328   min=-7.2074   max= 2520.1573
# [delta_G] p50=7.0 p90=49.5 p99=359.6 clip_ceiling=320.5
# [TRUE-COIN+Expert] Ep 18/20: temp=0.255, avg_r/step=22.3320, avg_steps=116.0, replay=10000, dG_clip=323.6
#
# [Episode 18 reward breakdown] n=386628
#   delta_G   mean= 31.3795   min= 0.2234   max= 2520.3786
#   dr        mean=-0.4903   min=-6.4716   max=-0.0045
#   exp       mean= 0.2764   min= 0.0000   max= 0.2999
#   miss      mean= 0.0000   min= 0.0000   max= 0.0000
#   prog      mean= 1.0424   min= 0.0000   max= 20.0000
#   step      mean= 0.0000   min=-0.0000   max=-0.0000
#   term      mean= 21.5517   min= 0.0000   max= 2500.0000
#   time      mean=-0.0483   min=-1.2949   max=-0.0006
#   total     mean= 22.3320   min=-7.2700   max= 2520.1573
# [delta_G] p50=7.0 p90=49.5 p99=359.6 clip_ceiling=323.6
# [TRUE-COIN+Expert] Ep 19/20: temp=0.153, avg_r/step=22.3313, avg_steps=116.0, replay=10000, dG_clip=326.4
#
# [Episode 19 reward breakdown] n=386628
#   delta_G   mean= 31.3795   min= 0.2234   max= 2520.3786
#   dr        mean=-0.4910   min=-6.5290   max=-0.0045
#   exp       mean= 0.2764   min= 0.0000   max= 0.2999
#   miss      mean= 0.0000   min= 0.0000   max= 0.0000
#   prog      mean= 1.0424   min= 0.0000   max= 20.0000
#   step      mean= 0.0000   min=-0.0000   max=-0.0000
#   term      mean= 21.5517   min= 0.0000   max= 2500.0000
#   time      mean=-0.0483   min=-1.2949   max=-0.0006
#   total     mean= 22.3313   min=-7.3274   max= 2520.1573
# [delta_G] p50=7.0 p90=49.5 p99=359.6 clip_ceiling=326.4
# [TRUE-COIN+Expert] Ep 20/20: temp=0.050, avg_r/step=22.3306, avg_steps=116.0, replay=10000, dG_clip=329.1
#
# [Episode 20 reward breakdown] n=386628
#   delta_G   mean= 31.3795   min= 0.2234   max= 2520.3786
#   dr        mean=-0.4917   min=-6.5818   max=-0.0045
#   exp       mean= 0.2764   min= 0.0000   max= 0.2999
#   miss      mean= 0.0000   min= 0.0000   max= 0.0000
#   prog      mean= 1.0424   min= 0.0000   max= 20.0000
#   step      mean= 0.0000   min=-0.0000   max=-0.0000
#   term      mean= 21.5517   min= 0.0000   max= 2500.0000
#   time      mean=-0.0483   min=-1.2949   max=-0.0006
#   total     mean= 22.3306   min=-7.3802   max= 2520.1573
# [delta_G] p50=7.0 p90=49.5 p99=359.6 clip_ceiling=329.1
# Finished TRUE-COIN+Expert Q-learning: 12959 state-action entries.

# %% [markdown]
# ## Experiment Results

# %%
print("========== Fraction reached ==========")
for name, (agents, flows, G) in results.items():
    print(f"[{name}] - reaching dest: {fraction_reached_agentspecific(agents ):.3f}")
# Out:
# ========== Fraction reached ==========
# [SPA] - reaching dest: 1.000
# [FF] - reaching dest: 1.000
# [FF-RL (TRUE COIN + expert)] - reaching dest: 0.984

# %%
for name, (agents, flows, G) in results.items():
    n = len(agents)
    print_scenario_metrics(name, manhattan_network, flows, G, n)

# Optional: quick global comparison
print("\n=== Global G comparison (hours) ===")
print(f"G_SPA              = {G_spa/3600:.2f} hrs")
print(f"G_FF               = {G_ff/3600:.2f} hrs")
print(f"G_FF-RL (COIN+exp) = {G_ff_rl/3600:.2f} hrs")
print(f"Improvement (FF-RL vs SPA)     = {(G_spa - G_ff_rl) / G_spa * 100:.2f}%")
# Out:
# [SPA] metrics:
#   Average travel time per agent:  2796.47 s  ( 46.61 min)
#   Total distance traveled:       187857.49 km
#   Average distance per agent:       18.79 km
#
# [FF] metrics:
#   Average travel time per agent:  4262.97 s  ( 71.05 min)
#   Total distance traveled:       327491.22 km
#   Average distance per agent:       32.75 km
#
# [FF-RL (TRUE COIN + expert)] metrics:
#   Average travel time per agent: 24727.41 s  (412.12 min)
#   Total distance traveled:       254155.10 km
#   Average distance per agent:       25.42 km
#
# === Global G comparison (hours) ===
# G_SPA              = 7767.97 hrs
# G_FF               = 11841.59 hrs
# G_FF-RL (COIN+exp) = 68687.26 hrs
# Improvement (FF-RL vs SPA)     = -784.24%

# %% [markdown]
# ## Experiment Visualizations

# %%
plot_routes_three_way(
    gdf,
    agents_spa, G_spa,
    agents_ff, G_ff,
    agents_ff_rl, G_ff_rl,
    num_agents=num_agents,
    horizon_s=horizon_s,
)

plot_heatmaps_three_way(
    gdf,
    manhattan_network,
    flows_spa,
    flows_ff,
    flows_ff_rl,
    num_agents=num_agents,
    horizon_s=horizon_s,
)

# %% [markdown]
# # Grid Search for Hyperparameters

# %%
import itertools
import time
import pandas as pd

def grid_search_coin(
    network,
    param_grid: dict,
    *,
    # fixed experiment settings
    seed: int = 26,
    num_agents: int = 1000,
    num_agents_expert: int | None = None,
    horizon_s: float = 3600.0,
    od_mode: str = "north_south",
    fixed_od: Optional[Tuple[Node, Node]] = None,
    steps_per_agent: int = 1500,
    # constraint
    min_reach: float = 0.90,
    # runtime / logging
    debug: bool = False,
    verbose_every: int = 1,
):
    """
    Grid search over run_ff_expert_coin_rl_experiment hyperparameters.

    Selection rule:
      - Only keep configs with reach_ff_rl >= min_reach
      - Among them, minimize G_ff_rl (veh-hours in your print)

    Returns:
      results_df (all trials)
      best_row (pd.Series or None if no feasible config)
    """
    if num_agents_expert is None:
        num_agents_expert = num_agents // 3

    # build all combinations
    keys = list(param_grid.keys())
    values_lists = [param_grid[k] for k in keys]
    combos = list(itertools.product(*values_lists))

    rows = []
    feasible_rows = []

    for i, vals in enumerate(combos, start=1):
        params = dict(zip(keys, vals))

        # make runs reproducible *per combo*
        random.seed(seed)
        np.random.seed(seed)
        t0 = time.time()

        try:
            (
                agents_spa,  flows_spa,  G_spa,
                agents_ff,   flows_ff,   G_ff,
                agents_ff_rl, flows_ff_rl, G_ff_rl,
                Q_ff_rl,
            ) = run_ff_expert_coin_rl_experiment(
                network,

                # --- fixed populations ---
                num_agents_baseline=num_agents,
                num_agents_expert=num_agents_expert,
                num_agents_eval_rl=num_agents,
                od_mode=od_mode,
                fixed_od=fixed_od,

                # --- fixed horizon + steps ---
                steps_per_agent=steps_per_agent,
                horizon_s=horizon_s,

                # --- tuned hyperparams from grid ---
                **params,

                # --- reduce spam unless debugging ---
                debug=debug,
            )

            reach_spa = fraction_reached_agentspecific(agents_spa)
            reach_ff  = fraction_reached_agentspecific(agents_ff)
            reach_rl  = fraction_reached_agentspecific(agents_ff_rl)

            elapsed = time.time() - t0

            row = {
                "trial": i,
                "elapsed_s": elapsed,

                "reach_spa": reach_spa,
                "reach_ff": reach_ff,
                "reach_ff_rl": reach_rl,

                "G_spa_vehhrs": G_spa / 3600.0,
                "G_ff_vehhrs": G_ff / 3600.0,
                "G_ff_rl_vehhrs": G_ff_rl / 3600.0,

                "feasible": (reach_rl >= min_reach),
            }
            row.update(params)

            rows.append(row)
            if row["feasible"]:
                feasible_rows.append(row)

            if verbose_every and (i % verbose_every == 0):
                print(
                    f"[{i}/{len(combos)}] reach_rl={reach_rl:.3f} "
                    f"G_rl={row['G_ff_rl_vehhrs']:.1f} veh·hrs "
                    f"feasible={row['feasible']} params={params}"
                )

        except Exception as e:
            elapsed = time.time() - t0
            row = {
                "trial": i,
                "elapsed_s": elapsed,
                "error": repr(e),
                "feasible": False,
            }
            row.update(params)
            rows.append(row)

            print(f"[{i}/{len(combos)}] ERROR: {e} params={params}")

    results_df = pd.DataFrame(rows)

    best_row = None
    if feasible_rows:
        feasible_df = pd.DataFrame(feasible_rows)
        best_idx = feasible_df["G_ff_rl_vehhrs"].idxmin()
        best_row = feasible_df.loc[best_idx]

    return results_df, best_row

# %% [markdown]
# ## Parameter Grid

# %%
param_grid = {
    # ==========================================================
    # ✅ VARIED (minimal, high-impact)
    # ==========================================================
    "temperature": [0.1, 0.3, 0.6],
    "lambda_live_cost": [0.5, 1.0, 2.0, 2.5],
    "visited_penalty_val": [1.0, 3.0, 6.0, 10.0],
    "epsilon_eval": [0.01],

    # ==========================================================
    # 🔒 FIXED (keep constant while you tune policy behavior)
    # ==========================================================
    # Boltzmann exploration (replaces epsilon_start / epsilon_end)
    "temp_start": [2.0],
    "temp_end": [0.05],
    "num_episodes_rl": [40],
    "visited_penalty_train": [1.0],

    # reward weights
    "lambda_dr": [0.2],
    "lambda_prog": [1.0],
    "lambda_exp": [0.1],
    "lambda_step": [0.1],

    # scaling
    "time_scale": [5000],

    # terminal shaping
    "lambda_term": [600.0],
    "lambda_miss": [300.0],
}

# %% [markdown]
# ## Grid Run

# %%
min_reach = 0.10

results_df, best = grid_search_coin(
    manhattan_network,
    param_grid,
    seed=26,
    num_agents=1000,
    horizon_s=3600.0,
    od_mode="north_south",
    steps_per_agent=1500,
    min_reach=min_reach,
    debug=False,
    verbose_every=1,
)

print("\n=== Grid search done ===")
print("Total trials:", len(results_df))
print("Feasible trials:", int(results_df["feasible"].sum()) if "feasible" in results_df else 0)

if best is None:
    print(f"No feasible config found (reach_ff_rl >= {min_reach:.2f}).")
else:
    print("\n=== Best feasible config (min G_ff_rl) ===")
    display(best)  # in notebook
# Out:
# SPA experiment with 1000 agents (north_south O/D)
# Used edges: 4948 / 16444
# FFA experiment with 1000 agents (north_south O/D)
# Used edges: 7366 / 16444
# Collected 32209 FF-expert (s,d,a,edge_id) steps from 333 agents.
# [FF expert] 4840 distinct expert edges.
# Initializing TRUE-COIN Q from Ford–Fulkerson expert trajectories...
# TRUE-COIN Q initialized on 32209 FF expert steps (unique state–action pairs: 31950).
# [TRUE-COIN+Expert] Episode 1/40: epsilon=0.400, avg_return=409.277, avg_steps=839.3
# [TRUE-COIN+Expert] Episode 2/40: epsilon=0.392, avg_return=403.066, avg_steps=816.5
# [TRUE-COIN+Expert] Episode 3/40: epsilon=0.385, avg_return=363.189, avg_steps=861.8
# [TRUE-COIN+Expert] Episode 4/40: epsilon=0.377, avg_return=417.997, avg_steps=771.4
# [TRUE-COIN+Expert] Episode 5/40: epsilon=0.369, avg_return=388.604, avg_steps=818.5
# [TRUE-COIN+Expert] Episode 6/40: epsilon=0.362, avg_return=402.446, avg_steps=774.6
# [TRUE-COIN+Expert] Episode 7/40: epsilon=0.354, avg_return=406.527, avg_steps=789.3
# [TRUE-COIN+Expert] Episode 8/40: epsilon=0.346, avg_return=392.253, avg_steps=777.5
# [TRUE-COIN+Expert] Episode 9/40: epsilon=0.338, avg_return=381.440, avg_steps=782.0
# [TRUE-COIN+Expert] Episode 10/40: epsilon=0.331, avg_return=386.094, avg_steps=763.4
# [TRUE-COIN+Expert] Episode 11/40: epsilon=0.323, avg_return=380.732, avg_steps=774.6
# [TRUE-COIN+Expert] Episode 12/40: epsilon=0.315, avg_return=391.367, avg_steps=749.7
# [TRUE-COIN+Expert] Episode 13/40: epsilon=0.308, avg_return=392.020, avg_steps=751.3
# [TRUE-COIN+Expert] Episode 14/40: epsilon=0.300, avg_return=397.700, avg_steps=737.3
# [TRUE-COIN+Expert] Episode 15/40: epsilon=0.292, avg_return=433.244, avg_steps=689.7
# [TRUE-COIN+Expert] Episode 16/40: epsilon=0.285, avg_return=400.877, avg_steps=693.1
# [TRUE-COIN+Expert] Episode 17/40: epsilon=0.277, avg_return=408.936, avg_steps=709.3
# [TRUE-COIN+Expert] Episode 18/40: epsilon=0.269, avg_return=426.978, avg_steps=690.4
# [TRUE-COIN+Expert] Episode 19/40: epsilon=0.262, avg_return=398.978, avg_steps=705.1
# [TRUE-COIN+Expert] Episode 20/40: epsilon=0.254, avg_return=455.031, avg_steps=629.7
# [TRUE-COIN+Expert] Episode 21/40: epsilon=0.246, avg_return=425.808, avg_steps=650.8
# [TRUE-COIN+Expert] Episode 22/40: epsilon=0.238, avg_return=422.403, avg_steps=661.0
# [TRUE-COIN+Expert] Episode 23/40: epsilon=0.231, avg_return=434.178, avg_steps=631.8
# [TRUE-COIN+Expert] Episode 24/40: epsilon=0.223, avg_return=439.768, avg_steps=612.7
# [TRUE-COIN+Expert] Episode 25/40: epsilon=0.215, avg_return=423.325, avg_steps=649.8
# [TRUE-COIN+Expert] Episode 26/40: epsilon=0.208, avg_return=386.251, avg_steps=683.4
# [TRUE-COIN+Expert] Episode 27/40: epsilon=0.200, avg_return=410.838, avg_steps=628.6
# [TRUE-COIN+Expert] Episode 28/40: epsilon=0.192, avg_return=382.234, avg_steps=675.0
# [TRUE-COIN+Expert] Episode 29/40: epsilon=0.185, avg_return=441.136, avg_steps=613.4
# [TRUE-COIN+Expert] Episode 30/40: epsilon=0.177, avg_return=440.876, avg_steps=580.8
# [TRUE-COIN+Expert] Episode 31/40: epsilon=0.169, avg_return=441.900, avg_steps=595.3
# [TRUE-COIN+Expert] Episode 32/40: epsilon=0.162, avg_return=441.818, avg_steps=588.7
# [TRUE-COIN+Expert] Episode 33/40: epsilon=0.154, avg_return=433.905, avg_steps=580.2
# [TRUE-COIN+Expert] Episode 34/40: epsilon=0.146, avg_return=420.014, avg_steps=595.8
# [TRUE-COIN+Expert] Episode 35/40: epsilon=0.138, avg_return=463.450, avg_steps=537.6
# [TRUE-COIN+Expert] Episode 36/40: epsilon=0.131, avg_return=413.681, avg_steps=594.7
# [TRUE-COIN+Expert] Episode 37/40: epsilon=0.123, avg_return=455.387, avg_steps=566.8
# [TRUE-COIN+Expert] Episode 38/40: epsilon=0.115, avg_return=420.832, avg_steps=606.1
# [TRUE-COIN+Expert] Episode 39/40: epsilon=0.108, avg_return=474.344, avg_steps=531.8
# [TRUE-COIN+Expert] Episode 40/40: epsilon=0.100, avg_return=374.074, avg_steps=621.6
# Finished TRUE-COIN+Expert Q-learning with 4419395 learned state–action entries.
# [1/48] reach_rl=0.211 G_rl=4280.7 veh·hrs feasible=True params={'temperature': 0.1, 'lambda_live_cost': 0.5, 'visited_penalty_val': 1.0, 'epsilon_eval': 0.01, 'epsilon_start': 0.4, 'epsilon_end': 0.1, 'num_episodes_rl': 40, 'lambda_dr': 0.2, 'lambda_prog': 1.0, 'lambda_exp': 0.1, 'lambda_step': 0.1, 'time_scale': 5000, 'lambda_term': 600.0, 'lambda_miss': 300.0}
# SPA experiment with 1000 agents (north_south O/D)
# Used edges: 4948 / 16444
# FFA experiment with 1000 agents (north_south O/D)
# Used edges: 7366 / 16444
# Collected 32209 FF-expert (s,d,a,edge_id) steps from 333 agents.
# [FF expert] 4840 distinct expert edges.
# Initializing TRUE-COIN Q from Ford–Fulkerson expert trajectories...
# TRUE-COIN Q initialized on 32209 FF expert steps (unique state–action pairs: 31950).
# [TRUE-COIN+Expert] Episode 1/40: epsilon=0.400, avg_return=409.277, avg_steps=839.3
# [TRUE-COIN+Expert] Episode 2/40: epsilon=0.392, avg_return=403.066, avg_steps=816.5
# [TRUE-COIN+Expert] Episode 3/40: epsilon=0.385, avg_return=363.189, avg_steps=861.8
# [TRUE-COIN+Expert] Episode 4/40: epsilon=0.377, avg_return=417.997, avg_steps=771.4
# [TRUE-COIN+Expert] Episode 5/40: epsilon=0.369, avg_return=388.604, avg_steps=818.5
# [TRUE-COIN+Expert] Episode 6/40: epsilon=0.362, avg_return=402.446, avg_steps=774.6
# [TRUE-COIN+Expert] Episode 7/40: epsilon=0.354, avg_return=406.527, avg_steps=789.3
# [TRUE-COIN+Expert] Episode 8/40: epsilon=0.346, avg_return=392.253, avg_steps=777.5
# [TRUE-COIN+Expert] Episode 9/40: epsilon=0.338, avg_return=381.440, avg_steps=782.0
# [TRUE-COIN+Expert] Episode 10/40: epsilon=0.331, avg_return=386.094, avg_steps=763.4
# [TRUE-COIN+Expert] Episode 11/40: epsilon=0.323, avg_return=380.732, avg_steps=774.6
# [TRUE-COIN+Expert] Episode 12/40: epsilon=0.315, avg_return=391.367, avg_steps=749.7
# [TRUE-COIN+Expert] Episode 13/40: epsilon=0.308, avg_return=392.020, avg_steps=751.3
# [TRUE-COIN+Expert] Episode 14/40: epsilon=0.300, avg_return=397.700, avg_steps=737.3
# [TRUE-COIN+Expert] Episode 15/40: epsilon=0.292, avg_return=433.244, avg_steps=689.7
# [TRUE-COIN+Expert] Episode 16/40: epsilon=0.285, avg_return=400.877, avg_steps=693.1
# [TRUE-COIN+Expert] Episode 17/40: epsilon=0.277, avg_return=408.936, avg_steps=709.3
# [TRUE-COIN+Expert] Episode 18/40: epsilon=0.269, avg_return=426.978, avg_steps=690.4
# [TRUE-COIN+Expert] Episode 19/40: epsilon=0.262, avg_return=398.978, avg_steps=705.1
# [TRUE-COIN+Expert] Episode 20/40: epsilon=0.254, avg_return=455.031, avg_steps=629.7
# [TRUE-COIN+Expert] Episode 21/40: epsilon=0.246, avg_return=425.808, avg_steps=650.8
# [TRUE-COIN+Expert] Episode 22/40: epsilon=0.238, avg_return=422.403, avg_steps=661.0
# [TRUE-COIN+Expert] Episode 23/40: epsilon=0.231, avg_return=434.178, avg_steps=631.8
# [TRUE-COIN+Expert] Episode 24/40: epsilon=0.223, avg_return=439.768, avg_steps=612.7
# [TRUE-COIN+Expert] Episode 25/40: epsilon=0.215, avg_return=423.325, avg_steps=649.8
# [TRUE-COIN+Expert] Episode 26/40: epsilon=0.208, avg_return=386.251, avg_steps=683.4
# [TRUE-COIN+Expert] Episode 27/40: epsilon=0.200, avg_return=410.838, avg_steps=628.6
# [TRUE-COIN+Expert] Episode 28/40: epsilon=0.192, avg_return=382.234, avg_steps=675.0
# [TRUE-COIN+Expert] Episode 29/40: epsilon=0.185, avg_return=441.136, avg_steps=613.4
# [TRUE-COIN+Expert] Episode 30/40: epsilon=0.177, avg_return=440.876, avg_steps=580.8
# [TRUE-COIN+Expert] Episode 31/40: epsilon=0.169, avg_return=441.900, avg_steps=595.3
# [TRUE-COIN+Expert] Episode 32/40: epsilon=0.162, avg_return=441.818, avg_steps=588.7
# [TRUE-COIN+Expert] Episode 33/40: epsilon=0.154, avg_return=433.905, avg_steps=580.2
# [TRUE-COIN+Expert] Episode 34/40: epsilon=0.146, avg_return=420.014, avg_steps=595.8
# [TRUE-COIN+Expert] Episode 35/40: epsilon=0.138, avg_return=463.450, avg_steps=537.6
# [TRUE-COIN+Expert] Episode 36/40: epsilon=0.131, avg_return=413.681, avg_steps=594.7
# [TRUE-COIN+Expert] Episode 37/40: epsilon=0.123, avg_return=455.387, avg_steps=566.8
# [TRUE-COIN+Expert] Episode 38/40: epsilon=0.115, avg_return=420.832, avg_steps=606.1
# [TRUE-COIN+Expert] Episode 39/40: epsilon=0.108, avg_return=474.344, avg_steps=531.8
# [TRUE-COIN+Expert] Episode 40/40: epsilon=0.100, avg_return=374.074, avg_steps=621.6
# Finished TRUE-COIN+Expert Q-learning with 4419395 learned state–action entries.
# [2/48] reach_rl=0.223 G_rl=4295.6 veh·hrs feasible=True params={'temperature': 0.1, 'lambda_live_cost': 0.5, 'visited_penalty_val': 3.0, 'epsilon_eval': 0.01, 'epsilon_start': 0.4, 'epsilon_end': 0.1, 'num_episodes_rl': 40, 'lambda_dr': 0.2, 'lambda_prog': 1.0, 'lambda_exp': 0.1, 'lambda_step': 0.1, 'time_scale': 5000, 'lambda_term': 600.0, 'lambda_miss': 300.0}
# SPA experiment with 1000 agents (north_south O/D)
# Used edges: 4948 / 16444
# FFA experiment with 1000 agents (north_south O/D)
# Used edges: 7366 / 16444
# Collected 32209 FF-expert (s,d,a,edge_id) steps from 333 agents.
# [FF expert] 4840 distinct expert edges.
# Initializing TRUE-COIN Q from Ford–Fulkerson expert trajectories...
# TRUE-COIN Q initialized on 32209 FF expert steps (unique state–action pairs: 31950).
# [TRUE-COIN+Expert] Episode 1/40: epsilon=0.400, avg_return=409.277, avg_steps=839.3
# [TRUE-COIN+Expert] Episode 2/40: epsilon=0.392, avg_return=403.066, avg_steps=816.5
# [TRUE-COIN+Expert] Episode 3/40: epsilon=0.385, avg_return=363.189, avg_steps=861.8
# [TRUE-COIN+Expert] Episode 4/40: epsilon=0.377, avg_return=417.997, avg_steps=771.4
# [TRUE-COIN+Expert] Episode 5/40: epsilon=0.369, avg_return=388.604, avg_steps=818.5
# [TRUE-COIN+Expert] Episode 6/40: epsilon=0.362, avg_return=402.446, avg_steps=774.6
# [TRUE-COIN+Expert] Episode 7/40: epsilon=0.354, avg_return=406.527, avg_steps=789.3
# [TRUE-COIN+Expert] Episode 8/40: epsilon=0.346, avg_return=392.253, avg_steps=777.5
# [TRUE-COIN+Expert] Episode 9/40: epsilon=0.338, avg_return=381.440, avg_steps=782.0
# [TRUE-COIN+Expert] Episode 10/40: epsilon=0.331, avg_return=386.094, avg_steps=763.4
# [TRUE-COIN+Expert] Episode 11/40: epsilon=0.323, avg_return=380.732, avg_steps=774.6
# [TRUE-COIN+Expert] Episode 12/40: epsilon=0.315, avg_return=391.367, avg_steps=749.7
# [TRUE-COIN+Expert] Episode 13/40: epsilon=0.308, avg_return=392.020, avg_steps=751.3
# [TRUE-COIN+Expert] Episode 14/40: epsilon=0.300, avg_return=397.700, avg_steps=737.3
# [TRUE-COIN+Expert] Episode 15/40: epsilon=0.292, avg_return=433.244, avg_steps=689.7
# [TRUE-COIN+Expert] Episode 16/40: epsilon=0.285, avg_return=400.877, avg_steps=693.1
# [TRUE-COIN+Expert] Episode 17/40: epsilon=0.277, avg_return=408.936, avg_steps=709.3
# [TRUE-COIN+Expert] Episode 18/40: epsilon=0.269, avg_return=426.978, avg_steps=690.4
# [TRUE-COIN+Expert] Episode 19/40: epsilon=0.262, avg_return=398.978, avg_steps=705.1
# [TRUE-COIN+Expert] Episode 20/40: epsilon=0.254, avg_return=455.031, avg_steps=629.7
# [TRUE-COIN+Expert] Episode 21/40: epsilon=0.246, avg_return=425.808, avg_steps=650.8
# [TRUE-COIN+Expert] Episode 22/40: epsilon=0.238, avg_return=422.403, avg_steps=661.0
# [TRUE-COIN+Expert] Episode 23/40: epsilon=0.231, avg_return=434.178, avg_steps=631.8
# [TRUE-COIN+Expert] Episode 24/40: epsilon=0.223, avg_return=439.768, avg_steps=612.7
# [TRUE-COIN+Expert] Episode 25/40: epsilon=0.215, avg_return=423.325, avg_steps=649.8
# [TRUE-COIN+Expert] Episode 26/40: epsilon=0.208, avg_return=386.251, avg_steps=683.4
# [TRUE-COIN+Expert] Episode 27/40: epsilon=0.200, avg_return=410.838, avg_steps=628.6
# [TRUE-COIN+Expert] Episode 28/40: epsilon=0.192, avg_return=382.234, avg_steps=675.0
# [TRUE-COIN+Expert] Episode 29/40: epsilon=0.185, avg_return=441.136, avg_steps=613.4
# [TRUE-COIN+Expert] Episode 30/40: epsilon=0.177, avg_return=440.876, avg_steps=580.8
# [TRUE-COIN+Expert] Episode 31/40: epsilon=0.169, avg_return=441.900, avg_steps=595.3
# [TRUE-COIN+Expert] Episode 32/40: epsilon=0.162, avg_return=441.818, avg_steps=588.7
# [TRUE-COIN+Expert] Episode 33/40: epsilon=0.154, avg_return=433.905, avg_steps=580.2
# [TRUE-COIN+Expert] Episode 34/40: epsilon=0.146, avg_return=420.014, avg_steps=595.8
# [TRUE-COIN+Expert] Episode 35/40: epsilon=0.138, avg_return=463.450, avg_steps=537.6
# [TRUE-COIN+Expert] Episode 36/40: epsilon=0.131, avg_return=413.681, avg_steps=594.7
# [TRUE-COIN+Expert] Episode 37/40: epsilon=0.123, avg_return=455.387, avg_steps=566.8
# [TRUE-COIN+Expert] Episode 38/40: epsilon=0.115, avg_return=420.832, avg_steps=606.1
# [TRUE-COIN+Expert] Episode 39/40: epsilon=0.108, avg_return=474.344, avg_steps=531.8
# [TRUE-COIN+Expert] Episode 40/40: epsilon=0.100, avg_return=374.074, avg_steps=621.6
# Finished TRUE-COIN+Expert Q-learning with 4419395 learned state–action entries.
# [3/48] reach_rl=0.200 G_rl=4331.4 veh·hrs feasible=True params={'temperature': 0.1, 'lambda_live_cost': 0.5, 'visited_penalty_val': 6.0, 'epsilon_eval': 0.01, 'epsilon_start': 0.4, 'epsilon_end': 0.1, 'num_episodes_rl': 40, 'lambda_dr': 0.2, 'lambda_prog': 1.0, 'lambda_exp': 0.1, 'lambda_step': 0.1, 'time_scale': 5000, 'lambda_term': 600.0, 'lambda_miss': 300.0}
# SPA experiment with 1000 agents (north_south O/D)
# Used edges: 4948 / 16444
# FFA experiment with 1000 agents (north_south O/D)
# Used edges: 7366 / 16444
# Collected 32209 FF-expert (s,d,a,edge_id) steps from 333 agents.
# [FF expert] 4840 distinct expert edges.
# Initializing TRUE-COIN Q from Ford–Fulkerson expert trajectories...
# TRUE-COIN Q initialized on 32209 FF expert steps (unique state–action pairs: 31950).
# [TRUE-COIN+Expert] Episode 1/40: epsilon=0.400, avg_return=409.277, avg_steps=839.3
# [TRUE-COIN+Expert] Episode 2/40: epsilon=0.392, avg_return=403.066, avg_steps=816.5
# [TRUE-COIN+Expert] Episode 3/40: epsilon=0.385, avg_return=363.189, avg_steps=861.8
# [TRUE-COIN+Expert] Episode 4/40: epsilon=0.377, avg_return=417.997, avg_steps=771.4
# [TRUE-COIN+Expert] Episode 5/40: epsilon=0.369, avg_return=388.604, avg_steps=818.5
# [TRUE-COIN+Expert] Episode 6/40: epsilon=0.362, avg_return=402.446, avg_steps=774.6
# [TRUE-COIN+Expert] Episode 7/40: epsilon=0.354, avg_return=406.527, avg_steps=789.3
# [TRUE-COIN+Expert] Episode 8/40: epsilon=0.346, avg_return=392.253, avg_steps=777.5
# [TRUE-COIN+Expert] Episode 9/40: epsilon=0.338, avg_return=381.440, avg_steps=782.0
# [TRUE-COIN+Expert] Episode 10/40: epsilon=0.331, avg_return=386.094, avg_steps=763.4
# [TRUE-COIN+Expert] Episode 11/40: epsilon=0.323, avg_return=380.732, avg_steps=774.6
# [TRUE-COIN+Expert] Episode 12/40: epsilon=0.315, avg_return=391.367, avg_steps=749.7
# [TRUE-COIN+Expert] Episode 13/40: epsilon=0.308, avg_return=392.020, avg_steps=751.3
# [TRUE-COIN+Expert] Episode 14/40: epsilon=0.300, avg_return=397.700, avg_steps=737.3
# [TRUE-COIN+Expert] Episode 15/40: epsilon=0.292, avg_return=433.244, avg_steps=689.7
# [TRUE-COIN+Expert] Episode 16/40: epsilon=0.285, avg_return=400.877, avg_steps=693.1
# [TRUE-COIN+Expert] Episode 17/40: epsilon=0.277, avg_return=408.936, avg_steps=709.3
# [TRUE-COIN+Expert] Episode 18/40: epsilon=0.269, avg_return=426.978, avg_steps=690.4
# [TRUE-COIN+Expert] Episode 19/40: epsilon=0.262, avg_return=398.978, avg_steps=705.1
# [TRUE-COIN+Expert] Episode 20/40: epsilon=0.254, avg_return=455.031, avg_steps=629.7
# [TRUE-COIN+Expert] Episode 21/40: epsilon=0.246, avg_return=425.808, avg_steps=650.8
# [TRUE-COIN+Expert] Episode 22/40: epsilon=0.238, avg_return=422.403, avg_steps=661.0
# [TRUE-COIN+Expert] Episode 23/40: epsilon=0.231, avg_return=434.178, avg_steps=631.8
# [TRUE-COIN+Expert] Episode 24/40: epsilon=0.223, avg_return=439.768, avg_steps=612.7
# [TRUE-COIN+Expert] Episode 25/40: epsilon=0.215, avg_return=423.325, avg_steps=649.8
# [TRUE-COIN+Expert] Episode 26/40: epsilon=0.208, avg_return=386.251, avg_steps=683.4
# [TRUE-COIN+Expert] Episode 27/40: epsilon=0.200, avg_return=410.838, avg_steps=628.6
# [TRUE-COIN+Expert] Episode 28/40: epsilon=0.192, avg_return=382.234, avg_steps=675.0
# [TRUE-COIN+Expert] Episode 29/40: epsilon=0.185, avg_return=441.136, avg_steps=613.4
# [TRUE-COIN+Expert] Episode 30/40: epsilon=0.177, avg_return=440.876, avg_steps=580.8
# [TRUE-COIN+Expert] Episode 31/40: epsilon=0.169, avg_return=441.900, avg_steps=595.3
# [TRUE-COIN+Expert] Episode 32/40: epsilon=0.162, avg_return=441.818, avg_steps=588.7
# [TRUE-COIN+Expert] Episode 33/40: epsilon=0.154, avg_return=433.905, avg_steps=580.2
# [TRUE-COIN+Expert] Episode 34/40: epsilon=0.146, avg_return=420.014, avg_steps=595.8
# [TRUE-COIN+Expert] Episode 35/40: epsilon=0.138, avg_return=463.450, avg_steps=537.6
# [TRUE-COIN+Expert] Episode 36/40: epsilon=0.131, avg_return=413.681, avg_steps=594.7
# [TRUE-COIN+Expert] Episode 37/40: epsilon=0.123, avg_return=455.387, avg_steps=566.8
# [TRUE-COIN+Expert] Episode 38/40: epsilon=0.115, avg_return=420.832, avg_steps=606.1
# [TRUE-COIN+Expert] Episode 39/40: epsilon=0.108, avg_return=474.344, avg_steps=531.8
# [TRUE-COIN+Expert] Episode 40/40: epsilon=0.100, avg_return=374.074, avg_steps=621.6
# Finished TRUE-COIN+Expert Q-learning with 4419395 learned state–action entries.
# [4/48] reach_rl=0.200 G_rl=4331.4 veh·hrs feasible=True params={'temperature': 0.1, 'lambda_live_cost': 0.5, 'visited_penalty_val': 10.0, 'epsilon_eval': 0.01, 'epsilon_start': 0.4, 'epsilon_end': 0.1, 'num_episodes_rl': 40, 'lambda_dr': 0.2, 'lambda_prog': 1.0, 'lambda_exp': 0.1, 'lambda_step': 0.1, 'time_scale': 5000, 'lambda_term': 600.0, 'lambda_miss': 300.0}
# SPA experiment with 1000 agents (north_south O/D)
# Used edges: 4948 / 16444
# FFA experiment with 1000 agents (north_south O/D)
# Used edges: 7366 / 16444
# Collected 32209 FF-expert (s,d,a,edge_id) steps from 333 agents.
# [FF expert] 4840 distinct expert edges.
# Initializing TRUE-COIN Q from Ford–Fulkerson expert trajectories...
# TRUE-COIN Q initialized on 32209 FF expert steps (unique state–action pairs: 31950).
# [TRUE-COIN+Expert] Episode 1/40: epsilon=0.400, avg_return=409.277, avg_steps=839.3
# [TRUE-COIN+Expert] Episode 2/40: epsilon=0.392, avg_return=403.066, avg_steps=816.5
# [TRUE-COIN+Expert] Episode 3/40: epsilon=0.385, avg_return=363.189, avg_steps=861.8
# [TRUE-COIN+Expert] Episode 4/40: epsilon=0.377, avg_return=417.997, avg_steps=771.4
# [TRUE-COIN+Expert] Episode 5/40: epsilon=0.369, avg_return=388.604, avg_steps=818.5
# [TRUE-COIN+Expert] Episode 6/40: epsilon=0.362, avg_return=402.446, avg_steps=774.6
# [TRUE-COIN+Expert] Episode 7/40: epsilon=0.354, avg_return=406.527, avg_steps=789.3
# [TRUE-COIN+Expert] Episode 8/40: epsilon=0.346, avg_return=392.253, avg_steps=777.5
# [TRUE-COIN+Expert] Episode 9/40: epsilon=0.338, avg_return=381.440, avg_steps=782.0
# [TRUE-COIN+Expert] Episode 10/40: epsilon=0.331, avg_return=386.094, avg_steps=763.4
# [TRUE-COIN+Expert] Episode 11/40: epsilon=0.323, avg_return=380.732, avg_steps=774.6
# [TRUE-COIN+Expert] Episode 12/40: epsilon=0.315, avg_return=391.367, avg_steps=749.7
# [TRUE-COIN+Expert] Episode 13/40: epsilon=0.308, avg_return=392.020, avg_steps=751.3
# [TRUE-COIN+Expert] Episode 14/40: epsilon=0.300, avg_return=397.700, avg_steps=737.3
# [TRUE-COIN+Expert] Episode 15/40: epsilon=0.292, avg_return=433.244, avg_steps=689.7
# [TRUE-COIN+Expert] Episode 16/40: epsilon=0.285, avg_return=400.877, avg_steps=693.1
# [TRUE-COIN+Expert] Episode 17/40: epsilon=0.277, avg_return=408.936, avg_steps=709.3
# [TRUE-COIN+Expert] Episode 18/40: epsilon=0.269, avg_return=426.978, avg_steps=690.4
# [TRUE-COIN+Expert] Episode 19/40: epsilon=0.262, avg_return=398.978, avg_steps=705.1
# [TRUE-COIN+Expert] Episode 20/40: epsilon=0.254, avg_return=455.031, avg_steps=629.7
# [TRUE-COIN+Expert] Episode 21/40: epsilon=0.246, avg_return=425.808, avg_steps=650.8
# [TRUE-COIN+Expert] Episode 22/40: epsilon=0.238, avg_return=422.403, avg_steps=661.0
# [TRUE-COIN+Expert] Episode 23/40: epsilon=0.231, avg_return=434.178, avg_steps=631.8
# [TRUE-COIN+Expert] Episode 24/40: epsilon=0.223, avg_return=439.768, avg_steps=612.7
# [TRUE-COIN+Expert] Episode 25/40: epsilon=0.215, avg_return=423.325, avg_steps=649.8
# [TRUE-COIN+Expert] Episode 26/40: epsilon=0.208, avg_return=386.251, avg_steps=683.4
# [TRUE-COIN+Expert] Episode 27/40: epsilon=0.200, avg_return=410.838, avg_steps=628.6
# [TRUE-COIN+Expert] Episode 28/40: epsilon=0.192, avg_return=382.234, avg_steps=675.0
# [TRUE-COIN+Expert] Episode 29/40: epsilon=0.185, avg_return=441.136, avg_steps=613.4
# [TRUE-COIN+Expert] Episode 30/40: epsilon=0.177, avg_return=440.876, avg_steps=580.8
# [TRUE-COIN+Expert] Episode 31/40: epsilon=0.169, avg_return=441.900, avg_steps=595.3
# [TRUE-COIN+Expert] Episode 32/40: epsilon=0.162, avg_return=441.818, avg_steps=588.7
# [TRUE-COIN+Expert] Episode 33/40: epsilon=0.154, avg_return=433.905, avg_steps=580.2
# [TRUE-COIN+Expert] Episode 34/40: epsilon=0.146, avg_return=420.014, avg_steps=595.8
# [TRUE-COIN+Expert] Episode 35/40: epsilon=0.138, avg_return=463.450, avg_steps=537.6
# [TRUE-COIN+Expert] Episode 36/40: epsilon=0.131, avg_return=413.681, avg_steps=594.7
# [TRUE-COIN+Expert] Episode 37/40: epsilon=0.123, avg_return=455.387, avg_steps=566.8
# [TRUE-COIN+Expert] Episode 38/40: epsilon=0.115, avg_return=420.832, avg_steps=606.1
# [TRUE-COIN+Expert] Episode 39/40: epsilon=0.108, avg_return=474.344, avg_steps=531.8
# [TRUE-COIN+Expert] Episode 40/40: epsilon=0.100, avg_return=374.074, avg_steps=621.6
# Finished TRUE-COIN+Expert Q-learning with 4419395 learned state–action entries.
# [5/48] reach_rl=0.220 G_rl=4296.6 veh·hrs feasible=True params={'temperature': 0.1, 'lambda_live_cost': 1.0, 'visited_penalty_val': 1.0, 'epsilon_eval': 0.01, 'epsilon_start': 0.4, 'epsilon_end': 0.1, 'num_episodes_rl': 40, 'lambda_dr': 0.2, 'lambda_prog': 1.0, 'lambda_exp': 0.1, 'lambda_step': 0.1, 'time_scale': 5000, 'lambda_term': 600.0, 'lambda_miss': 300.0}
# SPA experiment with 1000 agents (north_south O/D)
# Used edges: 4948 / 16444
# FFA experiment with 1000 agents (north_south O/D)
# Used edges: 7366 / 16444
# Collected 32209 FF-expert (s,d,a,edge_id) steps from 333 agents.
# [FF expert] 4840 distinct expert edges.
# Initializing TRUE-COIN Q from Ford–Fulkerson expert trajectories...
# TRUE-COIN Q initialized on 32209 FF expert steps (unique state–action pairs: 31950).
# [TRUE-COIN+Expert] Episode 1/40: epsilon=0.400, avg_return=409.277, avg_steps=839.3
# [TRUE-COIN+Expert] Episode 2/40: epsilon=0.392, avg_return=403.066, avg_steps=816.5
# [TRUE-COIN+Expert] Episode 3/40: epsilon=0.385, avg_return=363.189, avg_steps=861.8
# [TRUE-COIN+Expert] Episode 4/40: epsilon=0.377, avg_return=417.997, avg_steps=771.4
# [TRUE-COIN+Expert] Episode 5/40: epsilon=0.369, avg_return=388.604, avg_steps=818.5
# [TRUE-COIN+Expert] Episode 6/40: epsilon=0.362, avg_return=402.446, avg_steps=774.6
# [TRUE-COIN+Expert] Episode 7/40: epsilon=0.354, avg_return=406.527, avg_steps=789.3
# [TRUE-COIN+Expert] Episode 8/40: epsilon=0.346, avg_return=392.253, avg_steps=777.5
# [TRUE-COIN+Expert] Episode 9/40: epsilon=0.338, avg_return=381.440, avg_steps=782.0
# [TRUE-COIN+Expert] Episode 10/40: epsilon=0.331, avg_return=386.094, avg_steps=763.4
# [TRUE-COIN+Expert] Episode 11/40: epsilon=0.323, avg_return=380.732, avg_steps=774.6
# [TRUE-COIN+Expert] Episode 12/40: epsilon=0.315, avg_return=391.367, avg_steps=749.7
# [TRUE-COIN+Expert] Episode 13/40: epsilon=0.308, avg_return=392.020, avg_steps=751.3
# [TRUE-COIN+Expert] Episode 14/40: epsilon=0.300, avg_return=397.700, avg_steps=737.3
# [TRUE-COIN+Expert] Episode 15/40: epsilon=0.292, avg_return=433.244, avg_steps=689.7
# [TRUE-COIN+Expert] Episode 16/40: epsilon=0.285, avg_return=400.877, avg_steps=693.1
# [TRUE-COIN+Expert] Episode 17/40: epsilon=0.277, avg_return=408.936, avg_steps=709.3
# [TRUE-COIN+Expert] Episode 18/40: epsilon=0.269, avg_return=426.978, avg_steps=690.4
# [TRUE-COIN+Expert] Episode 19/40: epsilon=0.262, avg_return=398.978, avg_steps=705.1
# [TRUE-COIN+Expert] Episode 20/40: epsilon=0.254, avg_return=455.031, avg_steps=629.7
# [TRUE-COIN+Expert] Episode 21/40: epsilon=0.246, avg_return=425.808, avg_steps=650.8
# [TRUE-COIN+Expert] Episode 22/40: epsilon=0.238, avg_return=422.403, avg_steps=661.0
# [TRUE-COIN+Expert] Episode 23/40: epsilon=0.231, avg_return=434.178, avg_steps=631.8
# [TRUE-COIN+Expert] Episode 24/40: epsilon=0.223, avg_return=439.768, avg_steps=612.7
# [TRUE-COIN+Expert] Episode 25/40: epsilon=0.215, avg_return=423.325, avg_steps=649.8
# [TRUE-COIN+Expert] Episode 26/40: epsilon=0.208, avg_return=386.251, avg_steps=683.4
# [TRUE-COIN+Expert] Episode 27/40: epsilon=0.200, avg_return=410.838, avg_steps=628.6
# [TRUE-COIN+Expert] Episode 28/40: epsilon=0.192, avg_return=382.234, avg_steps=675.0
# [TRUE-COIN+Expert] Episode 29/40: epsilon=0.185, avg_return=441.136, avg_steps=613.4
# [TRUE-COIN+Expert] Episode 30/40: epsilon=0.177, avg_return=440.876, avg_steps=580.8
# [TRUE-COIN+Expert] Episode 31/40: epsilon=0.169, avg_return=441.900, avg_steps=595.3
# [TRUE-COIN+Expert] Episode 32/40: epsilon=0.162, avg_return=441.818, avg_steps=588.7
# [TRUE-COIN+Expert] Episode 33/40: epsilon=0.154, avg_return=433.905, avg_steps=580.2
# [TRUE-COIN+Expert] Episode 34/40: epsilon=0.146, avg_return=420.014, avg_steps=595.8
# [TRUE-COIN+Expert] Episode 35/40: epsilon=0.138, avg_return=463.450, avg_steps=537.6
# [TRUE-COIN+Expert] Episode 36/40: epsilon=0.131, avg_return=413.681, avg_steps=594.7
# [TRUE-COIN+Expert] Episode 37/40: epsilon=0.123, avg_return=455.387, avg_steps=566.8
# [TRUE-COIN+Expert] Episode 38/40: epsilon=0.115, avg_return=420.832, avg_steps=606.1
# [TRUE-COIN+Expert] Episode 39/40: epsilon=0.108, avg_return=474.344, avg_steps=531.8
# [TRUE-COIN+Expert] Episode 40/40: epsilon=0.100, avg_return=374.074, avg_steps=621.6
# Finished TRUE-COIN+Expert Q-learning with 4419395 learned state–action entries.
# [6/48] reach_rl=0.213 G_rl=4268.5 veh·hrs feasible=True params={'temperature': 0.1, 'lambda_live_cost': 1.0, 'visited_penalty_val': 3.0, 'epsilon_eval': 0.01, 'epsilon_start': 0.4, 'epsilon_end': 0.1, 'num_episodes_rl': 40, 'lambda_dr': 0.2, 'lambda_prog': 1.0, 'lambda_exp': 0.1, 'lambda_step': 0.1, 'time_scale': 5000, 'lambda_term': 600.0, 'lambda_miss': 300.0}
# SPA experiment with 1000 agents (north_south O/D)
# Used edges: 4948 / 16444
# FFA experiment with 1000 agents (north_south O/D)
# Used edges: 7366 / 16444
# Collected 32209 FF-expert (s,d,a,edge_id) steps from 333 agents.
# [FF expert] 4840 distinct expert edges.
# Initializing TRUE-COIN Q from Ford–Fulkerson expert trajectories...
# TRUE-COIN Q initialized on 32209 FF expert steps (unique state–action pairs: 31950).
# [TRUE-COIN+Expert] Episode 1/40: epsilon=0.400, avg_return=409.277, avg_steps=839.3
# [TRUE-COIN+Expert] Episode 2/40: epsilon=0.392, avg_return=403.066, avg_steps=816.5
# [TRUE-COIN+Expert] Episode 3/40: epsilon=0.385, avg_return=363.189, avg_steps=861.8
# [TRUE-COIN+Expert] Episode 4/40: epsilon=0.377, avg_return=417.997, avg_steps=771.4
# [TRUE-COIN+Expert] Episode 5/40: epsilon=0.369, avg_return=388.604, avg_steps=818.5
# [TRUE-COIN+Expert] Episode 6/40: epsilon=0.362, avg_return=402.446, avg_steps=774.6
# [TRUE-COIN+Expert] Episode 7/40: epsilon=0.354, avg_return=406.527, avg_steps=789.3
# [TRUE-COIN+Expert] Episode 8/40: epsilon=0.346, avg_return=392.253, avg_steps=777.5
# [TRUE-COIN+Expert] Episode 9/40: epsilon=0.338, avg_return=381.440, avg_steps=782.0
# [TRUE-COIN+Expert] Episode 10/40: epsilon=0.331, avg_return=386.094, avg_steps=763.4
# [TRUE-COIN+Expert] Episode 11/40: epsilon=0.323, avg_return=380.732, avg_steps=774.6
# [TRUE-COIN+Expert] Episode 12/40: epsilon=0.315, avg_return=391.367, avg_steps=749.7
# [TRUE-COIN+Expert] Episode 13/40: epsilon=0.308, avg_return=392.020, avg_steps=751.3
# [TRUE-COIN+Expert] Episode 14/40: epsilon=0.300, avg_return=397.700, avg_steps=737.3
# [TRUE-COIN+Expert] Episode 15/40: epsilon=0.292, avg_return=433.244, avg_steps=689.7
# [TRUE-COIN+Expert] Episode 16/40: epsilon=0.285, avg_return=400.877, avg_steps=693.1
# [TRUE-COIN+Expert] Episode 17/40: epsilon=0.277, avg_return=408.936, avg_steps=709.3
# [TRUE-COIN+Expert] Episode 18/40: epsilon=0.269, avg_return=426.978, avg_steps=690.4
# [TRUE-COIN+Expert] Episode 19/40: epsilon=0.262, avg_return=398.978, avg_steps=705.1
# [TRUE-COIN+Expert] Episode 20/40: epsilon=0.254, avg_return=455.031, avg_steps=629.7
# [TRUE-COIN+Expert] Episode 21/40: epsilon=0.246, avg_return=425.808, avg_steps=650.8
# [TRUE-COIN+Expert] Episode 22/40: epsilon=0.238, avg_return=422.403, avg_steps=661.0
# [TRUE-COIN+Expert] Episode 23/40: epsilon=0.231, avg_return=434.178, avg_steps=631.8
# [TRUE-COIN+Expert] Episode 24/40: epsilon=0.223, avg_return=439.768, avg_steps=612.7
# [TRUE-COIN+Expert] Episode 25/40: epsilon=0.215, avg_return=423.325, avg_steps=649.8
# [TRUE-COIN+Expert] Episode 26/40: epsilon=0.208, avg_return=386.251, avg_steps=683.4
# [TRUE-COIN+Expert] Episode 27/40: epsilon=0.200, avg_return=410.838, avg_steps=628.6
# [TRUE-COIN+Expert] Episode 28/40: epsilon=0.192, avg_return=382.234, avg_steps=675.0
# [TRUE-COIN+Expert] Episode 29/40: epsilon=0.185, avg_return=441.136, avg_steps=613.4
# [TRUE-COIN+Expert] Episode 30/40: epsilon=0.177, avg_return=440.876, avg_steps=580.8
# [TRUE-COIN+Expert] Episode 31/40: epsilon=0.169, avg_return=441.900, avg_steps=595.3
# [TRUE-COIN+Expert] Episode 32/40: epsilon=0.162, avg_return=441.818, avg_steps=588.7
# [TRUE-COIN+Expert] Episode 33/40: epsilon=0.154, avg_return=433.905, avg_steps=580.2
# [TRUE-COIN+Expert] Episode 34/40: epsilon=0.146, avg_return=420.014, avg_steps=595.8
# [TRUE-COIN+Expert] Episode 35/40: epsilon=0.138, avg_return=463.450, avg_steps=537.6
# [TRUE-COIN+Expert] Episode 36/40: epsilon=0.131, avg_return=413.681, avg_steps=594.7
# [TRUE-COIN+Expert] Episode 37/40: epsilon=0.123, avg_return=455.387, avg_steps=566.8
# [TRUE-COIN+Expert] Episode 38/40: epsilon=0.115, avg_return=420.832, avg_steps=606.1
# [TRUE-COIN+Expert] Episode 39/40: epsilon=0.108, avg_return=474.344, avg_steps=531.8
# [TRUE-COIN+Expert] Episode 40/40: epsilon=0.100, avg_return=374.074, avg_steps=621.6
# Finished TRUE-COIN+Expert Q-learning with 4419395 learned state–action entries.
# [7/48] reach_rl=0.210 G_rl=4287.6 veh·hrs feasible=True params={'temperature': 0.1, 'lambda_live_cost': 1.0, 'visited_penalty_val': 6.0, 'epsilon_eval': 0.01, 'epsilon_start': 0.4, 'epsilon_end': 0.1, 'num_episodes_rl': 40, 'lambda_dr': 0.2, 'lambda_prog': 1.0, 'lambda_exp': 0.1, 'lambda_step': 0.1, 'time_scale': 5000, 'lambda_term': 600.0, 'lambda_miss': 300.0}
# SPA experiment with 1000 agents (north_south O/D)
# Used edges: 4948 / 16444
# FFA experiment with 1000 agents (north_south O/D)
# Used edges: 7366 / 16444
# Collected 32209 FF-expert (s,d,a,edge_id) steps from 333 agents.
# [FF expert] 4840 distinct expert edges.
# Initializing TRUE-COIN Q from Ford–Fulkerson expert trajectories...
# TRUE-COIN Q initialized on 32209 FF expert steps (unique state–action pairs: 31950).
# [TRUE-COIN+Expert] Episode 1/40: epsilon=0.400, avg_return=409.277, avg_steps=839.3
# [TRUE-COIN+Expert] Episode 2/40: epsilon=0.392, avg_return=403.066, avg_steps=816.5
# [TRUE-COIN+Expert] Episode 3/40: epsilon=0.385, avg_return=363.189, avg_steps=861.8
# [TRUE-COIN+Expert] Episode 4/40: epsilon=0.377, avg_return=417.997, avg_steps=771.4
# [TRUE-COIN+Expert] Episode 5/40: epsilon=0.369, avg_return=388.604, avg_steps=818.5
# [TRUE-COIN+Expert] Episode 6/40: epsilon=0.362, avg_return=402.446, avg_steps=774.6
# [TRUE-COIN+Expert] Episode 7/40: epsilon=0.354, avg_return=406.527, avg_steps=789.3
# [TRUE-COIN+Expert] Episode 8/40: epsilon=0.346, avg_return=392.253, avg_steps=777.5
# [TRUE-COIN+Expert] Episode 9/40: epsilon=0.338, avg_return=381.440, avg_steps=782.0
# [TRUE-COIN+Expert] Episode 10/40: epsilon=0.331, avg_return=386.094, avg_steps=763.4
# [TRUE-COIN+Expert] Episode 11/40: epsilon=0.323, avg_return=380.732, avg_steps=774.6
# [TRUE-COIN+Expert] Episode 12/40: epsilon=0.315, avg_return=391.367, avg_steps=749.7
# [TRUE-COIN+Expert] Episode 13/40: epsilon=0.308, avg_return=392.020, avg_steps=751.3
# [TRUE-COIN+Expert] Episode 14/40: epsilon=0.300, avg_return=397.700, avg_steps=737.3
# [TRUE-COIN+Expert] Episode 15/40: epsilon=0.292, avg_return=433.244, avg_steps=689.7
# [TRUE-COIN+Expert] Episode 16/40: epsilon=0.285, avg_return=400.877, avg_steps=693.1
# [TRUE-COIN+Expert] Episode 17/40: epsilon=0.277, avg_return=408.936, avg_steps=709.3
# [TRUE-COIN+Expert] Episode 18/40: epsilon=0.269, avg_return=426.978, avg_steps=690.4
# [TRUE-COIN+Expert] Episode 19/40: epsilon=0.262, avg_return=398.978, avg_steps=705.1
# [TRUE-COIN+Expert] Episode 20/40: epsilon=0.254, avg_return=455.031, avg_steps=629.7
# [TRUE-COIN+Expert] Episode 21/40: epsilon=0.246, avg_return=425.808, avg_steps=650.8
# [TRUE-COIN+Expert] Episode 22/40: epsilon=0.238, avg_return=422.403, avg_steps=661.0
# [TRUE-COIN+Expert] Episode 23/40: epsilon=0.231, avg_return=434.178, avg_steps=631.8
# [TRUE-COIN+Expert] Episode 24/40: epsilon=0.223, avg_return=439.768, avg_steps=612.7
# [TRUE-COIN+Expert] Episode 25/40: epsilon=0.215, avg_return=423.325, avg_steps=649.8
# [TRUE-COIN+Expert] Episode 26/40: epsilon=0.208, avg_return=386.251, avg_steps=683.4
# [TRUE-COIN+Expert] Episode 27/40: epsilon=0.200, avg_return=410.838, avg_steps=628.6
# [TRUE-COIN+Expert] Episode 28/40: epsilon=0.192, avg_return=382.234, avg_steps=675.0
# [TRUE-COIN+Expert] Episode 29/40: epsilon=0.185, avg_return=441.136, avg_steps=613.4
# [TRUE-COIN+Expert] Episode 30/40: epsilon=0.177, avg_return=440.876, avg_steps=580.8
# [TRUE-COIN+Expert] Episode 31/40: epsilon=0.169, avg_return=441.900, avg_steps=595.3
# [TRUE-COIN+Expert] Episode 32/40: epsilon=0.162, avg_return=441.818, avg_steps=588.7
# [TRUE-COIN+Expert] Episode 33/40: epsilon=0.154, avg_return=433.905, avg_steps=580.2
# [TRUE-COIN+Expert] Episode 34/40: epsilon=0.146, avg_return=420.014, avg_steps=595.8
# [TRUE-COIN+Expert] Episode 35/40: epsilon=0.138, avg_return=463.450, avg_steps=537.6
# [TRUE-COIN+Expert] Episode 36/40: epsilon=0.131, avg_return=413.681, avg_steps=594.7
# [TRUE-COIN+Expert] Episode 37/40: epsilon=0.123, avg_return=455.387, avg_steps=566.8
# [TRUE-COIN+Expert] Episode 38/40: epsilon=0.115, avg_return=420.832, avg_steps=606.1
# [TRUE-COIN+Expert] Episode 39/40: epsilon=0.108, avg_return=474.344, avg_steps=531.8
# [TRUE-COIN+Expert] Episode 40/40: epsilon=0.100, avg_return=374.074, avg_steps=621.6
# Finished TRUE-COIN+Expert Q-learning with 4419395 learned state–action entries.
# [8/48] reach_rl=0.210 G_rl=4287.6 veh·hrs feasible=True params={'temperature': 0.1, 'lambda_live_cost': 1.0, 'visited_penalty_val': 10.0, 'epsilon_eval': 0.01, 'epsilon_start': 0.4, 'epsilon_end': 0.1, 'num_episodes_rl': 40, 'lambda_dr': 0.2, 'lambda_prog': 1.0, 'lambda_exp': 0.1, 'lambda_step': 0.1, 'time_scale': 5000, 'lambda_term': 600.0, 'lambda_miss': 300.0}
# SPA experiment with 1000 agents (north_south O/D)
# Used edges: 4948 / 16444
# FFA experiment with 1000 agents (north_south O/D)
# Used edges: 7366 / 16444
# Collected 32209 FF-expert (s,d,a,edge_id) steps from 333 agents.
# [FF expert] 4840 distinct expert edges.
# Initializing TRUE-COIN Q from Ford–Fulkerson expert trajectories...
# TRUE-COIN Q initialized on 32209 FF expert steps (unique state–action pairs: 31950).
# [TRUE-COIN+Expert] Episode 1/40: epsilon=0.400, avg_return=409.277, avg_steps=839.3
# [TRUE-COIN+Expert] Episode 2/40: epsilon=0.392, avg_return=403.066, avg_steps=816.5
# [TRUE-COIN+Expert] Episode 3/40: epsilon=0.385, avg_return=363.189, avg_steps=861.8
# [TRUE-COIN+Expert] Episode 4/40: epsilon=0.377, avg_return=417.997, avg_steps=771.4
# [TRUE-COIN+Expert] Episode 5/40: epsilon=0.369, avg_return=388.604, avg_steps=818.5
# [TRUE-COIN+Expert] Episode 6/40: epsilon=0.362, avg_return=402.446, avg_steps=774.6
# [TRUE-COIN+Expert] Episode 7/40: epsilon=0.354, avg_return=406.527, avg_steps=789.3
# [TRUE-COIN+Expert] Episode 8/40: epsilon=0.346, avg_return=392.253, avg_steps=777.5
# [TRUE-COIN+Expert] Episode 9/40: epsilon=0.338, avg_return=381.440, avg_steps=782.0
# [TRUE-COIN+Expert] Episode 10/40: epsilon=0.331, avg_return=386.094, avg_steps=763.4
# [TRUE-COIN+Expert] Episode 11/40: epsilon=0.323, avg_return=380.732, avg_steps=774.6
# [TRUE-COIN+Expert] Episode 12/40: epsilon=0.315, avg_return=391.367, avg_steps=749.7
# [TRUE-COIN+Expert] Episode 13/40: epsilon=0.308, avg_return=392.020, avg_steps=751.3
# [TRUE-COIN+Expert] Episode 14/40: epsilon=0.300, avg_return=397.700, avg_steps=737.3
# [TRUE-COIN+Expert] Episode 15/40: epsilon=0.292, avg_return=433.244, avg_steps=689.7
# [TRUE-COIN+Expert] Episode 16/40: epsilon=0.285, avg_return=400.877, avg_steps=693.1
# [TRUE-COIN+Expert] Episode 17/40: epsilon=0.277, avg_return=408.936, avg_steps=709.3
# [TRUE-COIN+Expert] Episode 18/40: epsilon=0.269, avg_return=426.978, avg_steps=690.4
# [TRUE-COIN+Expert] Episode 19/40: epsilon=0.262, avg_return=398.978, avg_steps=705.1
# [TRUE-COIN+Expert] Episode 20/40: epsilon=0.254, avg_return=455.031, avg_steps=629.7
# [TRUE-COIN+Expert] Episode 21/40: epsilon=0.246, avg_return=425.808, avg_steps=650.8
# [TRUE-COIN+Expert] Episode 22/40: epsilon=0.238, avg_return=422.403, avg_steps=661.0
# [TRUE-COIN+Expert] Episode 23/40: epsilon=0.231, avg_return=434.178, avg_steps=631.8
# [TRUE-COIN+Expert] Episode 24/40: epsilon=0.223, avg_return=439.768, avg_steps=612.7
# [TRUE-COIN+Expert] Episode 25/40: epsilon=0.215, avg_return=423.325, avg_steps=649.8
# [TRUE-COIN+Expert] Episode 26/40: epsilon=0.208, avg_return=386.251, avg_steps=683.4
# [TRUE-COIN+Expert] Episode 27/40: epsilon=0.200, avg_return=410.838, avg_steps=628.6
# [TRUE-COIN+Expert] Episode 28/40: epsilon=0.192, avg_return=382.234, avg_steps=675.0
# [TRUE-COIN+Expert] Episode 29/40: epsilon=0.185, avg_return=441.136, avg_steps=613.4
# [TRUE-COIN+Expert] Episode 30/40: epsilon=0.177, avg_return=440.876, avg_steps=580.8
# [TRUE-COIN+Expert] Episode 31/40: epsilon=0.169, avg_return=441.900, avg_steps=595.3
# [TRUE-COIN+Expert] Episode 32/40: epsilon=0.162, avg_return=441.818, avg_steps=588.7
# [TRUE-COIN+Expert] Episode 33/40: epsilon=0.154, avg_return=433.905, avg_steps=580.2
# [TRUE-COIN+Expert] Episode 34/40: epsilon=0.146, avg_return=420.014, avg_steps=595.8
# [TRUE-COIN+Expert] Episode 35/40: epsilon=0.138, avg_return=463.450, avg_steps=537.6
# [TRUE-COIN+Expert] Episode 36/40: epsilon=0.131, avg_return=413.681, avg_steps=594.7
# [TRUE-COIN+Expert] Episode 37/40: epsilon=0.123, avg_return=455.387, avg_steps=566.8
# [TRUE-COIN+Expert] Episode 38/40: epsilon=0.115, avg_return=420.832, avg_steps=606.1
# [TRUE-COIN+Expert] Episode 39/40: epsilon=0.108, avg_return=474.344, avg_steps=531.8
# [TRUE-COIN+Expert] Episode 40/40: epsilon=0.100, avg_return=374.074, avg_steps=621.6
# Finished TRUE-COIN+Expert Q-learning with 4419395 learned state–action entries.
# [9/48] reach_rl=0.200 G_rl=4166.8 veh·hrs feasible=True params={'temperature': 0.1, 'lambda_live_cost': 2.0, 'visited_penalty_val': 1.0, 'epsilon_eval': 0.01, 'epsilon_start': 0.4, 'epsilon_end': 0.1, 'num_episodes_rl': 40, 'lambda_dr': 0.2, 'lambda_prog': 1.0, 'lambda_exp': 0.1, 'lambda_step': 0.1, 'time_scale': 5000, 'lambda_term': 600.0, 'lambda_miss': 300.0}
# SPA experiment with 1000 agents (north_south O/D)
# Used edges: 4948 / 16444
# FFA experiment with 1000 agents (north_south O/D)
# Used edges: 7366 / 16444
# Collected 32209 FF-expert (s,d,a,edge_id) steps from 333 agents.
# [FF expert] 4840 distinct expert edges.
# Initializing TRUE-COIN Q from Ford–Fulkerson expert trajectories...
# TRUE-COIN Q initialized on 32209 FF expert steps (unique state–action pairs: 31950).
# [TRUE-COIN+Expert] Episode 1/40: epsilon=0.400, avg_return=409.277, avg_steps=839.3
# [TRUE-COIN+Expert] Episode 2/40: epsilon=0.392, avg_return=403.066, avg_steps=816.5
# [TRUE-COIN+Expert] Episode 3/40: epsilon=0.385, avg_return=363.189, avg_steps=861.8
# [TRUE-COIN+Expert] Episode 4/40: epsilon=0.377, avg_return=417.997, avg_steps=771.4
# [TRUE-COIN+Expert] Episode 5/40: epsilon=0.369, avg_return=388.604, avg_steps=818.5
# [TRUE-COIN+Expert] Episode 6/40: epsilon=0.362, avg_return=402.446, avg_steps=774.6
# [TRUE-COIN+Expert] Episode 7/40: epsilon=0.354, avg_return=406.527, avg_steps=789.3
# [TRUE-COIN+Expert] Episode 8/40: epsilon=0.346, avg_return=392.253, avg_steps=777.5
# [TRUE-COIN+Expert] Episode 9/40: epsilon=0.338, avg_return=381.440, avg_steps=782.0
# [TRUE-COIN+Expert] Episode 10/40: epsilon=0.331, avg_return=386.094, avg_steps=763.4
# [TRUE-COIN+Expert] Episode 11/40: epsilon=0.323, avg_return=380.732, avg_steps=774.6
# [TRUE-COIN+Expert] Episode 12/40: epsilon=0.315, avg_return=391.367, avg_steps=749.7
# [TRUE-COIN+Expert] Episode 13/40: epsilon=0.308, avg_return=392.020, avg_steps=751.3
# [TRUE-COIN+Expert] Episode 14/40: epsilon=0.300, avg_return=397.700, avg_steps=737.3
# [TRUE-COIN+Expert] Episode 15/40: epsilon=0.292, avg_return=433.244, avg_steps=689.7
# [TRUE-COIN+Expert] Episode 16/40: epsilon=0.285, avg_return=400.877, avg_steps=693.1
# [TRUE-COIN+Expert] Episode 17/40: epsilon=0.277, avg_return=408.936, avg_steps=709.3
# [TRUE-COIN+Expert] Episode 18/40: epsilon=0.269, avg_return=426.978, avg_steps=690.4
# [TRUE-COIN+Expert] Episode 19/40: epsilon=0.262, avg_return=398.978, avg_steps=705.1
# [TRUE-COIN+Expert] Episode 20/40: epsilon=0.254, avg_return=455.031, avg_steps=629.7
# [TRUE-COIN+Expert] Episode 21/40: epsilon=0.246, avg_return=425.808, avg_steps=650.8
# [TRUE-COIN+Expert] Episode 22/40: epsilon=0.238, avg_return=422.403, avg_steps=661.0
# [TRUE-COIN+Expert] Episode 23/40: epsilon=0.231, avg_return=434.178, avg_steps=631.8
# [TRUE-COIN+Expert] Episode 24/40: epsilon=0.223, avg_return=439.768, avg_steps=612.7
# [TRUE-COIN+Expert] Episode 25/40: epsilon=0.215, avg_return=423.325, avg_steps=649.8
# [TRUE-COIN+Expert] Episode 26/40: epsilon=0.208, avg_return=386.251, avg_steps=683.4
# [TRUE-COIN+Expert] Episode 27/40: epsilon=0.200, avg_return=410.838, avg_steps=628.6
# [TRUE-COIN+Expert] Episode 28/40: epsilon=0.192, avg_return=382.234, avg_steps=675.0
# [TRUE-COIN+Expert] Episode 29/40: epsilon=0.185, avg_return=441.136, avg_steps=613.4
# [TRUE-COIN+Expert] Episode 30/40: epsilon=0.177, avg_return=440.876, avg_steps=580.8
# [TRUE-COIN+Expert] Episode 31/40: epsilon=0.169, avg_return=441.900, avg_steps=595.3
# [TRUE-COIN+Expert] Episode 32/40: epsilon=0.162, avg_return=441.818, avg_steps=588.7
# [TRUE-COIN+Expert] Episode 33/40: epsilon=0.154, avg_return=433.905, avg_steps=580.2
# [TRUE-COIN+Expert] Episode 34/40: epsilon=0.146, avg_return=420.014, avg_steps=595.8
# [TRUE-COIN+Expert] Episode 35/40: epsilon=0.138, avg_return=463.450, avg_steps=537.6
# [TRUE-COIN+Expert] Episode 36/40: epsilon=0.131, avg_return=413.681, avg_steps=594.7
# [TRUE-COIN+Expert] Episode 37/40: epsilon=0.123, avg_return=455.387, avg_steps=566.8
# [TRUE-COIN+Expert] Episode 38/40: epsilon=0.115, avg_return=420.832, avg_steps=606.1
# [TRUE-COIN+Expert] Episode 39/40: epsilon=0.108, avg_return=474.344, avg_steps=531.8
# [TRUE-COIN+Expert] Episode 40/40: epsilon=0.100, avg_return=374.074, avg_steps=621.6
# Finished TRUE-COIN+Expert Q-learning with 4419395 learned state–action entries.
# [10/48] reach_rl=0.202 G_rl=4170.3 veh·hrs feasible=True params={'temperature': 0.1, 'lambda_live_cost': 2.0, 'visited_penalty_val': 3.0, 'epsilon_eval': 0.01, 'epsilon_start': 0.4, 'epsilon_end': 0.1, 'num_episodes_rl': 40, 'lambda_dr': 0.2, 'lambda_prog': 1.0, 'lambda_exp': 0.1, 'lambda_step': 0.1, 'time_scale': 5000, 'lambda_term': 600.0, 'lambda_miss': 300.0}
# SPA experiment with 1000 agents (north_south O/D)
# Used edges: 4948 / 16444
# FFA experiment with 1000 agents (north_south O/D)
# Used edges: 7366 / 16444
# Collected 32209 FF-expert (s,d,a,edge_id) steps from 333 agents.
# [FF expert] 4840 distinct expert edges.
# Initializing TRUE-COIN Q from Ford–Fulkerson expert trajectories...
# TRUE-COIN Q initialized on 32209 FF expert steps (unique state–action pairs: 31950).
# [TRUE-COIN+Expert] Episode 1/40: epsilon=0.400, avg_return=409.277, avg_steps=839.3
# [TRUE-COIN+Expert] Episode 2/40: epsilon=0.392, avg_return=403.066, avg_steps=816.5
# [TRUE-COIN+Expert] Episode 3/40: epsilon=0.385, avg_return=363.189, avg_steps=861.8
# [TRUE-COIN+Expert] Episode 4/40: epsilon=0.377, avg_return=417.997, avg_steps=771.4
# [TRUE-COIN+Expert] Episode 5/40: epsilon=0.369, avg_return=388.604, avg_steps=818.5
# [TRUE-COIN+Expert] Episode 6/40: epsilon=0.362, avg_return=402.446, avg_steps=774.6
# [TRUE-COIN+Expert] Episode 7/40: epsilon=0.354, avg_return=406.527, avg_steps=789.3
# [TRUE-COIN+Expert] Episode 8/40: epsilon=0.346, avg_return=392.253, avg_steps=777.5
# [TRUE-COIN+Expert] Episode 9/40: epsilon=0.338, avg_return=381.440, avg_steps=782.0
# [TRUE-COIN+Expert] Episode 10/40: epsilon=0.331, avg_return=386.094, avg_steps=763.4
# [TRUE-COIN+Expert] Episode 11/40: epsilon=0.323, avg_return=380.732, avg_steps=774.6
# [TRUE-COIN+Expert] Episode 12/40: epsilon=0.315, avg_return=391.367, avg_steps=749.7
# [TRUE-COIN+Expert] Episode 13/40: epsilon=0.308, avg_return=392.020, avg_steps=751.3
# [TRUE-COIN+Expert] Episode 14/40: epsilon=0.300, avg_return=397.700, avg_steps=737.3
# [TRUE-COIN+Expert] Episode 15/40: epsilon=0.292, avg_return=433.244, avg_steps=689.7
# [TRUE-COIN+Expert] Episode 16/40: epsilon=0.285, avg_return=400.877, avg_steps=693.1
# [TRUE-COIN+Expert] Episode 17/40: epsilon=0.277, avg_return=408.936, avg_steps=709.3
# [TRUE-COIN+Expert] Episode 18/40: epsilon=0.269, avg_return=426.978, avg_steps=690.4
# [TRUE-COIN+Expert] Episode 19/40: epsilon=0.262, avg_return=398.978, avg_steps=705.1
# [TRUE-COIN+Expert] Episode 20/40: epsilon=0.254, avg_return=455.031, avg_steps=629.7
# [TRUE-COIN+Expert] Episode 21/40: epsilon=0.246, avg_return=425.808, avg_steps=650.8
# [TRUE-COIN+Expert] Episode 22/40: epsilon=0.238, avg_return=422.403, avg_steps=661.0
# [TRUE-COIN+Expert] Episode 23/40: epsilon=0.231, avg_return=434.178, avg_steps=631.8
# [TRUE-COIN+Expert] Episode 24/40: epsilon=0.223, avg_return=439.768, avg_steps=612.7
# [TRUE-COIN+Expert] Episode 25/40: epsilon=0.215, avg_return=423.325, avg_steps=649.8
# [TRUE-COIN+Expert] Episode 26/40: epsilon=0.208, avg_return=386.251, avg_steps=683.4
# [TRUE-COIN+Expert] Episode 27/40: epsilon=0.200, avg_return=410.838, avg_steps=628.6
# [TRUE-COIN+Expert] Episode 28/40: epsilon=0.192, avg_return=382.234, avg_steps=675.0
# [TRUE-COIN+Expert] Episode 29/40: epsilon=0.185, avg_return=441.136, avg_steps=613.4
# [TRUE-COIN+Expert] Episode 30/40: epsilon=0.177, avg_return=440.876, avg_steps=580.8
# [TRUE-COIN+Expert] Episode 31/40: epsilon=0.169, avg_return=441.900, avg_steps=595.3
# [TRUE-COIN+Expert] Episode 32/40: epsilon=0.162, avg_return=441.818, avg_steps=588.7
# [TRUE-COIN+Expert] Episode 33/40: epsilon=0.154, avg_return=433.905, avg_steps=580.2
# [TRUE-COIN+Expert] Episode 34/40: epsilon=0.146, avg_return=420.014, avg_steps=595.8
# [TRUE-COIN+Expert] Episode 35/40: epsilon=0.138, avg_return=463.450, avg_steps=537.6
# [TRUE-COIN+Expert] Episode 36/40: epsilon=0.131, avg_return=413.681, avg_steps=594.7
# [TRUE-COIN+Expert] Episode 37/40: epsilon=0.123, avg_return=455.387, avg_steps=566.8
# [TRUE-COIN+Expert] Episode 38/40: epsilon=0.115, avg_return=420.832, avg_steps=606.1
# [TRUE-COIN+Expert] Episode 39/40: epsilon=0.108, avg_return=474.344, avg_steps=531.8
# [TRUE-COIN+Expert] Episode 40/40: epsilon=0.100, avg_return=374.074, avg_steps=621.6
# Finished TRUE-COIN+Expert Q-learning with 4419395 learned state–action entries.
# [11/48] reach_rl=0.202 G_rl=4170.3 veh·hrs feasible=True params={'temperature': 0.1, 'lambda_live_cost': 2.0, 'visited_penalty_val': 6.0, 'epsilon_eval': 0.01, 'epsilon_start': 0.4, 'epsilon_end': 0.1, 'num_episodes_rl': 40, 'lambda_dr': 0.2, 'lambda_prog': 1.0, 'lambda_exp': 0.1, 'lambda_step': 0.1, 'time_scale': 5000, 'lambda_term': 600.0, 'lambda_miss': 300.0}
# SPA experiment with 1000 agents (north_south O/D)
# Used edges: 4948 / 16444
# FFA experiment with 1000 agents (north_south O/D)
# Used edges: 7366 / 16444
# Collected 32209 FF-expert (s,d,a,edge_id) steps from 333 agents.
# [FF expert] 4840 distinct expert edges.
# Initializing TRUE-COIN Q from Ford–Fulkerson expert trajectories...
# TRUE-COIN Q initialized on 32209 FF expert steps (unique state–action pairs: 31950).
# [TRUE-COIN+Expert] Episode 1/40: epsilon=0.400, avg_return=409.277, avg_steps=839.3
# [TRUE-COIN+Expert] Episode 2/40: epsilon=0.392, avg_return=403.066, avg_steps=816.5
# [TRUE-COIN+Expert] Episode 3/40: epsilon=0.385, avg_return=363.189, avg_steps=861.8
# [TRUE-COIN+Expert] Episode 4/40: epsilon=0.377, avg_return=417.997, avg_steps=771.4
# [TRUE-COIN+Expert] Episode 5/40: epsilon=0.369, avg_return=388.604, avg_steps=818.5
# [TRUE-COIN+Expert] Episode 6/40: epsilon=0.362, avg_return=402.446, avg_steps=774.6
# [TRUE-COIN+Expert] Episode 7/40: epsilon=0.354, avg_return=406.527, avg_steps=789.3
# [TRUE-COIN+Expert] Episode 8/40: epsilon=0.346, avg_return=392.253, avg_steps=777.5
# [TRUE-COIN+Expert] Episode 9/40: epsilon=0.338, avg_return=381.440, avg_steps=782.0
# [TRUE-COIN+Expert] Episode 10/40: epsilon=0.331, avg_return=386.094, avg_steps=763.4
# ...
# [TRUE-COIN+Expert] Episode 19/40: epsilon=0.262, avg_return=398.978, avg_steps=705.1
# [TRUE-COIN+Expert] Episode 20/40: epsilon=0.254, avg_return=455.031, avg_steps=629.7
# [TRUE-COIN+Expert] Episode 21/40: epsilon=0.246, avg_return=425.808, avg_steps=650.8
# [TRUE-COIN+Expert] Episode 22/40: epsilon=0.238, avg_return=422.403, avg_steps=661.0
# [TRUE-COIN+Expert] Episode 23/40: epsilon=0.231, avg_return=434.178, avg_steps=631.8
# [TRUE-COIN+Expert] Episode 24/40: epsilon=0.223, avg_return=439.768, avg_steps=612.7
# [TRUE-COIN+Expert] Episode 25/40: epsilon=0.215, avg_return=423.325, avg_steps=649.8
# [TRUE-COIN+Expert] Episode 26/40: epsilon=0.208, avg_return=386.251, avg_steps=683.4
# [TRUE-COIN+Expert] Episode 27/40: epsilon=0.200, avg_return=410.838, avg_steps=628.6
# [TRUE-COIN+Expert] Episode 28/40: epsilon=0.192, avg_return=382.234, avg_steps=675.0
# [TRUE-COIN+Expert] Episode 29/40: epsilon=0.185, avg_return=441.136, avg_steps=613.4
# [TRUE-COIN+Expert] Episode 30/40: epsilon=0.177, avg_return=440.876, avg_steps=580.8
# [TRUE-COIN+Expert] Episode 31/40: epsilon=0.169, avg_return=441.900, avg_steps=595.3
# [TRUE-COIN+Expert] Episode 32/40: epsilon=0.162, avg_return=441.818, avg_steps=588.7
# [TRUE-COIN+Expert] Episode 33/40: epsilon=0.154, avg_return=433.905, avg_steps=580.2
# [TRUE-COIN+Expert] Episode 34/40: epsilon=0.146, avg_return=420.014, avg_steps=595.8
# [TRUE-COIN+Expert] Episode 35/40: epsilon=0.138, avg_return=463.450, avg_steps=537.6
# [TRUE-COIN+Expert] Episode 36/40: epsilon=0.131, avg_return=413.681, avg_steps=594.7
# [TRUE-COIN+Expert] Episode 37/40: epsilon=0.123, avg_return=455.387, avg_steps=566.8
# [TRUE-COIN+Expert] Episode 38/40: epsilon=0.115, avg_return=420.832, avg_steps=606.1
# [TRUE-COIN+Expert] Episode 39/40: epsilon=0.108, avg_return=474.344, avg_steps=531.8
# [TRUE-COIN+Expert] Episode 40/40: epsilon=0.100, avg_return=374.074, avg_steps=621.6
# Finished TRUE-COIN+Expert Q-learning with 4419395 learned state–action entries.
# [45/48] reach_rl=0.098 G_rl=4619.8 veh·hrs feasible=False params={'temperature': 0.6, 'lambda_live_cost': 2.5, 'visited_penalty_val': 1.0, 'epsilon_eval': 0.01, 'epsilon_start': 0.4, 'epsilon_end': 0.1, 'num_episodes_rl': 40, 'lambda_dr': 0.2, 'lambda_prog': 1.0, 'lambda_exp': 0.1, 'lambda_step': 0.1, 'time_scale': 5000, 'lambda_term': 600.0, 'lambda_miss': 300.0}
# SPA experiment with 1000 agents (north_south O/D)
# Used edges: 4948 / 16444
# FFA experiment with 1000 agents (north_south O/D)
# Used edges: 7366 / 16444
# Collected 32209 FF-expert (s,d,a,edge_id) steps from 333 agents.
# [FF expert] 4840 distinct expert edges.
# Initializing TRUE-COIN Q from Ford–Fulkerson expert trajectories...
# TRUE-COIN Q initialized on 32209 FF expert steps (unique state–action pairs: 31950).
# [TRUE-COIN+Expert] Episode 1/40: epsilon=0.400, avg_return=409.277, avg_steps=839.3
# [TRUE-COIN+Expert] Episode 2/40: epsilon=0.392, avg_return=403.066, avg_steps=816.5
# [TRUE-COIN+Expert] Episode 3/40: epsilon=0.385, avg_return=363.189, avg_steps=861.8
# [TRUE-COIN+Expert] Episode 4/40: epsilon=0.377, avg_return=417.997, avg_steps=771.4
# [TRUE-COIN+Expert] Episode 5/40: epsilon=0.369, avg_return=388.604, avg_steps=818.5
# [TRUE-COIN+Expert] Episode 6/40: epsilon=0.362, avg_return=402.446, avg_steps=774.6
# [TRUE-COIN+Expert] Episode 7/40: epsilon=0.354, avg_return=406.527, avg_steps=789.3
# [TRUE-COIN+Expert] Episode 8/40: epsilon=0.346, avg_return=392.253, avg_steps=777.5
# [TRUE-COIN+Expert] Episode 9/40: epsilon=0.338, avg_return=381.440, avg_steps=782.0
# [TRUE-COIN+Expert] Episode 10/40: epsilon=0.331, avg_return=386.094, avg_steps=763.4
# [TRUE-COIN+Expert] Episode 11/40: epsilon=0.323, avg_return=380.732, avg_steps=774.6
# [TRUE-COIN+Expert] Episode 12/40: epsilon=0.315, avg_return=391.367, avg_steps=749.7
# [TRUE-COIN+Expert] Episode 13/40: epsilon=0.308, avg_return=392.020, avg_steps=751.3
# [TRUE-COIN+Expert] Episode 14/40: epsilon=0.300, avg_return=397.700, avg_steps=737.3
# [TRUE-COIN+Expert] Episode 15/40: epsilon=0.292, avg_return=433.244, avg_steps=689.7
# [TRUE-COIN+Expert] Episode 16/40: epsilon=0.285, avg_return=400.877, avg_steps=693.1
# [TRUE-COIN+Expert] Episode 17/40: epsilon=0.277, avg_return=408.936, avg_steps=709.3
# [TRUE-COIN+Expert] Episode 18/40: epsilon=0.269, avg_return=426.978, avg_steps=690.4
# [TRUE-COIN+Expert] Episode 19/40: epsilon=0.262, avg_return=398.978, avg_steps=705.1
# [TRUE-COIN+Expert] Episode 20/40: epsilon=0.254, avg_return=455.031, avg_steps=629.7
# [TRUE-COIN+Expert] Episode 21/40: epsilon=0.246, avg_return=425.808, avg_steps=650.8
# [TRUE-COIN+Expert] Episode 22/40: epsilon=0.238, avg_return=422.403, avg_steps=661.0
# [TRUE-COIN+Expert] Episode 23/40: epsilon=0.231, avg_return=434.178, avg_steps=631.8
# [TRUE-COIN+Expert] Episode 24/40: epsilon=0.223, avg_return=439.768, avg_steps=612.7
# [TRUE-COIN+Expert] Episode 25/40: epsilon=0.215, avg_return=423.325, avg_steps=649.8
# [TRUE-COIN+Expert] Episode 26/40: epsilon=0.208, avg_return=386.251, avg_steps=683.4
# [TRUE-COIN+Expert] Episode 27/40: epsilon=0.200, avg_return=410.838, avg_steps=628.6
# [TRUE-COIN+Expert] Episode 28/40: epsilon=0.192, avg_return=382.234, avg_steps=675.0
# [TRUE-COIN+Expert] Episode 29/40: epsilon=0.185, avg_return=441.136, avg_steps=613.4
# [TRUE-COIN+Expert] Episode 30/40: epsilon=0.177, avg_return=440.876, avg_steps=580.8
# [TRUE-COIN+Expert] Episode 31/40: epsilon=0.169, avg_return=441.900, avg_steps=595.3
# [TRUE-COIN+Expert] Episode 32/40: epsilon=0.162, avg_return=441.818, avg_steps=588.7
# [TRUE-COIN+Expert] Episode 33/40: epsilon=0.154, avg_return=433.905, avg_steps=580.2
# [TRUE-COIN+Expert] Episode 34/40: epsilon=0.146, avg_return=420.014, avg_steps=595.8
# [TRUE-COIN+Expert] Episode 35/40: epsilon=0.138, avg_return=463.450, avg_steps=537.6
# [TRUE-COIN+Expert] Episode 36/40: epsilon=0.131, avg_return=413.681, avg_steps=594.7
# [TRUE-COIN+Expert] Episode 37/40: epsilon=0.123, avg_return=455.387, avg_steps=566.8
# [TRUE-COIN+Expert] Episode 38/40: epsilon=0.115, avg_return=420.832, avg_steps=606.1
# [TRUE-COIN+Expert] Episode 39/40: epsilon=0.108, avg_return=474.344, avg_steps=531.8
# [TRUE-COIN+Expert] Episode 40/40: epsilon=0.100, avg_return=374.074, avg_steps=621.6
# Finished TRUE-COIN+Expert Q-learning with 4419395 learned state–action entries.
# [46/48] reach_rl=0.116 G_rl=4593.4 veh·hrs feasible=True params={'temperature': 0.6, 'lambda_live_cost': 2.5, 'visited_penalty_val': 3.0, 'epsilon_eval': 0.01, 'epsilon_start': 0.4, 'epsilon_end': 0.1, 'num_episodes_rl': 40, 'lambda_dr': 0.2, 'lambda_prog': 1.0, 'lambda_exp': 0.1, 'lambda_step': 0.1, 'time_scale': 5000, 'lambda_term': 600.0, 'lambda_miss': 300.0}
# SPA experiment with 1000 agents (north_south O/D)
# Used edges: 4948 / 16444
# FFA experiment with 1000 agents (north_south O/D)
# Used edges: 7366 / 16444
# Collected 32209 FF-expert (s,d,a,edge_id) steps from 333 agents.
# [FF expert] 4840 distinct expert edges.
# Initializing TRUE-COIN Q from Ford–Fulkerson expert trajectories...
# TRUE-COIN Q initialized on 32209 FF expert steps (unique state–action pairs: 31950).
# [TRUE-COIN+Expert] Episode 1/40: epsilon=0.400, avg_return=409.277, avg_steps=839.3
# [TRUE-COIN+Expert] Episode 2/40: epsilon=0.392, avg_return=403.066, avg_steps=816.5
# [TRUE-COIN+Expert] Episode 3/40: epsilon=0.385, avg_return=363.189, avg_steps=861.8
# [TRUE-COIN+Expert] Episode 4/40: epsilon=0.377, avg_return=417.997, avg_steps=771.4
# [TRUE-COIN+Expert] Episode 5/40: epsilon=0.369, avg_return=388.604, avg_steps=818.5
# [TRUE-COIN+Expert] Episode 6/40: epsilon=0.362, avg_return=402.446, avg_steps=774.6
# [TRUE-COIN+Expert] Episode 7/40: epsilon=0.354, avg_return=406.527, avg_steps=789.3
# [TRUE-COIN+Expert] Episode 8/40: epsilon=0.346, avg_return=392.253, avg_steps=777.5
# [TRUE-COIN+Expert] Episode 9/40: epsilon=0.338, avg_return=381.440, avg_steps=782.0
# [TRUE-COIN+Expert] Episode 10/40: epsilon=0.331, avg_return=386.094, avg_steps=763.4
# [TRUE-COIN+Expert] Episode 11/40: epsilon=0.323, avg_return=380.732, avg_steps=774.6
# [TRUE-COIN+Expert] Episode 12/40: epsilon=0.315, avg_return=391.367, avg_steps=749.7
# [TRUE-COIN+Expert] Episode 13/40: epsilon=0.308, avg_return=392.020, avg_steps=751.3
# [TRUE-COIN+Expert] Episode 14/40: epsilon=0.300, avg_return=397.700, avg_steps=737.3
# [TRUE-COIN+Expert] Episode 15/40: epsilon=0.292, avg_return=433.244, avg_steps=689.7
# [TRUE-COIN+Expert] Episode 16/40: epsilon=0.285, avg_return=400.877, avg_steps=693.1
# [TRUE-COIN+Expert] Episode 17/40: epsilon=0.277, avg_return=408.936, avg_steps=709.3
# [TRUE-COIN+Expert] Episode 18/40: epsilon=0.269, avg_return=426.978, avg_steps=690.4
# [TRUE-COIN+Expert] Episode 19/40: epsilon=0.262, avg_return=398.978, avg_steps=705.1
# [TRUE-COIN+Expert] Episode 20/40: epsilon=0.254, avg_return=455.031, avg_steps=629.7
# [TRUE-COIN+Expert] Episode 21/40: epsilon=0.246, avg_return=425.808, avg_steps=650.8
# [TRUE-COIN+Expert] Episode 22/40: epsilon=0.238, avg_return=422.403, avg_steps=661.0
# [TRUE-COIN+Expert] Episode 23/40: epsilon=0.231, avg_return=434.178, avg_steps=631.8
# [TRUE-COIN+Expert] Episode 24/40: epsilon=0.223, avg_return=439.768, avg_steps=612.7
# [TRUE-COIN+Expert] Episode 25/40: epsilon=0.215, avg_return=423.325, avg_steps=649.8
# [TRUE-COIN+Expert] Episode 26/40: epsilon=0.208, avg_return=386.251, avg_steps=683.4
# [TRUE-COIN+Expert] Episode 27/40: epsilon=0.200, avg_return=410.838, avg_steps=628.6
# [TRUE-COIN+Expert] Episode 28/40: epsilon=0.192, avg_return=382.234, avg_steps=675.0
# [TRUE-COIN+Expert] Episode 29/40: epsilon=0.185, avg_return=441.136, avg_steps=613.4
# [TRUE-COIN+Expert] Episode 30/40: epsilon=0.177, avg_return=440.876, avg_steps=580.8
# [TRUE-COIN+Expert] Episode 31/40: epsilon=0.169, avg_return=441.900, avg_steps=595.3
# [TRUE-COIN+Expert] Episode 32/40: epsilon=0.162, avg_return=441.818, avg_steps=588.7
# [TRUE-COIN+Expert] Episode 33/40: epsilon=0.154, avg_return=433.905, avg_steps=580.2
# [TRUE-COIN+Expert] Episode 34/40: epsilon=0.146, avg_return=420.014, avg_steps=595.8
# [TRUE-COIN+Expert] Episode 35/40: epsilon=0.138, avg_return=463.450, avg_steps=537.6
# [TRUE-COIN+Expert] Episode 36/40: epsilon=0.131, avg_return=413.681, avg_steps=594.7
# [TRUE-COIN+Expert] Episode 37/40: epsilon=0.123, avg_return=455.387, avg_steps=566.8
# [TRUE-COIN+Expert] Episode 38/40: epsilon=0.115, avg_return=420.832, avg_steps=606.1
# [TRUE-COIN+Expert] Episode 39/40: epsilon=0.108, avg_return=474.344, avg_steps=531.8
# [TRUE-COIN+Expert] Episode 40/40: epsilon=0.100, avg_return=374.074, avg_steps=621.6
# Finished TRUE-COIN+Expert Q-learning with 4419395 learned state–action entries.
# [47/48] reach_rl=0.132 G_rl=4536.1 veh·hrs feasible=True params={'temperature': 0.6, 'lambda_live_cost': 2.5, 'visited_penalty_val': 6.0, 'epsilon_eval': 0.01, 'epsilon_start': 0.4, 'epsilon_end': 0.1, 'num_episodes_rl': 40, 'lambda_dr': 0.2, 'lambda_prog': 1.0, 'lambda_exp': 0.1, 'lambda_step': 0.1, 'time_scale': 5000, 'lambda_term': 600.0, 'lambda_miss': 300.0}
# SPA experiment with 1000 agents (north_south O/D)
# Used edges: 4948 / 16444
# FFA experiment with 1000 agents (north_south O/D)
# Used edges: 7366 / 16444
# Collected 32209 FF-expert (s,d,a,edge_id) steps from 333 agents.
# [FF expert] 4840 distinct expert edges.
# Initializing TRUE-COIN Q from Ford–Fulkerson expert trajectories...
# TRUE-COIN Q initialized on 32209 FF expert steps (unique state–action pairs: 31950).
# [TRUE-COIN+Expert] Episode 1/40: epsilon=0.400, avg_return=409.277, avg_steps=839.3
# [TRUE-COIN+Expert] Episode 2/40: epsilon=0.392, avg_return=403.066, avg_steps=816.5
# [TRUE-COIN+Expert] Episode 3/40: epsilon=0.385, avg_return=363.189, avg_steps=861.8
# [TRUE-COIN+Expert] Episode 4/40: epsilon=0.377, avg_return=417.997, avg_steps=771.4
# [TRUE-COIN+Expert] Episode 5/40: epsilon=0.369, avg_return=388.604, avg_steps=818.5
# [TRUE-COIN+Expert] Episode 6/40: epsilon=0.362, avg_return=402.446, avg_steps=774.6
# [TRUE-COIN+Expert] Episode 7/40: epsilon=0.354, avg_return=406.527, avg_steps=789.3
# [TRUE-COIN+Expert] Episode 8/40: epsilon=0.346, avg_return=392.253, avg_steps=777.5
# [TRUE-COIN+Expert] Episode 9/40: epsilon=0.338, avg_return=381.440, avg_steps=782.0
# [TRUE-COIN+Expert] Episode 10/40: epsilon=0.331, avg_return=386.094, avg_steps=763.4
# [TRUE-COIN+Expert] Episode 11/40: epsilon=0.323, avg_return=380.732, avg_steps=774.6
# [TRUE-COIN+Expert] Episode 12/40: epsilon=0.315, avg_return=391.367, avg_steps=749.7
# [TRUE-COIN+Expert] Episode 13/40: epsilon=0.308, avg_return=392.020, avg_steps=751.3
# [TRUE-COIN+Expert] Episode 14/40: epsilon=0.300, avg_return=397.700, avg_steps=737.3
# [TRUE-COIN+Expert] Episode 15/40: epsilon=0.292, avg_return=433.244, avg_steps=689.7
# [TRUE-COIN+Expert] Episode 16/40: epsilon=0.285, avg_return=400.877, avg_steps=693.1
# [TRUE-COIN+Expert] Episode 17/40: epsilon=0.277, avg_return=408.936, avg_steps=709.3
# [TRUE-COIN+Expert] Episode 18/40: epsilon=0.269, avg_return=426.978, avg_steps=690.4
# [TRUE-COIN+Expert] Episode 19/40: epsilon=0.262, avg_return=398.978, avg_steps=705.1
# [TRUE-COIN+Expert] Episode 20/40: epsilon=0.254, avg_return=455.031, avg_steps=629.7
# [TRUE-COIN+Expert] Episode 21/40: epsilon=0.246, avg_return=425.808, avg_steps=650.8
# [TRUE-COIN+Expert] Episode 22/40: epsilon=0.238, avg_return=422.403, avg_steps=661.0
# [TRUE-COIN+Expert] Episode 23/40: epsilon=0.231, avg_return=434.178, avg_steps=631.8
# [TRUE-COIN+Expert] Episode 24/40: epsilon=0.223, avg_return=439.768, avg_steps=612.7
# [TRUE-COIN+Expert] Episode 25/40: epsilon=0.215, avg_return=423.325, avg_steps=649.8
# [TRUE-COIN+Expert] Episode 26/40: epsilon=0.208, avg_return=386.251, avg_steps=683.4
# [TRUE-COIN+Expert] Episode 27/40: epsilon=0.200, avg_return=410.838, avg_steps=628.6
# [TRUE-COIN+Expert] Episode 28/40: epsilon=0.192, avg_return=382.234, avg_steps=675.0
# [TRUE-COIN+Expert] Episode 29/40: epsilon=0.185, avg_return=441.136, avg_steps=613.4
# [TRUE-COIN+Expert] Episode 30/40: epsilon=0.177, avg_return=440.876, avg_steps=580.8
# [TRUE-COIN+Expert] Episode 31/40: epsilon=0.169, avg_return=441.900, avg_steps=595.3
# [TRUE-COIN+Expert] Episode 32/40: epsilon=0.162, avg_return=441.818, avg_steps=588.7
# [TRUE-COIN+Expert] Episode 33/40: epsilon=0.154, avg_return=433.905, avg_steps=580.2
# [TRUE-COIN+Expert] Episode 34/40: epsilon=0.146, avg_return=420.014, avg_steps=595.8
# [TRUE-COIN+Expert] Episode 35/40: epsilon=0.138, avg_return=463.450, avg_steps=537.6
# [TRUE-COIN+Expert] Episode 36/40: epsilon=0.131, avg_return=413.681, avg_steps=594.7
# [TRUE-COIN+Expert] Episode 37/40: epsilon=0.123, avg_return=455.387, avg_steps=566.8
# [TRUE-COIN+Expert] Episode 38/40: epsilon=0.115, avg_return=420.832, avg_steps=606.1
# [TRUE-COIN+Expert] Episode 39/40: epsilon=0.108, avg_return=474.344, avg_steps=531.8
# [TRUE-COIN+Expert] Episode 40/40: epsilon=0.100, avg_return=374.074, avg_steps=621.6
# Finished TRUE-COIN+Expert Q-learning with 4419395 learned state–action entries.
# [48/48] reach_rl=0.128 G_rl=4526.4 veh·hrs feasible=True params={'temperature': 0.6, 'lambda_live_cost': 2.5, 'visited_penalty_val': 10.0, 'epsilon_eval': 0.01, 'epsilon_start': 0.4, 'epsilon_end': 0.1, 'num_episodes_rl': 40, 'lambda_dr': 0.2, 'lambda_prog': 1.0, 'lambda_exp': 0.1, 'lambda_step': 0.1, 'time_scale': 5000, 'lambda_term': 600.0, 'lambda_miss': 300.0}
#
# === Grid search done ===
# Total trials: 48
# Feasible trials: 44
#
# === Best feasible config (min G_ff_rl) ===
# trial                           14
# elapsed_s                80.288723
# reach_spa                    0.912
# reach_ff                     0.908
# reach_ff_rl                   0.23
# G_spa_vehhrs            232.245023
# G_ff_vehhrs              297.46848
# G_ff_rl_vehhrs         4073.802056
# feasible                      True
# temperature                    0.1
# lambda_live_cost               2.5
# visited_penalty_val            3.0
# epsilon_eval                  0.01
# epsilon_start                  0.4
# epsilon_end                    0.1
# num_episodes_rl                 40
# lambda_dr                      0.2
# lambda_prog                    1.0
# lambda_exp                     0.1
# lambda_step                    0.1
# time_scale                    5000
# lambda_term                  600.0
# lambda_miss                  300.0
# Name: 13, dtype: object

# %% [markdown]
# ## Best setup run

# %%
# =========================
# RUN TRUE COIN + EXPERT EXPERIMENT (BEST GRIDSEARCH CONFIG)
# =========================

if best is None:
    raise ValueError("No feasible config found in grid search (best is None).")

random.seed(26)
np.random.seed(26)
num_agents = 1000
num_agents_expert = num_agents // 3
horizon_s = 3600.0
od_mode = "north_south"

# Extract only the hyperparams that belong in the experiment call
BEST_PARAMS = best.to_dict()

# (Optional) drop non-hyperparam columns if they exist in `best`
for k in [
    "trial", "elapsed_s", "reach_spa", "reach_ff", "reach_ff_rl",
    "G_spa_vehhrs", "G_ff_vehhrs", "G_ff_rl_vehhrs", "feasible", "error"
]:
    BEST_PARAMS.pop(k, None)

(
    agents_spa,  flows_spa,  G_spa,
    agents_ff,   flows_ff,   G_ff,
    agents_ff_rl, flows_ff_rl, G_ff_rl,
    Q_ff_rl,
) = run_ff_expert_coin_rl_experiment(
    manhattan_network,

    # fixed experiment settings
    num_agents_baseline=num_agents,
    num_agents_expert=num_agents_expert,
    num_agents_eval_rl=num_agents,
    od_mode=od_mode,
    steps_per_agent=1500,
    horizon_s=horizon_s,

    # best hyperparameters from grid search
    **BEST_PARAMS,

    # your preference
    debug=True,
)

# --- package results neatly ---
spa_results   = (agents_spa,    flows_spa,    G_spa)
ff_results    = (agents_ff,     flows_ff,     G_ff)
ff_rl_results = (agents_ff_rl,  flows_ff_rl,  G_ff_rl)

results = {
    "SPA":                 spa_results,
    "FF":                  ff_results,
    "FF-RL (TRUE COIN + expert)": ff_rl_results,
}
# Out:
# SPA experiment with 1000 agents (north_south O/D)
# Used edges: 4948 / 16444
# FFA experiment with 1000 agents (north_south O/D)
# Used edges: 7366 / 16444
# Collected 32209 FF-expert (s,d,a,edge_id) steps from 333 agents.
# [FF expert] 4840 distinct expert edges.
# Initializing TRUE-COIN Q from Ford–Fulkerson expert trajectories...
# TRUE-COIN Q initialized on 32209 FF expert steps (unique state–action pairs: 31950).
# [TRUE-COIN+Expert] Episode 1/40: epsilon=0.400, avg_return=409.277, avg_steps=839.3
#
# [Episode 1 reward breakdown] n=279499
#   delta_G   mean= 11.5325   min= 0.1183   max= 390.4225
#   dr        mean=-0.0005   min=-0.0156   max=-0.0000
#   exp       mean= 0.0406   min= 0.0000   max= 0.1000
#   miss      mean=-0.0547   min=-300.0000   max= 0.0000
#   prog      mean=-0.0032   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.6054   min= 0.0000   max= 600.0000
#   total     mean= 0.4876   min=-301.1007   max= 601.0000
# [ΔG percentiles] p50=5.970 p90=24.949 p99=86.398 max=390.423
# delta_G mean=11.53, dr mean=-0.0005
# [debug] avg |prog| term per step ≈ 0.003170
# [debug] avg dr term per step      ≈ -0.000461
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 2/40: epsilon=0.392, avg_return=403.066, avg_steps=816.5
#
# [Episode 2 reward breakdown] n=271902
#   delta_G   mean= 11.6895   min= 0.1183   max= 390.4225
#   dr        mean=-0.0005   min=-0.0156   max=-0.0000
#   exp       mean= 0.0408   min= 0.0000   max= 0.1000
#   miss      mean=-0.0596   min=-300.0000   max= 0.0000
#   prog      mean=-0.0028   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.6157   min= 0.0000   max= 600.0000
#   total     mean= 0.4936   min=-300.4934   max= 601.0000
# [ΔG percentiles] p50=5.987 p90=25.969 p99=92.859 max=390.423
# delta_G mean=11.69, dr mean=-0.0005
# [debug] avg |prog| term per step ≈ 0.002782
# [debug] avg dr term per step      ≈ -0.000468
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 3/40: epsilon=0.385, avg_return=363.189, avg_steps=861.8
#
# [Episode 3 reward breakdown] n=286979
#   delta_G   mean= 11.1218   min= 0.1183   max= 390.4225
#   dr        mean=-0.0004   min=-0.0156   max=-0.0000
#   exp       mean= 0.0400   min= 0.0000   max= 0.1000
#   miss      mean=-0.0700   min=-300.0000   max= 0.0000
#   prog      mean=-0.0042   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.5561   min= 0.0000   max= 600.0000
#   total     mean= 0.4214   min=-301.1021   max= 601.0000
# [ΔG percentiles] p50=5.873 p90=24.669 p99=80.809 max=390.423
# delta_G mean=11.12, dr mean=-0.0004
# [debug] avg |prog| term per step ≈ 0.004173
# [debug] avg dr term per step      ≈ -0.000445
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 4/40: epsilon=0.377, avg_return=417.997, avg_steps=771.4
#
# [Episode 4 reward breakdown] n=256865
#   delta_G   mean= 11.9573   min= 0.1183   max= 390.4225
#   dr        mean=-0.0005   min=-0.0156   max=-0.0000
#   exp       mean= 0.0388   min= 0.0000   max= 0.1000
#   miss      mean=-0.0572   min=-300.0000   max= 0.0000
#   prog      mean=-0.0026   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.6634   min= 0.0000   max= 600.0000
#   total     mean= 0.5419   min=-301.1009   max= 601.0000
# [ΔG percentiles] p50=5.998 p90=26.260 p99=111.000 max=390.423
# delta_G mean=11.96, dr mean=-0.0005
# [debug] avg |prog| term per step ≈ 0.002597
# [debug] avg dr term per step      ≈ -0.000478
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 5/40: epsilon=0.369, avg_return=388.604, avg_steps=818.5
#
# [Episode 5 reward breakdown] n=272564
#   delta_G   mean= 12.1339   min= 0.1183   max= 390.4225
#   dr        mean=-0.0005   min=-0.0156   max=-0.0000
#   exp       mean= 0.0427   min= 0.0000   max= 0.1000
#   miss      mean=-0.0660   min=-300.0000   max= 0.0000
#   prog      mean=-0.0024   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.6010   min= 0.0000   max= 600.0000
#   total     mean= 0.4748   min=-301.1010   max= 601.0000
# [ΔG percentiles] p50=5.792 p90=26.287 p99=130.093 max=390.423
# delta_G mean=12.13, dr mean=-0.0005
# [debug] avg |prog| term per step ≈ 0.002377
# [debug] avg dr term per step      ≈ -0.000485
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 6/40: epsilon=0.362, avg_return=402.446, avg_steps=774.6
#
# [Episode 6 reward breakdown] n=257932
#   delta_G   mean= 11.4714   min= 0.1183   max= 390.4225
#   dr        mean=-0.0005   min=-0.0156   max=-0.0000
#   exp       mean= 0.0410   min= 0.0000   max= 0.1000
#   miss      mean=-0.0640   min=-300.0000   max= 0.0000
#   prog      mean=-0.0036   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.6467   min= 0.0000   max= 600.0000
#   total     mean= 0.5196   min=-301.0004   max= 601.0000
# [ΔG percentiles] p50=5.877 p90=26.398 p99=78.194 max=390.423
# delta_G mean=11.47, dr mean=-0.0005
# [debug] avg |prog| term per step ≈ 0.003645
# [debug] avg dr term per step      ≈ -0.000459
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 7/40: epsilon=0.354, avg_return=406.527, avg_steps=789.3
#
# [Episode 7 reward breakdown] n=262827
#   delta_G   mean= 11.6392   min= 0.2165   max= 390.4225
#   dr        mean=-0.0005   min=-0.0156   max=-0.0000
#   exp       mean= 0.0388   min= 0.0000   max= 0.1000
#   miss      mean=-0.0605   min=-300.0000   max= 0.0000
#   prog      mean=-0.0020   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.6392   min= 0.0000   max= 600.0000
#   total     mean= 0.5151   min=-300.4974   max= 601.0000
# [ΔG percentiles] p50=6.218 p90=25.800 p99=84.860 max=390.423
# delta_G mean=11.64, dr mean=-0.0005
# [debug] avg |prog| term per step ≈ 0.001966
# [debug] avg dr term per step      ≈ -0.000466
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 8/40: epsilon=0.346, avg_return=392.253, avg_steps=777.5
#
# [Episode 8 reward breakdown] n=258914
#   delta_G   mean= 12.3530   min= 0.1183   max= 390.4225
#   dr        mean=-0.0005   min=-0.0156   max=-0.0000
#   exp       mean= 0.0409   min= 0.0000   max= 0.1000
#   miss      mean=-0.0684   min=-300.0000   max= 0.0000
#   prog      mean=-0.0025   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.6350   min= 0.0000   max= 600.0000
#   total     mean= 0.5045   min=-301.1014   max= 601.0000
# [ΔG percentiles] p50=5.998 p90=28.279 p99=130.093 max=390.423
# delta_G mean=12.35, dr mean=-0.0005
# [debug] avg |prog| term per step ≈ 0.002510
# [debug] avg dr term per step      ≈ -0.000494
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 9/40: epsilon=0.338, avg_return=381.440, avg_steps=782.0
#
# [Episode 9 reward breakdown] n=260392
#   delta_G   mean= 11.7500   min= 0.1183   max= 390.4225
#   dr        mean=-0.0005   min=-0.0156   max=-0.0000
#   exp       mean= 0.0393   min= 0.0000   max= 0.1000
#   miss      mean=-0.0714   min=-300.0000   max= 0.0000
#   prog      mean=-0.0040   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.6244   min= 0.0000   max= 600.0000
#   total     mean= 0.4878   min=-301.1008   max= 601.0000
# [ΔG percentiles] p50=6.131 p90=26.505 p99=89.083 max=390.423
# delta_G mean=11.75, dr mean=-0.0005
# [debug] avg |prog| term per step ≈ 0.004037
# [debug] avg dr term per step      ≈ -0.000470
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 10/40: epsilon=0.331, avg_return=386.094, avg_steps=763.4
#
# [Episode 10 reward breakdown] n=254227
#   delta_G   mean= 12.0576   min= 0.1537   max= 390.4225
#   dr        mean=-0.0005   min=-0.0156   max=-0.0000
#   exp       mean= 0.0396   min= 0.0000   max= 0.1000
#   miss      mean=-0.0720   min=-300.0000   max= 0.0000
#   prog      mean=-0.0033   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.6419   min= 0.0000   max= 600.0000
#   total     mean= 0.5057   min=-301.1005   max= 601.0000
# [ΔG percentiles] p50=6.398 p90=28.634 p99=75.520 max=390.423
# delta_G mean=12.06, dr mean=-0.0005
# [debug] avg |prog| term per step ≈ 0.003339
# [debug] avg dr term per step      ≈ -0.000482
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 11/40: epsilon=0.323, avg_return=380.732, avg_steps=774.6
#
# [Episode 11 reward breakdown] n=257936
#   delta_G   mean= 12.3358   min= 0.1537   max= 390.4225
#   dr        mean=-0.0005   min=-0.0156   max=-0.0000
#   exp       mean= 0.0398   min= 0.0000   max= 0.1000
#   miss      mean=-0.0733   min=-300.0000   max= 0.0000
#   prog      mean=-0.0026   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.6281   min= 0.0000   max= 600.0000
#   total     mean= 0.4915   min=-301.0007   max= 601.0000
# [ΔG percentiles] p50=6.021 p90=28.348 p99=111.042 max=390.423
# delta_G mean=12.34, dr mean=-0.0005
# [debug] avg |prog| term per step ≈ 0.002593
# [debug] avg dr term per step      ≈ -0.000493
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 12/40: epsilon=0.315, avg_return=391.367, avg_steps=749.7
#
# [Episode 12 reward breakdown] n=249647
#   delta_G   mean= 11.0407   min= 0.1183   max= 390.4225
#   dr        mean=-0.0004   min=-0.0156   max=-0.0000
#   exp       mean= 0.0426   min= 0.0000   max= 0.1000
#   miss      mean=-0.0721   min=-300.0000   max= 0.0000
#   prog      mean=-0.0042   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.6561   min= 0.0000   max= 600.0000
#   total     mean= 0.5220   min=-301.1005   max= 601.0000
# [ΔG percentiles] p50=5.778 p90=24.561 p99=80.809 max=390.423
# delta_G mean=11.04, dr mean=-0.0004
# [debug] avg |prog| term per step ≈ 0.004156
# [debug] avg dr term per step      ≈ -0.000442
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 13/40: epsilon=0.308, avg_return=392.020, avg_steps=751.3
#
# [Episode 13 reward breakdown] n=250187
#   delta_G   mean= 12.0493   min= 0.1183   max= 390.4225
#   dr        mean=-0.0005   min=-0.0156   max=-0.0000
#   exp       mean= 0.0409   min= 0.0000   max= 0.1000
#   miss      mean=-0.0719   min=-300.0000   max= 0.0000
#   prog      mean=-0.0014   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.6547   min= 0.0000   max= 600.0000
#   total     mean= 0.5218   min=-301.1006   max= 601.0000
# [ΔG percentiles] p50=6.007 p90=26.389 p99=111.001 max=390.423
# delta_G mean=12.05, dr mean=-0.0005
# [debug] avg |prog| term per step ≈ 0.001373
# [debug] avg dr term per step      ≈ -0.000482
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 14/40: epsilon=0.300, avg_return=397.700, avg_steps=737.3
#
# [Episode 14 reward breakdown] n=245525
#   delta_G   mean= 12.9006   min= 0.1183   max= 390.4225
#   dr        mean=-0.0005   min=-0.0156   max=-0.0000
#   exp       mean= 0.0417   min= 0.0000   max= 0.1000
#   miss      mean=-0.0709   min=-300.0000   max= 0.0000
#   prog      mean=-0.0030   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.6720   min= 0.0000   max= 600.0000
#   total     mean= 0.5394   min=-301.1042   max= 601.0000
# [ΔG percentiles] p50=6.082 p90=28.904 p99=137.770 max=390.423
# delta_G mean=12.90, dr mean=-0.0005
# [debug] avg |prog| term per step ≈ 0.002990
# [debug] avg dr term per step      ≈ -0.000516
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 15/40: epsilon=0.292, avg_return=433.244, avg_steps=689.7
#
# [Episode 15 reward breakdown] n=229655
#   delta_G   mean= 11.7336   min= 0.1183   max= 390.4225
#   dr        mean=-0.0005   min=-0.0156   max=-0.0000
#   exp       mean= 0.0433   min= 0.0000   max= 0.1000
#   miss      mean=-0.0614   min=-300.0000   max= 0.0000
#   prog      mean=-0.0005   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.7472   min= 0.0000   max= 600.0000
#   total     mean= 0.6282   min=-301.1005   max= 601.0000
# [ΔG percentiles] p50=6.012 p90=27.447 p99=87.036 max=390.423
# delta_G mean=11.73, dr mean=-0.0005
# [debug] avg |prog| term per step ≈ 0.000463
# [debug] avg dr term per step      ≈ -0.000469
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 16/40: epsilon=0.285, avg_return=400.877, avg_steps=693.1
#
# [Episode 16 reward breakdown] n=230808
#   delta_G   mean= 11.7094   min= 0.1183   max= 390.4225
#   dr        mean=-0.0005   min=-0.0156   max=-0.0000
#   exp       mean= 0.0397   min= 0.0000   max= 0.1000
#   miss      mean=-0.0754   min=-300.0000   max= 0.0000
#   prog      mean=-0.0003   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.7149   min= 0.0000   max= 600.0000
#   total     mean= 0.5784   min=-301.1007   max= 601.0000
# [ΔG percentiles] p50=5.888 p90=24.373 p99=111.011 max=390.423
# delta_G mean=11.71, dr mean=-0.0005
# [debug] avg |prog| term per step ≈ 0.000335
# [debug] avg dr term per step      ≈ -0.000468
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 17/40: epsilon=0.277, avg_return=408.936, avg_steps=709.3
#
# [Episode 17 reward breakdown] n=236196
#   delta_G   mean= 11.4285   min= 0.1183   max= 390.4225
#   dr        mean=-0.0005   min=-0.0156   max=-0.0000
#   exp       mean= 0.0415   min= 0.0000   max= 0.1000
#   miss      mean=-0.0699   min=-300.0000   max= 0.0000
#   prog      mean=-0.0009   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.7062   min= 0.0000   max= 600.0000
#   total     mean= 0.5765   min=-301.1010   max= 601.0000
# [ΔG percentiles] p50=5.687 p90=26.505 p99=76.491 max=390.423
# delta_G mean=11.43, dr mean=-0.0005
# [debug] avg |prog| term per step ≈ 0.000862
# [debug] avg dr term per step      ≈ -0.000457
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 18/40: epsilon=0.269, avg_return=426.978, avg_steps=690.4
#
# [Episode 18 reward breakdown] n=229905
#   delta_G   mean= 10.8983   min= 0.1183   max= 390.4225
#   dr        mean=-0.0004   min=-0.0156   max=-0.0000
#   exp       mean= 0.0427   min= 0.0000   max= 0.1000
#   miss      mean=-0.0639   min=-300.0000   max= 0.0000
#   prog      mean=-0.0010   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.7412   min= 0.0000   max= 600.0000
#   total     mean= 0.6184   min=-301.1005   max= 601.0000
# [ΔG percentiles] p50=5.726 p90=25.923 p99=72.625 max=390.423
# delta_G mean=10.90, dr mean=-0.0004
# [debug] avg |prog| term per step ≈ 0.001026
# [debug] avg dr term per step      ≈ -0.000436
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 19/40: epsilon=0.262, avg_return=398.978, avg_steps=705.1
#
# [Episode 19 reward breakdown] n=234792
#   delta_G   mean= 11.6025   min= 0.1183   max= 390.4225
#   dr        mean=-0.0005   min=-0.0156   max=-0.0000
#   exp       mean= 0.0424   min= 0.0000   max= 0.1000
#   miss      mean=-0.0754   min=-300.0000   max= 0.0000
#   prog      mean=-0.0009   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.7002   min= 0.0000   max= 600.0000
#   total     mean= 0.5659   min=-301.1010   max= 601.0000
# [ΔG percentiles] p50=5.792 p90=24.586 p99=132.249 max=390.423
# delta_G mean=11.60, dr mean=-0.0005
# [debug] avg |prog| term per step ≈ 0.000864
# [debug] avg dr term per step      ≈ -0.000464
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 20/40: epsilon=0.254, avg_return=455.031, avg_steps=629.7
#
# [Episode 20 reward breakdown] n=209677
#   delta_G   mean= 11.2213   min= 0.1183   max= 390.4225
#   dr        mean=-0.0004   min=-0.0156   max=-0.0000
#   exp       mean= 0.0424   min= 0.0000   max= 0.1000
#   miss      mean=-0.0572   min=-300.0000   max= 0.0000
#   prog      mean=-0.0005   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.8384   min= 0.0000   max= 600.0000
#   total     mean= 0.7227   min=-300.2028   max= 601.0000
# [ΔG percentiles] p50=5.904 p90=25.119 p99=80.809 max=390.423
# delta_G mean=11.22, dr mean=-0.0004
# [debug] avg |prog| term per step ≈ 0.000542
# [debug] avg dr term per step      ≈ -0.000449
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 21/40: epsilon=0.246, avg_return=425.808, avg_steps=650.8
#
# [Episode 21 reward breakdown] n=216731
#   delta_G   mean= 11.4589   min= 0.1183   max= 390.4225
#   dr        mean=-0.0005   min=-0.0156   max=-0.0000
#   exp       mean= 0.0453   min= 0.0000   max= 0.1000
#   miss      mean=-0.0706   min=-300.0000   max= 0.0000
#   prog      mean=-0.0007   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.7807   min= 0.0000   max= 600.0000
#   total     mean= 0.6542   min=-301.1021   max= 601.0000
# [ΔG percentiles] p50=5.701 p90=26.926 p99=75.821 max=390.423
# delta_G mean=11.46, dr mean=-0.0005
# [debug] avg |prog| term per step ≈ 0.000668
# [debug] avg dr term per step      ≈ -0.000458
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 22/40: epsilon=0.238, avg_return=422.403, avg_steps=661.0
#
# [Episode 22 reward breakdown] n=220100
#   delta_G   mean= 11.0966   min= 0.1183   max= 390.4225
#   dr        mean=-0.0004   min=-0.0156   max=-0.0000
#   exp       mean= 0.0449   min= 0.0000   max= 0.1000
#   miss      mean=-0.0709   min=-300.0000   max= 0.0000
#   prog      mean=-0.0006   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.7660   min= 0.0000   max= 600.0000
#   total     mean= 0.6391   min=-301.1007   max= 601.0000
# [ΔG percentiles] p50=5.571 p90=25.659 p99=77.451 max=390.423
# delta_G mean=11.10, dr mean=-0.0004
# [debug] avg |prog| term per step ≈ 0.000562
# [debug] avg dr term per step      ≈ -0.000444
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 23/40: epsilon=0.231, avg_return=434.178, avg_steps=631.8
#
# [Episode 23 reward breakdown] n=210382
#   delta_G   mean= 11.6016   min= 0.1183   max= 390.4225
#   dr        mean=-0.0005   min=-0.0156   max=-0.0000
#   exp       mean= 0.0432   min= 0.0000   max= 0.1000
#   miss      mean=-0.0684   min=-300.0000   max= 0.0000
#   prog      mean= 0.0002   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.8128   min= 0.0000   max= 600.0000
#   total     mean= 0.6872   min=-301.1012   max= 601.0000
# [ΔG percentiles] p50=6.017 p90=28.158 p99=72.625 max=390.423
# delta_G mean=11.60, dr mean=-0.0005
# [debug] avg |prog| term per step ≈ 0.000168
# [debug] avg dr term per step      ≈ -0.000464
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 24/40: epsilon=0.223, avg_return=439.768, avg_steps=612.7
#
# [Episode 24 reward breakdown] n=204043
#   delta_G   mean= 11.0692   min= 0.1183   max= 390.4225
#   dr        mean=-0.0004   min=-0.0156   max=-0.0000
#   exp       mean= 0.0457   min= 0.0000   max= 0.1000
#   miss      mean=-0.0691   min=-300.0000   max= 0.0000
#   prog      mean= 0.0005   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.8410   min= 0.0000   max= 600.0000
#   total     mean= 0.7177   min=-301.0004   max= 601.0000
# [ΔG percentiles] p50=5.676 p90=25.921 p99=72.625 max=390.423
# delta_G mean=11.07, dr mean=-0.0004
# [debug] avg |prog| term per step ≈ 0.000524
# [debug] avg dr term per step      ≈ -0.000443
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 25/40: epsilon=0.215, avg_return=423.325, avg_steps=649.8
#
# [Episode 25 reward breakdown] n=216367
#   delta_G   mean= 11.9623   min= 0.1183   max= 390.4225
#   dr        mean=-0.0005   min=-0.0156   max=-0.0000
#   exp       mean= 0.0436   min= 0.0000   max= 0.1000
#   miss      mean=-0.0721   min=-300.0000   max= 0.0000
#   prog      mean= 0.0013   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.7792   min= 0.0000   max= 600.0000
#   total     mean= 0.6515   min=-301.1010   max= 601.0000
# [ΔG percentiles] p50=5.978 p90=26.865 p99=111.002 max=390.423
# delta_G mean=11.96, dr mean=-0.0005
# [debug] avg |prog| term per step ≈ 0.001257
# [debug] avg dr term per step      ≈ -0.000478
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 26/40: epsilon=0.208, avg_return=386.251, avg_steps=683.4
#
# [Episode 26 reward breakdown] n=227566
#   delta_G   mean= 11.5062   min= 0.1183   max= 390.4225
#   dr        mean=-0.0005   min=-0.0156   max=-0.0000
#   exp       mean= 0.0419   min= 0.0000   max= 0.1000
#   miss      mean=-0.0844   min=-300.0000   max= 0.0000
#   prog      mean=-0.0011   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.7092   min= 0.0000   max= 600.0000
#   total     mean= 0.5652   min=-301.1010   max= 601.0000
# [ΔG percentiles] p50=6.008 p90=26.238 p99=79.039 max=390.423
# delta_G mean=11.51, dr mean=-0.0005
# [debug] avg |prog| term per step ≈ 0.001117
# [debug] avg dr term per step      ≈ -0.000460
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 27/40: epsilon=0.200, avg_return=410.838, avg_steps=628.6
#
# [Episode 27 reward breakdown] n=209328
#   delta_G   mean= 12.6966   min= 0.1183   max= 390.4225
#   dr        mean=-0.0005   min=-0.0156   max=-0.0000
#   exp       mean= 0.0412   min= 0.0000   max= 0.1000
#   miss      mean=-0.0803   min=-300.0000   max= 0.0000
#   prog      mean=-0.0008   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.7940   min= 0.0000   max= 600.0000
#   total     mean= 0.6536   min=-301.1006   max= 601.0000
# [ΔG percentiles] p50=6.045 p90=28.339 p99=137.770 max=390.423
# delta_G mean=12.70, dr mean=-0.0005
# [debug] avg |prog| term per step ≈ 0.000804
# [debug] avg dr term per step      ≈ -0.000508
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 28/40: epsilon=0.192, avg_return=382.234, avg_steps=675.0
#
# [Episode 28 reward breakdown] n=224776
#   delta_G   mean= 11.9421   min= 0.1183   max= 390.4225
#   dr        mean=-0.0005   min=-0.0156   max=-0.0000
#   exp       mean= 0.0425   min= 0.0000   max= 0.1000
#   miss      mean=-0.0881   min=-300.0000   max= 0.0000
#   prog      mean=-0.0003   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.7127   min= 0.0000   max= 600.0000
#   total     mean= 0.5663   min=-301.1007   max= 601.0000
# [ΔG percentiles] p50=5.800 p90=26.682 p99=92.129 max=390.423
# delta_G mean=11.94, dr mean=-0.0005
# [debug] avg |prog| term per step ≈ 0.000332
# [debug] avg dr term per step      ≈ -0.000478
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 29/40: epsilon=0.185, avg_return=441.136, avg_steps=613.4
#
# [Episode 29 reward breakdown] n=204268
#   delta_G   mean= 11.4291   min= 0.2165   max= 390.4225
#   dr        mean=-0.0005   min=-0.0156   max=-0.0000
#   exp       mean= 0.0480   min= 0.0000   max= 0.1000
#   miss      mean=-0.0690   min=-300.0000   max= 0.0000
#   prog      mean= 0.0005   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.8401   min= 0.0000   max= 600.0000
#   total     mean= 0.7191   min=-301.1003   max= 601.0000
# [ΔG percentiles] p50=5.506 p90=25.095 p99=137.770 max=390.423
# delta_G mean=11.43, dr mean=-0.0005
# [debug] avg |prog| term per step ≈ 0.000526
# [debug] avg dr term per step      ≈ -0.000457
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 30/40: epsilon=0.177, avg_return=440.876, avg_steps=580.8
#
# [Episode 30 reward breakdown] n=193395
#   delta_G   mean= 10.9696   min= 0.1183   max= 390.4225
#   dr        mean=-0.0004   min=-0.0156   max=-0.0000
#   exp       mean= 0.0453   min= 0.0000   max= 0.1000
#   miss      mean=-0.0729   min=-300.0000   max= 0.0000
#   prog      mean=-0.0001   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.8873   min= 0.0000   max= 600.0000
#   total     mean= 0.7591   min=-301.1002   max= 601.0000
# [ΔG percentiles] p50=5.499 p90=23.852 p99=87.248 max=390.423
# delta_G mean=10.97, dr mean=-0.0004
# [debug] avg |prog| term per step ≈ 0.000115
# [debug] avg dr term per step      ≈ -0.000439
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 31/40: epsilon=0.169, avg_return=441.900, avg_steps=595.3
#
# [Episode 31 reward breakdown] n=198248
#   delta_G   mean= 10.6379   min= 0.1183   max= 390.4225
#   dr        mean=-0.0004   min=-0.0156   max=-0.0000
#   exp       mean= 0.0467   min= 0.0000   max= 0.1000
#   miss      mean=-0.0711   min=-300.0000   max= 0.0000
#   prog      mean= 0.0016   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.8656   min= 0.0000   max= 600.0000
#   total     mean= 0.7423   min=-300.5584   max= 601.0000
# [ΔG percentiles] p50=5.616 p90=25.085 p99=71.075 max=390.423
# delta_G mean=10.64, dr mean=-0.0004
# [debug] avg |prog| term per step ≈ 0.001579
# [debug] avg dr term per step      ≈ -0.000426
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 32/40: epsilon=0.162, avg_return=441.818, avg_steps=588.7
#
# [Episode 32 reward breakdown] n=196023
#   delta_G   mean= 11.6368   min= 0.1183   max= 390.4225
#   dr        mean=-0.0005   min=-0.0156   max=-0.0000
#   exp       mean= 0.0457   min= 0.0000   max= 0.1000
#   miss      mean=-0.0719   min=-300.0000   max= 0.0000
#   prog      mean= 0.0019   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.8754   min= 0.0000   max= 600.0000
#   total     mean= 0.7506   min=-300.4370   max= 601.0000
# [ΔG percentiles] p50=5.666 p90=24.567 p99=137.770 max=390.423
# delta_G mean=11.64, dr mean=-0.0005
# [debug] avg |prog| term per step ≈ 0.001862
# [debug] avg dr term per step      ≈ -0.000465
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 33/40: epsilon=0.154, avg_return=433.905, avg_steps=580.2
#
# [Episode 33 reward breakdown] n=193196
#   delta_G   mean= 12.7431   min= 0.1183   max= 390.4225
#   dr        mean=-0.0005   min=-0.0156   max=-0.0000
#   exp       mean= 0.0449   min= 0.0000   max= 0.1000
#   miss      mean=-0.0776   min=-300.0000   max= 0.0000
#   prog      mean= 0.0022   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.8789   min= 0.0000   max= 600.0000
#   total     mean= 0.7479   min=-301.1022   max= 601.0000
# [ΔG percentiles] p50=5.867 p90=30.370 p99=111.051 max=390.423
# delta_G mean=12.74, dr mean=-0.0005
# [debug] avg |prog| term per step ≈ 0.002228
# [debug] avg dr term per step      ≈ -0.000510
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 34/40: epsilon=0.146, avg_return=420.014, avg_steps=595.8
#
# [Episode 34 reward breakdown] n=198413
#   delta_G   mean= 10.5805   min= 0.1183   max= 390.4225
#   dr        mean=-0.0004   min=-0.0156   max=-0.0000
#   exp       mean= 0.0460   min= 0.0000   max= 0.1000
#   miss      mean=-0.0832   min=-300.0000   max= 0.0000
#   prog      mean= 0.0018   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.8407   min= 0.0000   max= 600.0000
#   total     mean= 0.7049   min=-300.3366   max= 601.0000
# [ΔG percentiles] p50=5.272 p90=23.656 p99=72.621 max=390.423
# delta_G mean=10.58, dr mean=-0.0004
# [debug] avg |prog| term per step ≈ 0.001796
# [debug] avg dr term per step      ≈ -0.000423
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 35/40: epsilon=0.138, avg_return=463.450, avg_steps=537.6
#
# [Episode 35 reward breakdown] n=179030
#   delta_G   mean= 10.5100   min= 0.1183   max= 390.4225
#   dr        mean=-0.0004   min=-0.0156   max=-0.0000
#   exp       mean= 0.0496   min= 0.0000   max= 0.1000
#   miss      mean=-0.0687   min=-300.0000   max= 0.0000
#   prog      mean= 0.0030   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.9786   min= 0.0000   max= 600.0000
#   total     mean= 0.8620   min=-300.7587   max= 601.0000
# [ΔG percentiles] p50=5.406 p90=23.555 p99=71.441 max=390.423
# delta_G mean=10.51, dr mean=-0.0004
# [debug] avg |prog| term per step ≈ 0.002979
# [debug] avg dr term per step      ≈ -0.000420
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 36/40: epsilon=0.131, avg_return=413.681, avg_steps=594.7
#
# [Episode 36 reward breakdown] n=198041
#   delta_G   mean= 12.0469   min= 0.1537   max= 390.4225
#   dr        mean=-0.0005   min=-0.0156   max=-0.0000
#   exp       mean= 0.0450   min= 0.0000   max= 0.1000
#   miss      mean=-0.0863   min=-300.0000   max= 0.0000
#   prog      mean= 0.0012   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.8362   min= 0.0000   max= 600.0000
#   total     mean= 0.6956   min=-301.1006   max= 601.0000
# [ΔG percentiles] p50=5.522 p90=23.706 p99=137.770 max=390.423
# delta_G mean=12.05, dr mean=-0.0005
# [debug] avg |prog| term per step ≈ 0.001238
# [debug] avg dr term per step      ≈ -0.000482
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 37/40: epsilon=0.123, avg_return=455.387, avg_steps=566.8
#
# [Episode 37 reward breakdown] n=188748
#   delta_G   mean= 10.0940   min= 0.1183   max= 390.4225
#   dr        mean=-0.0004   min=-0.0156   max=-0.0000
#   exp       mean= 0.0480   min= 0.0000   max= 0.1000
#   miss      mean=-0.0683   min=-300.0000   max= 0.0000
#   prog      mean= 0.0023   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.9219   min= 0.0000   max= 600.0000
#   total     mean= 0.8034   min=-301.1007   max= 601.0000
# [ΔG percentiles] p50=5.189 p90=22.207 p99=67.803 max=390.423
# delta_G mean=10.09, dr mean=-0.0004
# [debug] avg |prog| term per step ≈ 0.002317
# [debug] avg dr term per step      ≈ -0.000404
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 38/40: epsilon=0.115, avg_return=420.832, avg_steps=606.1
#
# [Episode 38 reward breakdown] n=201815
#   delta_G   mean= 10.0845   min= 0.1183   max= 390.4225
#   dr        mean=-0.0004   min=-0.0156   max=-0.0000
#   exp       mean= 0.0478   min= 0.0000   max= 0.1000
#   miss      mean=-0.0818   min=-300.0000   max= 0.0000
#   prog      mean= 0.0022   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.8265   min= 0.0000   max= 600.0000
#   total     mean= 0.6944   min=-300.9385   max= 601.0000
# [ΔG percentiles] p50=5.541 p90=22.031 p99=66.295 max=390.423
# delta_G mean=10.08, dr mean=-0.0004
# [debug] avg |prog| term per step ≈ 0.002217
# [debug] avg dr term per step      ≈ -0.000403
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 39/40: epsilon=0.108, avg_return=474.344, avg_steps=531.8
#
# [Episode 39 reward breakdown] n=177082
#   delta_G   mean= 12.1547   min= 0.1183   max= 390.4225
#   dr        mean=-0.0005   min=-0.0156   max=-0.0000
#   exp       mean= 0.0480   min= 0.0000   max= 0.1000
#   miss      mean=-0.0627   min=-300.0000   max= 0.0000
#   prog      mean= 0.0042   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 1.0029   min= 0.0000   max= 600.0000
#   total     mean= 0.8920   min=-301.0006   max= 601.0000
# [ΔG percentiles] p50=5.522 p90=28.135 p99=137.770 max=390.423
# delta_G mean=12.15, dr mean=-0.0005
# [debug] avg |prog| term per step ≈ 0.004226
# [debug] avg dr term per step      ≈ -0.000486
# [debug] avg step term per step    ≈ -0.100000
# [TRUE-COIN+Expert] Episode 40/40: epsilon=0.100, avg_return=374.074, avg_steps=621.6
#
# [Episode 40 reward breakdown] n=207008
#   delta_G   mean= 10.8374   min= 0.1183   max= 390.4225
#   dr        mean=-0.0004   min=-0.0156   max=-0.0000
#   exp       mean= 0.0443   min= 0.0000   max= 0.1000
#   miss      mean=-0.1029   min=-300.0000   max= 0.0000
#   prog      mean= 0.0013   min=-1.0000   max= 1.0000
#   step      mean=-0.1000   min=-0.1000   max=-0.1000
#   term      mean= 0.7594   min= 0.0000   max= 600.0000
#   total     mean= 0.6017   min=-301.1006   max= 601.0000
# [ΔG percentiles] p50=5.941 p90=24.676 p99=63.127 max=390.423
# delta_G mean=10.84, dr mean=-0.0004
# [debug] avg |prog| term per step ≈ 0.001346
# [debug] avg dr term per step      ≈ -0.000433
# [debug] avg step term per step    ≈ -0.100000
# Finished TRUE-COIN+Expert Q-learning with 4419395 learned state–action entries.

# %% [markdown]
# ## Best setup results

# %%
print(f"\n=== Summary for {num_agents} agents ===")

print("========== Fraction reached ==========")
for name, (agents, flows, G) in results.items():
    print(f"[{name}] - reaching dest: {fraction_reached_agentspecific(agents):.3f}")

print("\n========== Scenario metrics ==========")
for name, (agents, flows, G) in results.items():
    n = len(agents)
    print_scenario_metrics(name, manhattan_network, flows, G, n)

# Optional: quick global comparison
print("\n=== Global G comparison (hours) ===")
print(f"G_SPA              = {G_spa/3600:.2f} hrs")
print(f"G_FF               = {G_ff/3600:.2f} hrs")
print(f"G_FF-RL (COIN+exp) = {G_ff_rl/3600:.2f} hrs")
print(f"Improvement (FF-RL vs SPA)     = {(G_spa - G_ff_rl) / G_spa * 100:.2f}%")
# Out:
# === Summary for 1000 agents ===
# ========== Fraction reached ==========
# [SPA] - reaching dest: 0.912
# [FF] - reaching dest: 0.908
# [FF-RL (TRUE COIN + expert)] - reaching dest: 0.230
#
# ========== Scenario metrics ==========
#
# [SPA] metrics:
#   Average travel time per agent:   836.08 s  ( 13.93 min)
#   Total distance traveled:       10318.23 km
#   Average distance per agent:       10.32 km
#
# [FF] metrics:
#   Average travel time per agent:  1070.89 s  ( 17.85 min)
#   Total distance traveled:       11482.40 km
#   Average distance per agent:       11.48 km
#
# [FF-RL (TRUE COIN + expert)] metrics:
#   Average travel time per agent: 14665.69 s  (244.43 min)
#   Total distance traveled:       155973.56 km
#   Average distance per agent:      155.97 km
#
# === Global G comparison (hours) ===
# G_SPA              = 232.25 hrs
# G_FF               = 297.47 hrs
# G_FF-RL (COIN+exp) = 4073.80 hrs
# Improvement (FF-RL vs SPA)     = -1654.10%

# %% [markdown]
# ### Best setup parameters

# %%
pd.DataFrame(best)
# Out:
#                               13
# trial                         14
# elapsed_s              80.288723
# reach_spa                  0.912
# reach_ff                   0.908
# reach_ff_rl                 0.23
# G_spa_vehhrs          232.245023
# G_ff_vehhrs            297.46848
# G_ff_rl_vehhrs       4073.802056
# feasible                    True
# temperature                  0.1
# lambda_live_cost             2.5
# visited_penalty_val          3.0
# epsilon_eval                0.01
# epsilon_start                0.4
# epsilon_end                  0.1
# num_episodes_rl               40
# lambda_dr                    0.2
# lambda_prog                  1.0
# lambda_exp                   0.1
# lambda_step                  0.1
# time_scale                  5000
# lambda_term                600.0
# lambda_miss                300.0

# %% [markdown]
# ## Best setup visualizations

# %%
plot_routes_three_way(
    gdf,
    agents_spa, G_spa,
    agents_ff, G_ff,
    agents_ff_rl, G_ff_rl,
    num_agents=num_agents,
    horizon_s=horizon_s,
)

plot_heatmaps_three_way(
    gdf,
    manhattan_network,
    flows_spa,
    flows_ff,
    flows_ff_rl,
    num_agents=num_agents,
    horizon_s=horizon_s,
)

# %% [markdown]
# # Animation

# %% [markdown]
# ## Animation Helper

# %%
def animate_routes_three_way_light(
    gdf: gpd.GeoDataFrame,
    agents_spa: list,
    agents_ff: list,
    agents_ff_rl: list,
    num_agents: int,
    out_path: str | None = None,
    max_frames: int = 80,      # total frames of the animation
    fps: int = 8,              # frames per second
    figsize=(10, 6),           # overall figure size
    dpi: int = 80,             # resolution
):
    """
    Lightweight 3-panel animation of SPA, FF/COIN_FF, and FF-RL (expert COIN) routes.

    Each panel:
      - draws the Manhattan network once as a gray background
      - shows the routes being constructed over time

    The function:
      - sub-samples each path so we only use `max_frames` frames
      - saves as an MP4 (much smaller than GIF)

    Parameters
    ----------
    gdf : GeoDataFrame
        Street network (same you used for static plots).
    agents_spa, agents_ff, agents_ff_rl : list[Agent]
        Agents with .path = [node0, node1, ...].
    num_agents : int
        Number of agents used in the experiment (for title + filename).
    out_path : str or None
        Output file name (MP4). If None, a name with num_agents is used.
    max_frames : int
        Maximum number of frames in the animation.
    fps : int
        Frames per second.
    figsize : tuple
        Matplotlib figure size.
    dpi : int
        Resolution of the saved video.
    """

    # auto-generate filename if not provided
    if out_path is None:
        out_path = f"routes_three_way_{num_agents}_agents.mp4"

    # --- helper: convert Node -> (x, y) ---
    def node_xy(node):
        x, y = node  # your Node is an (x, y) tuple
        return x, y

    # --- prepare figure with 3 subplots ---
    fig, axes = plt.subplots(1, 3, figsize=figsize)

    titles = [
        "SPA routes",
        "FF / COIN_FF routes",
        "FF-RL (Expert COIN) routes",
    ]

    # draw background network once in each subplot
    for ax, title in zip(axes, titles):
        gdf.plot(ax=ax, color="lightgrey", linewidth=0.3)
        ax.set_axis_off()
        ax.set_title(title, fontsize=10)

    # global title with number of agents
    fig.suptitle(
        f"Animation for {num_agents} agents",
        fontsize=12,
        fontweight="bold",
        y=0.97
    )

    # for each scenario, convert paths to (xs, ys) lists
    scenarios_agents = [agents_spa, agents_ff, agents_ff_rl]
    scenarios_paths_xy = []     # per scenario: list of (xs, ys)
    global_max_len = 0          # longest path across all scenarios

    for agents in scenarios_agents:
        paths_xy = []
        for a in agents:
            if not getattr(a, "path", None) or len(a.path) < 2:
                continue
            xs, ys = zip(*[node_xy(n) for n in a.path])
            paths_xy.append((xs, ys))
            global_max_len = max(global_max_len, len(xs))
        scenarios_paths_xy.append(paths_xy)

    if global_max_len == 0:
        print("No non-empty paths to animate.")
        plt.close(fig)
        return

    # total frames = min(max_frames, longest path length)
    n_frames = min(max_frames, global_max_len)

    # for each scenario and each path, precompute indices per frame
    scenarios_indices_per_frame = []
    for paths_xy in scenarios_paths_xy:
        idx_lists = []
        for xs, ys in paths_xy:
            L = len(xs)
            if L <= 1:
                idx_lists.append([0] * n_frames)
                continue
            idxs = [
                min(int((k / (n_frames - 1)) * (L - 1)), L - 1)
                for k in range(n_frames)
            ]
            idx_lists.append(idxs)
        scenarios_indices_per_frame.append(idx_lists)

    # line objects for each path in each scenario
    scenarios_lines = []
    for ax, paths_xy in zip(axes, scenarios_paths_xy):
        scenario_lines = []
        for xs, ys in paths_xy:
            line, = ax.plot([], [], linewidth=1.5)
            scenario_lines.append(line)
        scenarios_lines.append(scenario_lines)

    # --- animation callbacks ---
    def init():
        for scenario_lines in scenarios_lines:
            for line in scenario_lines:
                line.set_data([], [])
        return [line for scenario_lines in scenarios_lines for line in scenario_lines]

    def update(frame):
        for paths_xy, idx_lists, lines in zip(
            scenarios_paths_xy,
            scenarios_indices_per_frame,
            scenarios_lines
        ):
            for (xs, ys), idxs, line in zip(paths_xy, idx_lists, lines):
                idx = idxs[frame]
                line.set_data(xs[:idx + 1], ys[:idx + 1])

        return [line for scenario_lines in scenarios_lines for line in scenario_lines]

    anim = FuncAnimation(
        fig,
        update,
        frames=n_frames,
        init_func=init,
        blit=True,
        interval=1000 // fps,
    )

    # save as MP4 (small-ish)
    writer = FFMpegWriter(fps=fps, bitrate=1200)  # tweak bitrate if you want smaller file
    anim.save(out_path, writer=writer, dpi=dpi)
    plt.close(fig)

    print(
        f"Saved 3-way route animation to {out_path} "
        f"({n_frames} frames, {fps} fps, {num_agents} agents)"
    )

# %% [markdown]
# ## Run animation

# %%
animate_routes_three_way_light(
    gdf,
    agents_spa,
    agents_ff,
    agents_ff_rl,
    num_agents=num_agents,
    out_path=None,        # or leave out to auto-name with num_agents
    max_frames=80,
    fps=8,
)
